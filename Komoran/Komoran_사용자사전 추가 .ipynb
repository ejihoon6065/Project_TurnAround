# %% [markdown]
# # 본문에서는 soynlp를 사용
# #### https://datascienceschool.net/view-notebook/31eaecec4187428a8dfcab5f686bda8b/ soynlp 설명 사이트
# #### 단어를 cohenson 위주로 설명
# #### word_score["연합"].right_branching_entropy => 0.42721236711742844
# #### word_score["연합뉴스"].right_branching_entropy => 3.8967810761022053
# #### word_score["연합뉴스는"].right_branching_entropy => 0.410116318288409
# #### 이런식으로 워드 스코어를 만들어준다. 이를 통해 komoran의 단어사전을 만들어 줄 수 있다.

# %%
import konlpy
from konlpy.tag import Komoran
from pprint import pprint
from collections import defaultdict
from collections import Counter
komoran=Komoran()
print(konlpy.__version__)


import pandas as pd
# Out:
# 0.5.2

# %%
import datetime

year = 2020 #2020
month = 7 #7
day = 25 #28
lenth = 56 #26
# The size of each step in days
day_delta = datetime.timedelta(days=1)

start_date = datetime.date(year, month, day) + 1*day_delta # 가장 첫번째 day는 concat을 위한 base corpus 로 설정하기 위해 빼준다. 
end_date = start_date + lenth*day_delta # 숫자를 설정하여 일수를 조절 할 수 있다. 

date_list = []
for i in range((end_date - start_date).days):
    date_list.append(str(start_date + i*day_delta))
   # print(date_list)
print(start_date)
print(end_date)
# Out:
# 2020-07-26
# 2020-09-20

# %%
corpus_start_date = start_date - 1*day_delta  # 위에서 
Data=pd.read_excel(f"D:\Turnaround_Project\YG_DATA\YG_DATAyg {corpus_start_date}.xlsx") 
corpus_start=Data['title'] 

#!pip install xlrd
for i in date_list :
    Data=pd.read_excel(f'D:\Turnaround_Project\YG_DATA\YG_DATAyg {i}.xlsx') ##데이터 가져오기 
    #corpus.append(Data['title'])  ##데이터 text 지정 - 열이 여러개일때
    corpus = Data['title']
    corpus_start = pd.concat([corpus_start, corpus])
    #print(corpus_start)
corpus = corpus_start
print(corpus)
# Out:
# 0                        나도 ‘따상’ 꿀맛 좀 보자…개미들 공모주에 취했다
# 1                                          블랙핑크 세계1위!
# 2           '유희열의 스케치북' 이하이, 다이어트 후 달라진 몸매…'시청자도 놀랐다'
# 3     이하이 “YG→AOMG 이적, 유희열 안테나 연락 없더라”(스케치북)[결정적장면...
# 4                    한승연, 여고생이라고 해도 믿을수 있는 최강의 동안 비주얼
#                            ...
# 70             블랙핑크, 美 유명 패션지 커버! 음악·패션 넘나드는 아이콘 '주목'
# 71                  블랙핑크X셀레나고메즈 'Ice Cream' 리릭 비디오 공개
# 72                       BTS의 분신이 광고도 찍는다...아이돌의 아바타들
# 73               블랙핑크 리사, 독보적인 원피스 소화력…사랑스러운 뿔머리 '눈길'
# 74                          안병용 의정부시장 “청년체감형 정책 적극개발”
# Name: title, Length: 5239, dtype: object

# %%
from soynlp.word import WordExtractor
word_extractor=WordExtractor(max_left_length=10, max_right_length=6, min_frequency=5)
word_extractor.train(corpus)
scores=word_extractor.word_scores()


from soynlp.noun import LRNounExtractor_v2
noun_extractor=LRNounExtractor_v2()
nouns=noun_extractor.train_extract(corpus,min_noun_frequency=2) #적어도 2번 이상 나온 단어 
print(len(nouns)) #추출된 단어의 갯수 확인 
#nouns['국립암센터'] #특정단어의 빈도수와 단어점수를 알고 싶을때 사용 



high_frequency=[(word, *score) for word, score in nouns.items() 
                if not word.isdigit() and len(word)>1]
sorted(high_frequency, key=lambda x:(-x[1], x[0]))[:1000]
# 단어   (빈도수, cohesion)
# Out:
# training was done. used memory 1.106 Gbry 1.106 Gb
# all cohesion probabilities was computed. # words = 4900
# all branching entropies was computed # words = 9610
# all accessor variety was computed # words = 9610
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 12688 from 5239 sents. mem=1.106 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=40942, mem=1.122 Gb
# [Noun Extractor] batch prediction was completed for 2461 words
# [Noun Extractor] checked compounds. discovered 111 compounds
# [Noun Extractor] postprocessing detaching_features : 728 -> 728
# [Noun Extractor] postprocessing ignore_features : 728 -> 709
# [Noun Extractor] postprocessing ignore_NJ : 709 -> 709
# [Noun Extractor] 709 nouns (111 compounds) with min frequency=2
# [Noun Extractor] flushing was done. mem=1.130 Gb
# [Noun Extractor] 51.41 % eojeols are covered
# 709
# [('블랙핑크', 798, 1.0),
#  ('YG', 566, 0.75),
#  ('공개', 377, 1.0),
#  ('신곡', 315, 0.6666666666666666),
#  ('양현석', 307, 1.0),
#  ('데뷔', 275, 1.0),
#  ('트레저', 274, 1.0),
#  ('신인', 234, 1.0),
#  ('고메즈', 203, 1.0),
#  ('뮤비', 202, 1.0),
#  ('포스터', 199, 0.6),
#  ('MV', 196, 0.75),
#  ('돌파', 193, 1.0),
#  ("Cream'", 168, 1.0),
#  ('컴백', 153, 1.0),
#  ('K팝', 149, 1.0),
#  ('앨범', 144, 1.0),
#  ("'아이스크림'", 142, 1.0),
#  ('혐의', 139, 1.0),
#  ('1위', 136, 1.0),
#  ('최초', 133, 1.0),
#  ('대표', 111, 1.0),
#  ("'BOY'", 105, 1.0),
#  ('영상', 103, 0.6666666666666666),
#  ('세계', 98, 1.0),
#  ('뮤직비디오', 97, 1.0),
#  ('발매', 94, 1.0),
#  ("'사랑해'", 91, 1.0),
#  ('그룹', 87, 0.5),
#  ('매력', 84, 1.0),
#  ("That'", 81, 1.0),
#  ('정규앨범', 81, 1.0),
#  ('글로', 79, 0.9186046511627907),
#  ('예고', 77, 1.0),
#  ('싱글', 76, 1.0),
#  ('8월', 73, 1.0),
#  ('Cream’', 73, 1.0),
#  ('5억뷰', 72, 1.0),
#  ('걸그룹', 71, 1.0),
#  ('안무', 71, 1.0),
#  ('출연', 66, 1.0),
#  ("'YG", 64, 1.0),
#  ('10월', 64, 1.0),
#  ('BTS', 64, 1.0),
#  ('기록', 64, 0.3333333333333333),
#  ('빅히트', 63, 1.0),
#  ('선주문', 63, 1.0),
#  ('출석', 63, 1.0),
#  ('9월', 62, 1.0),
#  ('상장', 62, 1.0),
#  ('넷플릭스', 61, 0.3333333333333333),
#  ('솔로', 61, 1.0),
#  ("'뚜두뚜두'", 59, 1.0),
#  ('아티스트', 59, 1.0),
#  ('제니', 57, 1.0),
#  ('차트', 56, 0.5),
#  ('발표', 49, 1.0),
#  ('확정', 47, 1.0),
#  ('모두', 45, 1.0),
#  ('도박', 44, 1.0),
#  ('법원', 43, 1.0),
#  ('인정', 43, 1.0),
#  ('4위', 42, 1.0),
#  ('데뷔곡', 41, 1.0),
#  ('스포티파이', 41, 1.0),
#  ('최고', 41, 1.0),
#  ('기대', 40, 1.0),
#  ("'K팝", 37, 1.0),
#  ('신기록', 37, 1.0),
#  ("신인'", 37, 1.0),
#  ('아이돌', 37, 1.0),
#  ('가수', 36, 1.0),
#  ('다큐', 35, 1.0),
#  ('스트리밍', 35, 1.0),
#  ('음원', 35, 1.0),
#  ('SM', 34, 1.0),
#  ('시장', 34, 1.0),
#  ('정규', 34, 1.0),
#  ('무대', 33, 1.0),
#  ('제목', 33, 0.9705882352941176),
#  ('함께', 33, 1.0),
#  ('근황', 32, 1.0),
#  ('등극', 32, 1.0),
#  ('위너', 32, 1.0),
#  ('"블랙핑크', 31, 1.0),
#  ("'설강화'", 30, 0.3333333333333333),
#  ('비디오', 30, 0.9090909090909091),
#  ('아바타', 30, 0.8181818181818182),
#  ('"YG', 29, 0.7837837837837838),
#  ('3차례', 29, 1.0),
#  ('달콤', 29, 1.0),
#  ('전세계', 29, 1.0),
#  ('참여', 29, 0.6590909090909091),
#  ('IPO', 28, 1.0),
#  ('시작', 28, 1.0),
#  ('타이틀곡', 28, 1.0),
#  ('해외', 28, 0.7567567567567568),
#  ('콘테스트', 27, 0.84375),
#  ('‘뚜두뚜두’', 26, 1.0),
#  ('강렬', 26, 1.0),
#  ('라이브', 26, 1.0),
#  ('여성', 26, 0.9285714285714286),
#  ('주인공', 26, 1.0),
#  ('7일', 25, 1.0),
#  ('방예담', 25, 0.8620689655172413),
#  ('보석함', 25, 0.9259259259259259),
#  ('콘셉트', 25, 1.0),
#  ('특별', 25, 0.8064516129032258),
#  ('3위', 24, 0.7272727272727273),
#  ('4년', 24, 1.0),
#  ('사랑', 24, 1.0),
#  ('주가', 24, 1.0),
#  ("'트레저'", 23, 1.0),
#  ('12人', 23, 0.9583333333333334),
#  ("댓'", 23, 0.71875),
#  ("러브'", 23, 1.0),
#  ('비주얼', 23, 1.0),
#  ('캐릭터', 23, 1.0),
#  ('조회수', 22, 0.9565217391304348),
#  ('가득', 21, 0.84),
#  ('광복절', 21, 1.0),
#  ('상승', 21, 1.0),
#  ('에미넴', 21, 1.0),
#  ('통화', 21, 0.9545454545454546),
#  ('6일', 20, 1.0),
#  ('That’', 20, 0.9523809523809523),
#  ('관심', 20, 1.0),
#  ('도전', 20, 0.46511627906976744),
#  ('방탄소년단', 20, 1.0),
#  ('보이그룹', 20, 0.9090909090909091),
#  ('열풍', 20, 1.0),
#  ('팬들', 20, 1.0),
#  ('‘사랑해’', 19, 0.7916666666666666),
#  ('기대감', 19, 1.0),
#  ('모델', 19, 0.95),
#  ('싱글앨범', 19, 0.8260869565217391),
#  ('올해', 19, 1.0),
#  ('질문', 19, 1.0),
#  ("'솔로'", 18, 0.9),
#  ('26시간', 18, 1.0),
#  ('4400만명', 18, 0.9),
#  ('묵묵부답', 18, 0.5),
#  ('벌써', 18, 1.0),
#  ('성장', 18, 1.0),
#  ('안무영상', 18, 0.9),
#  ('영화', 18, 1.0),
#  ('준비', 18, 1.0),
#  ('판매량', 18, 1.0),
#  ('피처링', 18, 0.72),
#  ('행보', 18, 0.6428571428571429),
#  ('활동', 18, 0.8571428571428571),
#  ('히로카즈', 18, 1.0),
#  ('41시간', 17, 0.9444444444444444),
#  ('네이버', 17, 1.0),
#  ('상큼', 17, 0.7727272727272727),
#  ('주목', 17, 1.0),
#  ('9일', 16, 0.9411764705882353),
#  ('가온차트', 16, 0.3333333333333333),
#  ('소유', 16, 0.8421052631578947),
#  ('시런', 16, 1.0),
#  ('싹쓸이', 16, 0.8421052631578947),
#  ('언택트', 16, 1.0),
#  ('코로나19', 16, 1.0),
#  ('탄생', 16, 0.64),
#  ('한국', 16, 0.6),
#  ('현장', 16, 1.0),
#  ('M/V', 15, 1.0),
#  ('공모주', 15, 0.9375),
#  ('데뷔앨범', 15, 1.0),
#  ('변신', 15, 1.0),
#  ('선물', 15, 1.0),
#  ('여부', 15, 0.9375),
#  ('역대급', 15, 1.0),
#  ('예상', 15, 0.7894736842105263),
#  ('이하이', 15, 0.39473684210526316),
#  ('참석', 15, 1.0),
#  ('코로나', 15, 1.0),
#  ('팬사인회', 15, 1.0),
#  ('표정', 15, 0.8333333333333334),
#  ('"데뷔', 14, 1.0),
#  ('‘K팝', 14, 1.0),
#  ('가을', 14, 1.0),
#  ('경신', 14, 1.0),
#  ('달성', 14, 1.0),
#  ('멤버', 14, 1.0),
#  ('올라', 14, 0.7368421052631579),
#  ('음악방송', 14, 0.9333333333333333),
#  ('접수', 14, 1.0),
#  ('폭풍성장', 14, 0.875),
#  ('하루', 14, 1.0),
#  ("'글로", 13, 0.8666666666666667),
#  ('다른', 13, 0.9285714285714286),
#  ('생일', 13, 0.8666666666666667),
#  ('시간', 13, 0.6190476190476191),
#  ('시너지', 13, 0.8666666666666667),
#  ('시총', 13, 0.8666666666666667),
#  ('오픈', 13, 0.43333333333333335),
#  ('음원차트', 13, 0.9285714285714286),
#  ('퍼포먼스', 13, 0.7222222222222222),
#  ('13위', 12, 0.42857142857142855),
#  ('YG엔터', 12, 0.36363636363636365),
#  ('‘설강화’', 12, 1.0),
#  ('그래미', 12, 1.0),
#  ('완주', 12, 0.8571428571428571),
#  ('입증', 12, 0.75),
#  ('제작', 12, 1.0),
#  ('질문에', 12, 0.8),
#  ('청약', 12, 0.75),
#  ('2020년', 11, 1.0),
#  ('돌아', 11, 1.0),
#  ('러블리', 11, 1.0),
#  ('산다라박', 11, 1.0),
#  ('씨엘', 11, 0.3793103448275862),
#  ('예승이', 11, 0.6111111111111112),
#  ('오늘(18일)', 11, 1.0),
#  ('우리', 11, 1.0),
#  ('직진', 11, 0.7857142857142857),
#  ('캐스팅', 11, 0.55),
#  ('투자', 11, 0.5555555555555556),
#  ('하락', 11, 1.0),
#  ("'스타로드'", 10, 1.0),
#  ('4주년', 10, 0.43478260869565216),
#  ('CJCGV', 10, 1.0),
#  ('`아이스크림`', 10, 0.9090909090909091),
#  ('관광홍보대사', 10, 0.9090909090909091),
#  ('광고', 10, 0.8333333333333334),
#  ('김도훈', 10, 1.0),
#  ('대회', 10, 0.9090909090909091),
#  ('러브’', 10, 1.0),
#  ('로맨틱', 10, 1.0),
#  ('이번', 10, 1.0),
#  ('일본', 10, 0.5),
#  ('취재진', 10, 1.0),
#  ("'7번방", 9, 0.9),
#  ("'보이'", 9, 1.0),
#  ('1000억', 9, 0.75),
#  ('5주년', 9, 0.42857142857142855),
#  ('7년', 9, 1.0),
#  ('AOMG', 9, 1.0),
#  ('감독', 9, 0.6923076923076923),
#  ('관련주', 9, 1.0),
#  ('논란', 9, 1.0),
#  ('등장', 9, 1.0),
#  ('모습', 9, 0.9),
#  ('사진', 9, 1.0),
#  ('상승세', 9, 0.6428571428571429),
#  ('소통', 9, 1.0),
#  ('엔터株', 9, 0.75),
#  ('여름', 9, 1.0),
#  ('역사', 9, 0.6428571428571429),
#  ('영향력', 9, 0.6428571428571429),
#  ('완성', 9, 0.5625),
#  ('이상', 9, 0.6923076923076923),
#  ('인정…취재진', 9, 1.0),
#  ('조언', 9, 0.6923076923076923),
#  ('지원', 9, 1.0),
#  ('청량', 9, 0.4090909090909091),
#  ('최단기', 9, 0.7777777777777778),
#  ('활약', 9, 0.6428571428571429),
#  ("'취재진", 8, 1.0),
#  ('FNC', 8, 0.8888888888888888),
#  ('거침', 8, 1.0),
#  ('고개', 8, 1.0),
#  ('공모', 8, 1.0),
#  ('기간', 8, 0.8888888888888888),
#  ('내달', 8, 1.0),
#  ('무드', 8, 0.8888888888888888),
#  ('박준형', 8, 0.38095238095238093),
#  ('소년미', 8, 0.6153846153846154),
#  ('실적', 8, 0.6666666666666666),
#  ('오나라', 8, 0.47058823529411764),
#  ('이후', 8, 1.0),
#  ('주식', 8, 0.42105263157894735),
#  ('추억', 8, 0.6666666666666666),
#  ('팬덤', 8, 1.0),
#  ('"데뷔곡', 7, 1.0),
#  ('10월2', 7, 0.875),
#  ('2년', 7, 1.0),
#  ('“우리', 7, 1.0),
#  ('검찰', 7, 0.4375),
#  ('고양이', 7, 0.875),
#  ('광고계', 7, 1.0),
#  ('목표', 7, 0.30434782608695654),
#  ('미소', 7, 0.7777777777777778),
#  ('시대', 7, 0.875),
#  ('에너지', 7, 0.7),
#  ('예능', 7, 0.5384615384615384),
#  ('완벽', 7, 0.7),
#  ('음성', 7, 0.7777777777777778),
#  ('음악', 7, 1.0),
#  ('이적', 7, 0.875),
#  ('입성', 7, 0.4666666666666667),
#  ('주자', 7, 0.5),
#  ('폭우', 7, 1.0),
#  ('확인', 7, 0.7),
#  ('"함께', 6, 1.0),
#  ('45일', 6, 1.0),
#  ('`뚜두뚜두`', 6, 1.0),
#  ('“블랙핑크', 6, 1.0),
#  ('결혼', 6, 0.8571428571428571),
#  ('대형신인', 6, 0.6666666666666666),
#  ('반나절', 6, 1.0),
#  ('부담', 6, 0.8571428571428571),
#  ('부부', 6, 0.6666666666666666),
#  ('생각', 6, 1.0),
#  ('신인상', 6, 0.5),
#  ('아동', 6, 0.75),
#  ('악재', 6, 1.0),
#  ('압도적', 6, 1.0),
#  ('여고생', 6, 1.0),
#  ('연예인', 6, 0.8571428571428571),
#  ('요구', 6, 0.6),
#  ('의미', 6, 0.6666666666666666),
#  ('작사', 6, 1.0),
#  ('제작진', 6, 0.75),
#  ('차량', 6, 0.5),
#  ('한류', 6, 0.75),
#  ('효과', 6, 0.6666666666666666),
#  ('"\'아이스크림\'', 5, 1.0),
#  ('"러블리', 5, 1.0),
#  ("'러블리", 5, 0.8333333333333334),
#  ("'치명적", 5, 0.8333333333333334),
#  ('12명', 5, 1.0),
#  ('12색', 5, 1.0),
#  ('40시간', 5, 0.8333333333333334),
#  ('43일', 5, 1.0),
#  ('That`', 5, 1.0),
#  ('YG보석', 5, 1.0),
#  ('[연', 5, 0.4166666666666667),
#  ('‘트레저’', 5, 0.8333333333333334),
#  ('韓영화', 5, 1.0),
#  ('감성', 5, 1.0),
#  ('강승윤', 5, 1.0),
#  ('기업가치', 5, 1.0),
#  ('녹음', 5, 0.8333333333333334),
#  ('돌풍', 5, 0.625),
#  ('발랄', 5, 0.7142857142857143),
#  ('방송', 5, 0.3333333333333333),
#  ('방시혁', 5, 0.7142857142857143),
#  ('보유', 5, 1.0),
#  ('불안', 5, 1.0),
#  ('빅히트엔터', 5, 0.4166666666666667),
#  ('사업', 5, 1.0),
#  ('서프라이즈', 5, 0.8333333333333334),
#  ('스쿨룩', 5, 0.8333333333333334),
#  ('에미넘', 5, 1.0),
#  ('응원', 5, 0.625),
#  ('점령', 5, 0.625),
#  ('한복', 5, 0.4166666666666667),
#  ('확정…', 5, 1.0),
#  ('"내', 4, 1.0),
#  ('"서', 4, 1.0),
#  ('"올', 4, 1.0),
#  ('1년', 4, 1.0),
#  ('2위', 4, 0.6666666666666666),
#  ('JYP엔터테인먼트', 4, 0.8),
#  ('LP', 4, 0.5),
#  ('SM엔터‧YG엔터', 4, 1.0),
#  ('`사랑해`', 4, 1.0),
#  ('‘블랙핑크’', 4, 0.8),
#  ('‘솔로’', 4, 0.8),
#  ('감사', 4, 1.0),
#  ('강수지', 4, 1.0),
#  ('개성', 4, 1.0),
#  ('계속', 4, 0.6666666666666666),
#  ('계획', 4, 1.0),
#  ("고메즈'", 4, 0.8),
#  ('기소', 4, 0.8),
#  ('긴장', 4, 1.0),
#  ('난리', 4, 1.0),
#  ('단순', 4, 0.6666666666666666),
#  ('대어', 4, 0.6666666666666666),
#  ('대전', 4, 0.8),
#  ('데뷔음반', 4, 1.0),
#  ('도박혐의', 4, 1.0),
#  ('뛰어', 4, 0.8),
#  ('무모', 4, 1.0),
#  ('뿜뿜', 4, 0.5),
#  ('서부지법', 4, 1.0),
#  ('섹시', 4, 1.0),
#  ('소년', 4, 1.0),
#  ('스타일', 4, 0.5),
#  ("스텝'", 4, 1.0),
#  ('시원', 4, 1.0),
#  ('신작', 4, 1.0),
#  ("아이콘'", 4, 1.0),
#  ('여자', 4, 1.0),
#  ('여전', 4, 0.4),
#  ('완주…독립유공자', 4, 1.0),
#  ('위로', 4, 1.0),
#  ('이미지', 4, 0.6666666666666666),
#  ('정조준', 4, 1.0),
#  ('종목', 4, 0.5714285714285714),
#  ('증가', 4, 0.6666666666666666),
#  ('증여', 4, 1.0),
#  ('지금', 4, 0.6666666666666666),
#  ('최대어', 4, 1.0),
#  ('취소', 4, 1.0),
#  ('칠링', 4, 0.6666666666666666),
#  ('탑승', 4, 1.0),
#  ("테마주'", 4, 1.0),
#  ('팬심', 4, 1.0),
#  ('필요', 4, 0.4444444444444444),
#  ('女아티스트', 4, 1.0),
#  ('"BTS', 3, 1.0),
#  ('"나', 3, 1.0),
#  ('"너', 3, 0.5),
#  ('"우리', 3, 1.0),
#  ('"추', 3, 0.6),
#  ("'따", 3, 0.75),
#  ('10분', 3, 1.0),
#  ('10일', 3, 1.0),
#  ('2시간', 3, 1.0),
#  ('42일', 3, 1.0),
#  ('BTS·블랙핑크', 3, 0.6),
#  ('GD', 3, 1.0),
#  ('JYP엔터', 3, 0.75),
#  ('SM엔터테인먼트', 3, 1.0),
#  ('SNS', 3, 0.3333333333333333),
#  ('[오늘', 3, 0.375),
#  ('`트레저`', 3, 1.0),
#  ('‘7번방', 3, 1.0),
#  ('“함께', 3, 1.0),
#  ('가수들', 3, 1.0),
#  ('감탄', 3, 0.75),
#  ('개인전', 3, 0.6),
#  ('거품', 3, 0.75),
#  ('계약', 3, 0.75),
#  ('공개..수록곡', 3, 1.0),
#  ("공개…'강렬", 3, 1.0),
#  ('공개…달콤', 3, 1.0),
#  ('공개…훈훈', 3, 1.0),
#  ('공연', 3, 0.42857142857142855),
#  ('기업', 3, 0.3333333333333333),
#  ('네이버·카카오', 3, 1.0),
#  ('노력', 3, 1.0),
#  ('니쥬', 3, 0.375),
#  ('대장주', 3, 0.75),
#  ('대체', 3, 1.0),
#  ('덕분', 3, 0.42857142857142855),
#  ('드러', 3, 1.0),
#  ('루키', 3, 0.6),
#  ('마음', 3, 0.75),
#  ('막강', 3, 1.0),
#  ('멤버들', 3, 0.75),
#  ('문화', 3, 1.0),
#  ('부활', 3, 1.0),
#  ('비상', 3, 1.0),
#  ('사로', 3, 1.0),
#  ('색깔', 3, 0.5),
#  ('생활', 3, 0.75),
#  ('선배', 3, 0.6),
#  ('선배들', 3, 0.6),
#  ('선택', 3, 0.75),
#  ('세계적', 3, 1.0),
#  ('속도', 3, 1.0),
#  ('송민호', 3, 1.0),
#  ('슈퍼', 3, 0.5),
#  ('스튜디오드래곤', 3, 1.0),
#  ('에디션', 3, 0.75),
#  ('외국', 3, 1.0),
#  ('외면하고', 3, 1.0),
#  ('유행', 3, 1.0),
#  ('의상', 3, 1.0),
#  ('재활치료비', 3, 1.0),
#  ('제보', 3, 0.6),
#  ('제안', 3, 0.75),
#  ('종료', 3, 1.0),
#  ('주장', 3, 1.0),
#  ('증권', 3, 0.5),
#  ('질주', 3, 1.0),
#  ('첫걸음', 3, 0.5),
#  ('컴백…"데뷔곡', 3, 1.0),
#  ('콘서트', 3, 1.0),
#  ('탈락', 3, 1.0),
#  ('탈출', 3, 1.0),
#  ('트렌드', 3, 1.0),
#  ('팀워크', 3, 1.0),
#  ('포착', 3, 1.0),
#  ('필로폰', 3, 1.0),
#  ('한달', 3, 1.0),
#  ('후광', 3, 0.42857142857142855),
#  ('"10월', 2, 1.0),
#  ('"12', 2, 1.0),
#  ('"9월', 2, 1.0),
#  ('"독립유공자', 2, 1.0),
#  ('"독보적', 2, 1.0),
#  ('"블링크', 2, 1.0),
#  ('"비', 2, 0.6666666666666666),
#  ('"새', 2, 1.0),
#  ('"세상', 2, 1.0),
#  ('"셀레나고메즈', 2, 1.0),
#  ('"셀핑크', 2, 1.0),
#  ('"악뮤', 2, 0.6666666666666666),
#  ('"에미넴', 2, 1.0),
#  ('"여름', 2, 1.0),
#  ('"인성', 2, 0.5),
#  ('"코로나19', 2, 1.0),
#  ("'공", 2, 0.4),
#  ("'글로벌돌'", 2, 1.0),
#  ("'달콤", 2, 0.4),
#  ("'마", 2, 0.3333333333333333),
#  ("'반", 2, 1.0),
#  ("'수", 2, 0.4),
#  ("'짜릿", 2, 1.0),
#  ('1시간', 2, 1.0),
#  ('2.5단계', 2, 0.6666666666666666),
#  ('2명', 2, 1.0),
#  ('3년', 2, 1.0),
#  ('3천', 2, 0.4),
#  ('40여', 2, 1.0),
#  ('4위…에미넴', 2, 1.0),
#  ('BOY', 2, 0.5),
#  ('K-엔터', 2, 1.0),
#  ('K팝스타', 2, 0.6666666666666666),
#  ('[팝\'s신곡]"너', 2, 1.0),
#  ('‘도박’', 2, 1.0),
#  ('“역사', 2, 1.0),
#  ('가능', 2, 1.0),
#  ('강렬함', 2, 1.0),
#  ('갤러리', 2, 1.0),
#  ('경호', 2, 1.0),
#  ('공개..매혹적', 2, 1.0),
#  ('공개..상큼', 2, 0.6666666666666666),
#  ('공개..청량', 2, 0.5),
#  ('공개…12', 2, 0.5),
#  ('공개…청량', 2, 0.4),
#  ('군법정', 2, 1.0),
#  ('그것', 2, 1.0),
#  ('그들', 2, 1.0),
#  ('기대주', 2, 0.6666666666666666),
#  ('기억', 2, 0.6666666666666666),
#  ('낙수효과', 2, 0.4),
#  ('넘었다…', 2, 0.3333333333333333),
#  ('눈치', 2, 1.0),
#  ('다이너마이트', 2, 1.0),
#  ('달콤·청량', 2, 1.0),
#  ('대구', 2, 1.0),
#  ('도전장', 2, 1.0),
#  ('돌파...에미넴', 2, 1.0),
#  ('떡잎', 2, 1.0),
#  ('마운틴무브먼트', 2, 1.0),
#  ('맞이', 2, 1.0),
#  ('매일', 2, 1.0),
#  ('메이크업', 2, 0.6666666666666666),
#  ('무엇', 2, 0.6666666666666666),
#  ('물려', 2, 1.0),
#  ('뮤지컬', 2, 1.0),
#  ('바람', 2, 1.0),
#  ('바로', 2, 1.0),
#  ('배출', 2, 1.0),
#  ('벤처', 2, 1.0),
#  ('변경', 2, 1.0),
#  ('보석', 2, 1.0),
#  ('보여', 2, 0.3333333333333333),
#  ('본격화', 2, 0.6666666666666666),
#  ('분신', 2, 0.6666666666666666),
#  ('불가', 2, 0.6666666666666666),
#  ('사이', 2, 0.5),
#  ('선두', 2, 1.0),
#  ('선배님들', 2, 1.0),
#  ('선사', 2, 1.0),
#  ('성숙', 2, 1.0),
#  ('셀레나고메즈', 2, 0.6666666666666666),
#  ('소탈', 2, 0.4),
#  ('수업', 2, 1.0),
#  ('숙녀', 2, 1.0),
#  ('술집', 2, 0.6666666666666666),
#  ('스튜디오', 2, 1.0),
#  ('스트레', 2, 0.6666666666666666),
#  ('신선', 2, 0.6666666666666666),
#  ('씹어', 2, 1.0),
#  ('아들', 2, 1.0),
#  ('아스트', 2, 0.6666666666666666),
#  ('애틋', 2, 1.0),
#  ('야구', 2, 1.0),
#  ('양성', 2, 0.5),
#  ('에드시런', 2, 1.0),
#  ('엔터사업', 2, 1.0),
#  ('예능감', 2, 0.5),
#  ('예술가', 2, 1.0),
#  ('오디션', 2, 1.0),
#  ('완화', 2, 0.6666666666666666),
#  ('요동', 2, 1.0),
#  ('유강남', 2, 1.0),
#  ('음식', 2, 0.6666666666666666),
#  ('이것', 2, 1.0),
#  ('이수', 2, 0.5),
#  ('인정..취재진', 2, 1.0),
#  ('인증', 2, 0.3333333333333333),
#  ('장현성', 2, 0.4),
#  ('재확산', 2, 0.6666666666666666),
#  ('저희', 2, 1.0),
#  ('접대', 2, 1.0),
#  ('제자', 2, 1.0),
#  ('조심', 2, 0.6666666666666666),
#  ('준규→요시', 2, 1.0),
#  ('진격', 2, 1.0),
#  ('청년', 2, 1.0),
#  ('축구대회', 2, 1.0),
#  ('컴백..', 2, 1.0),
#  ('키워드', 2, 0.5),
#  ('트와이스', 2, 0.5),
#  ('파급력', 2, 1.0),
#  ('팬데믹', 2, 1.0),
#  ('평정', 2, 1.0),
#  ('포브스', 2, 1.0),
#  ('폭락', 2, 1.0),
#  ('폭증', 2, 1.0),
#  ('핑크머리', 2, 1.0),
#  ('한국적', 2, 1.0),
#  ('헤어', 2, 0.6666666666666666),
#  ('헤어스타일', 2, 1.0),
#  ('혁신', 2, 0.5),
#  ('현지', 2, 0.6666666666666666),
#  ('확산', 2, 0.6666666666666666),
#  ('확장', 2, 0.4),
#  ('확정…12', 2, 0.6666666666666666),
#  ('회상', 2, 0.5),
#  ("효과'", 2, 1.0),
#  ('효자', 2, 1.0),
#  ('훈풍', 2, 1.0),
#  ('훈훈', 2, 0.6666666666666666),
#  ('흑자', 2, 0.4)]

# %%
import re
RE_FILTER = re.compile("=[.,!?\"':;~()]…")

sort_hf = sorted(high_frequency, key=lambda x:(-x[1], x[0]))[:1000]
word = []
for i in range(len(sort_hf)):
    print(re.sub(RE_FILTER, "", str(sort_hf[i][0])))
# Out:
# 블랙핑크
# YG
# 공개
# 신곡
# 양현석
# 데뷔
# 트레저
# 신인
# 고메즈
# 뮤비
# 포스터
# MV
# 돌파
# Cream'
# 컴백
# K팝
# 앨범
# '아이스크림'
# 혐의
# 1위
# 최초
# 대표
# 'BOY'
# 영상
# 세계
# 뮤직비디오
# 발매
# '사랑해'
# 그룹
# 매력
# That'
# 정규앨범
# 글로
# 예고
# 싱글
# 8월
# Cream’
# 5억뷰
# 걸그룹
# 안무
# 출연
# 'YG
# 10월
# BTS
# 기록
# 빅히트
# 선주문
# 출석
# 9월
# 상장
# 넷플릭스
# 솔로
# '뚜두뚜두'
# 아티스트
# 제니
# 차트
# 발표
# 확정
# 모두
# 도박
# 법원
# 인정
# 4위
# 데뷔곡
# 스포티파이
# 최고
# 기대
# 'K팝
# 신기록
# 신인'
# 아이돌
# 가수
# 다큐
# 스트리밍
# 음원
# SM
# 시장
# 정규
# 무대
# 제목
# 함께
# 근황
# 등극
# 위너
# "블랙핑크
# '설강화'
# 비디오
# 아바타
# "YG
# 3차례
# 달콤
# 전세계
# 참여
# IPO
# 시작
# 타이틀곡
# 해외
# 콘테스트
# ‘뚜두뚜두’
# 강렬
# 라이브
# 여성
# 주인공
# 7일
# 방예담
# 보석함
# 콘셉트
# 특별
# 3위
# 4년
# 사랑
# 주가
# '트레저'
# 12人
# 댓'
# 러브'
# 비주얼
# 캐릭터
# 조회수
# 가득
# 광복절
# 상승
# 에미넴
# 통화
# 6일
# That’
# 관심
# 도전
# 방탄소년단
# 보이그룹
# 열풍
# 팬들
# ‘사랑해’
# 기대감
# 모델
# 싱글앨범
# 올해
# 질문
# '솔로'
# 26시간
# 4400만명
# 묵묵부답
# 벌써
# 성장
# 안무영상
# 영화
# 준비
# 판매량
# 피처링
# 행보
# 활동
# 히로카즈
# 41시간
# 네이버
# 상큼
# 주목
# 9일
# 가온차트
# 소유
# 시런
# 싹쓸이
# 언택트
# 코로나19
# 탄생
# 한국
# 현장
# M/V
# 공모주
# 데뷔앨범
# 변신
# 선물
# 여부
# 역대급
# 예상
# 이하이
# 참석
# 코로나
# 팬사인회
# 표정
# "데뷔
# ‘K팝
# 가을
# 경신
# 달성
# 멤버
# 올라
# 음악방송
# 접수
# 폭풍성장
# 하루
# '글로
# 다른
# 생일
# 시간
# 시너지
# 시총
# 오픈
# 음원차트
# 퍼포먼스
# 13위
# YG엔터
# ‘설강화’
# 그래미
# 완주
# 입증
# 제작
# 질문에
# 청약
# 2020년
# 돌아
# 러블리
# 산다라박
# 씨엘
# 예승이
# 오늘(18일)
# 우리
# 직진
# 캐스팅
# 투자
# 하락
# '스타로드'
# 4주년
# CJCGV
# `아이스크림`
# 관광홍보대사
# 광고
# 김도훈
# 대회
# 러브’
# 로맨틱
# 이번
# 일본
# 취재진
# '7번방
# '보이'
# 1000억
# 5주년
# 7년
# AOMG
# 감독
# 관련주
# 논란
# 등장
# 모습
# 사진
# 상승세
# 소통
# 엔터株
# 여름
# 역사
# 영향력
# 완성
# 이상
# 인정…취재진
# 조언
# 지원
# 청량
# 최단기
# 활약
# '취재진
# FNC
# 거침
# 고개
# 공모
# 기간
# 내달
# 무드
# 박준형
# 소년미
# 실적
# 오나라
# 이후
# 주식
# 추억
# 팬덤
# "데뷔곡
# 10월2
# 2년
# “우리
# 검찰
# 고양이
# 광고계
# 목표
# 미소
# 시대
# 에너지
# 예능
# 완벽
# 음성
# 음악
# 이적
# 입성
# 주자
# 폭우
# 확인
# "함께
# 45일
# `뚜두뚜두`
# “블랙핑크
# 결혼
# 대형신인
# 반나절
# 부담
# 부부
# 생각
# 신인상
# 아동
# 악재
# 압도적
# 여고생
# 연예인
# 요구
# 의미
# 작사
# 제작진
# 차량
# 한류
# 효과
# "'아이스크림'
# "러블리
# '러블리
# '치명적
# 12명
# 12색
# 40시간
# 43일
# That`
# YG보석
# [연
# ‘트레저’
# 韓영화
# 감성
# 강승윤
# 기업가치
# 녹음
# 돌풍
# 발랄
# 방송
# 방시혁
# 보유
# 불안
# 빅히트엔터
# 사업
# 서프라이즈
# 스쿨룩
# 에미넘
# 응원
# 점령
# 한복
# 확정…
# "내
# "서
# "올
# 1년
# 2위
# JYP엔터테인먼트
# LP
# SM엔터‧YG엔터
# `사랑해`
# ‘블랙핑크’
# ‘솔로’
# 감사
# 강수지
# 개성
# 계속
# 계획
# 고메즈'
# 기소
# 긴장
# 난리
# 단순
# 대어
# 대전
# 데뷔음반
# 도박혐의
# 뛰어
# 무모
# 뿜뿜
# 서부지법
# 섹시
# 소년
# 스타일
# 스텝'
# 시원
# 신작
# 아이콘'
# 여자
# 여전
# 완주…독립유공자
# 위로
# 이미지
# 정조준
# 종목
# 증가
# 증여
# 지금
# 최대어
# 취소
# 칠링
# 탑승
# 테마주'
# 팬심
# 필요
# 女아티스트
# "BTS
# "나
# "너
# "우리
# "추
# '따
# 10분
# 10일
# 2시간
# 42일
# BTS·블랙핑크
# GD
# JYP엔터
# SM엔터테인먼트
# SNS
# [오늘
# `트레저`
# ‘7번방
# “함께
# 가수들
# 감탄
# 개인전
# 거품
# 계약
# 공개..수록곡
# 공개…'강렬
# 공개…달콤
# 공개…훈훈
# 공연
# 기업
# 네이버·카카오
# 노력
# 니쥬
# 대장주
# 대체
# 덕분
# 드러
# 루키
# 마음
# 막강
# 멤버들
# 문화
# 부활
# 비상
# 사로
# 색깔
# 생활
# 선배
# 선배들
# 선택
# 세계적
# 속도
# 송민호
# 슈퍼
# 스튜디오드래곤
# 에디션
# 외국
# 외면하고
# 유행
# 의상
# 재활치료비
# 제보
# 제안
# 종료
# 주장
# 증권
# 질주
# 첫걸음
# 컴백…"데뷔곡
# 콘서트
# 탈락
# 탈출
# 트렌드
# 팀워크
# 포착
# 필로폰
# 한달
# 후광
# "10월
# "12
# "9월
# "독립유공자
# "독보적
# "블링크
# "비
# "새
# "세상
# "셀레나고메즈
# "셀핑크
# "악뮤
# "에미넴
# "여름
# "인성
# "코로나19
# '공
# '글로벌돌'
# '달콤
# '마
# '반
# '수
# '짜릿
# 1시간
# 2.5단계
# 2명
# 3년
# 3천
# 40여
# 4위…에미넴
# BOY
# K-엔터
# K팝스타
# [팝's신곡]"너
# ‘도박’
# “역사
# 가능
# 강렬함
# 갤러리
# 경호
# 공개..매혹적
# 공개..상큼
# 공개..청량
# 공개…12
# 공개…청량
# 군법정
# 그것
# 그들
# 기대주
# 기억
# 낙수효과
# 넘었다…
# 눈치
# 다이너마이트
# 달콤·청량
# 대구
# 도전장
# 돌파...에미넴
# 떡잎
# 마운틴무브먼트
# 맞이
# 매일
# 메이크업
# 무엇
# 물려
# 뮤지컬
# 바람
# 바로
# 배출
# 벤처
# 변경
# 보석
# 보여
# 본격화
# 분신
# 불가
# 사이
# 선두
# 선배님들
# 선사
# 성숙
# 셀레나고메즈
# 소탈
# 수업
# 숙녀
# 술집
# 스튜디오
# 스트레
# 신선
# 씹어
# 아들
# 아스트
# 애틋
# 야구
# 양성
# 에드시런
# 엔터사업
# 예능감
# 예술가
# 오디션
# 완화
# 요동
# 유강남
# 음식
# 이것
# 이수
# 인정..취재진
# 인증
# 장현성
# 재확산
# 저희
# 접대
# 제자
# 조심
# 준규→요시
# 진격
# 청년
# 축구대회
# 컴백..
# 키워드
# 트와이스
# 파급력
# 팬데믹
# 평정
# 포브스
# 폭락
# 폭증
# 핑크머리
# 한국적
# 헤어
# 헤어스타일
# 혁신
# 현지
# 확산
# 확장
# 확정…12
# 회상
# 효과'
# 효자
# 훈풍
# 훈훈
# 흑자

# %%
#위의 결과를 바탕으로 사용자 사전 만들기
##사용자 사전 추가하기 & 사용자사전이 잘 되는지 테스트
##사용자 사전은 메모장 형태로 되어있다. 단어 tab 형태 로 쓰면 사용자 단어에 추가되는 방식

sent='생일 선물 여부 예상 특별 강렬 벌써 소유 역대급 오픈'
print(f'코모란 형태소 분리 : {komoran.nouns(sent)}')
##사용자 사전 추가하기 & 사용자사전이 잘 되는지 테스트
komoran_userdic=Komoran(userdic='./userdicCanSur.txt')
# 형태소분석 결과 보기 komoran.pos(sent)
print(f'사용자 정의사전 추가 : {komoran_userdic.nouns(sent)}')
# Out:
# 코모란 형태소 분리 : ['생일', '선물', '여부', '예상', '소유', '역대', '급', '오픈']
# 사용자 정의사전 추가 : ['생일', '선물', '여부', '예상', '특별', '강렬', '벌써', '소유', '역대급', '오픈']

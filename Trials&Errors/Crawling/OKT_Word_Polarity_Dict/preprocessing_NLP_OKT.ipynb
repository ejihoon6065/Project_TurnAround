# %% [markdown]
# # AutoML을 위한 데이터 전처리 정리
# #### 뉴스를 크롤링한 형식이 date, 요일, labeling이 빠져있는 형태임... 크롤링file  + 전처리file 할때  date, 요일, labeling 을 추가 해주어야 들어가는 데이터가 맞음.

# %%
import pandas as pd
from tqdm import tqdm
import re
from konlpy.tag import Okt
# from konlpy.tag import Mecab
# tokenizer는 okt, mecab 중 선택하여 사용 .

# %%
# 사용할 데이터 경로, 결과 데이터 경로, tokenizer와 stopwords 를 정의하고 사용하면 됩니다.

path = './뉴스데이터통합테스트.xlsx' # path는 원데이터 경로 / 데이터는 labeling, 요일, date 가 있는 크롤링 뉴스 데이터
result_path = './automl_data.csv' # 결과 데이터가 저장될 path

tokenizer = Okt()
#tokenizer = Mecab()
stopwords = ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
# 데이터를 정의하고 원데이터를 한열로 펴주는 역할. 
data = pd.read_excel(path)

titles = [] 
for i in range(len(data.loc[0])-3): # data.loc[0] data의 0행을 반환, 앞의 3개열을 제외하고 4번째 열부터 시작 하기위해 -3 를 해준다.
    titles.append(data.iloc[0,i+3]) # 1,2,3 열을 제외하고 4번째 열부터 시작. 데이터에 date, labeling 만 있다면 숫자는 2로 바꾼다.

data_temp = pd.DataFrame(titles, columns=['title']) # concat을 위해 첫번째 행을 가지고 data frame 1개를 만든다.
data_temp = data_temp.dropna()
data_temp['date'] = data.loc[0]['date']
data_temp['labeling'] = data.loc[0]['labeling']
data_temp

for j in range(len(data)-1) : # 첫번째 행을 제외한 나머지 행을 돌며 뉴스를 일렬로 
    titles = [] 
    for i in range(len(data.loc[j+1])-3): # 2번째 행, 4번째 열 부터 for 문을 돈다. 왜냐하면 첫번째 행은 data_temp로 만들었고, 1,2,3 열 에는 title 값이 들어가 있지 않기 때문이다.
        titles.append(data.iloc[j+1,i+3])

    data_temp2 = pd.DataFrame(titles, columns=['title']) 
    data_temp2 = data_temp2.dropna()
    data_temp2['date'] = data.loc[j+1]['date']
    data_temp2['labeling'] = data.loc[j+1]['labeling']
    
    
    data_temp = pd.concat([data_temp, data_temp2]) # 첫번째 행의 일렬 데이터와, 두번째행 부터 끝행 까지의 일렬 데이터를 합쳐준다. 
data_temp
# Out:
#                                    title        date labeling
# 0            "美 상·하원 외교위원장, 하원 군사위원장 교체"  2019.01.01        0
# 1     러시아 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조  2019.01.01        0
# 2           마크롱 "개혁 중단 없다"…노란 조끼 정면돌파 선언  2019.01.01        0
# 3   日이시바 전 간사장 "아베 추진 개헌, 국민적 논의 이르지 못해"  2019.01.01        0
# 4     쓰나미 이어 산사태까지…"인니, 30가구 파묻혀 15명 사망"  2019.01.01        0
# ..                                   ...         ...      ...
# 51           현대·기아차, 유럽서 한달에 전기차 1만대 팔았다  2020.09.30        1
# 52    부정행위로 입찰제한된 업체들, 5년간 1.6조 관급공사 따냈다  2020.09.30        1
# 53      "홈파티하고 넷플릭스 시청"…슬기로운 '추석 집콕' 방법은  2020.09.30        1
# 54          SKT, 추석연휴 택배기사 문자메시지 발송제한 푼다  2020.09.30        1
# 55       국제유가, 코로나19 재확산에 '털썩'…WTI 3.2%↓  2020.09.30        1
#
# [38251 rows x 3 columns]

# %%
#print('중복 제거전 :' ,len(data_temp['labeling'])) #확인용 코드 
#print('라벨이 0, 1인 뉴스 개수 :',len(data_temp[data_temp['labeling'] == 0]) + len(data_temp[data_temp['labeling'] == 1])) #확인용 코드 
label_zero = data_temp[data_temp['labeling'] == 0] # 라벨이 0인것만 가지고 온다. 
label_one = data_temp[data_temp['labeling'] == 1] # 라벨이 1인것만 가지고온다. 
data = pd.concat([label_zero, label_one])
#print('중복 제거후 :',len(data)) #결과 확인용 코드 

clean_title = []
for text in data['title']:
  temp = re.sub('[-=+,#/\?:^$.@*\"※~>`\'…》]', '', text) # 특수문자를 제거하여 clean title을 만들어준다.
  clean_title.append(temp)
data['clean_title'] = clean_title

data
# Out:
#                                    title        date labeling  \
# 0            "美 상·하원 외교위원장, 하원 군사위원장 교체"  2019.01.01        0
# 1     러시아 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조  2019.01.01        0
# 2           마크롱 "개혁 중단 없다"…노란 조끼 정면돌파 선언  2019.01.01        0
# 3   日이시바 전 간사장 "아베 추진 개헌, 국민적 논의 이르지 못해"  2019.01.01        0
# 4     쓰나미 이어 산사태까지…"인니, 30가구 파묻혀 15명 사망"  2019.01.01        0
# ..                                   ...         ...      ...
# 51           현대·기아차, 유럽서 한달에 전기차 1만대 팔았다  2020.09.30        1
# 52    부정행위로 입찰제한된 업체들, 5년간 1.6조 관급공사 따냈다  2020.09.30        1
# 53      "홈파티하고 넷플릭스 시청"…슬기로운 '추석 집콕' 방법은  2020.09.30        1
# 54          SKT, 추석연휴 택배기사 문자메시지 발송제한 푼다  2020.09.30        1
# 55       국제유가, 코로나19 재확산에 '털썩'…WTI 3.2%↓  2020.09.30        1
#
#                            clean_title
# 0             美 상·하원 외교위원장 하원 군사위원장 교체
# 1   러시아 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조
# 2            마크롱 개혁 중단 없다노란 조끼 정면돌파 선언
# 3    日이시바 전 간사장 아베 추진 개헌 국민적 논의 이르지 못해
# 4       쓰나미 이어 산사태까지인니 30가구 파묻혀 15명 사망
# ..                                 ...
# 51          현대·기아차 유럽서 한달에 전기차 1만대 팔았다
# 52    부정행위로 입찰제한된 업체들 5년간 16조 관급공사 따냈다
# 53         홈파티하고 넷플릭스 시청슬기로운 추석 집콕 방법은
# 54         SKT 추석연휴 택배기사 문자메시지 발송제한 푼다
# 55          국제유가 코로나19 재확산에 털썩WTI 32%↓
#
# [36729 rows x 4 columns]

# %%
clean_title = data['clean_title'].tolist() # clean title을 이용하여 words top 1000을 만들어 주기위해 리스트에 title을 넣어준다.
title_words_list = [] # 각 title을 쪼갠 words값들이 들어가는 list 를 만들어준다. [[title1 words], [title2 words], ....]

for i in tqdm(range(len(clean_title))):
  temp_X = []
  temp_X = tokenizer.morphs(clean_title[i], stem=True) # 토큰화
  temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
  temp_X = [word for word in temp_X if len(word) > 1]
  title_words_list.append(temp_X)
data['word'] = title_words_list
data
# Out:
# 100%|██████████| 36729/36729 [00:32<00:00, 1122.73it/s]
#                                    title        date labeling  \
# 0            "美 상·하원 외교위원장, 하원 군사위원장 교체"  2019.01.01        0
# 1     러시아 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조  2019.01.01        0
# 2           마크롱 "개혁 중단 없다"…노란 조끼 정면돌파 선언  2019.01.01        0
# 3   日이시바 전 간사장 "아베 추진 개헌, 국민적 논의 이르지 못해"  2019.01.01        0
# 4     쓰나미 이어 산사태까지…"인니, 30가구 파묻혀 15명 사망"  2019.01.01        0
# ..                                   ...         ...      ...
# 51           현대·기아차, 유럽서 한달에 전기차 1만대 팔았다  2020.09.30        1
# 52    부정행위로 입찰제한된 업체들, 5년간 1.6조 관급공사 따냈다  2020.09.30        1
# 53      "홈파티하고 넷플릭스 시청"…슬기로운 '추석 집콕' 방법은  2020.09.30        1
# 54          SKT, 추석연휴 택배기사 문자메시지 발송제한 푼다  2020.09.30        1
# 55       국제유가, 코로나19 재확산에 '털썩'…WTI 3.2%↓  2020.09.30        1
#
#                            clean_title  \
# 0             美 상·하원 외교위원장 하원 군사위원장 교체
# 1   러시아 우랄 아파트 붕괴 현장서 11개월 남자아이 기적적 구조
# 2            마크롱 개혁 중단 없다노란 조끼 정면돌파 선언
# 3    日이시바 전 간사장 아베 추진 개헌 국민적 논의 이르지 못해
# 4       쓰나미 이어 산사태까지인니 30가구 파묻혀 15명 사망
# ..                                 ...
# 51          현대·기아차 유럽서 한달에 전기차 1만대 팔았다
# 52    부정행위로 입찰제한된 업체들 5년간 16조 관급공사 따냈다
# 53         홈파티하고 넷플릭스 시청슬기로운 추석 집콕 방법은
# 54         SKT 추석연휴 택배기사 문자메시지 발송제한 푼다
# 55          국제유가 코로나19 재확산에 털썩WTI 32%↓
#
#                                               word
# 0                   [하원, 외교, 위원장, 하원, 군사, 위원장, 교체]
# 1   [러시아, 우랄, 아파트, 붕괴, 현장, 11, 개월, 남자, 아이, 기적, 구조]
# 2            [마크, 개혁, 중단, 없다, 노랗다, 조끼, 정면, 돌파, 선언]
# 3               [시바, 간사장, 아베, 추진, 개헌, 국민, 논의, 이르다]
# 4     [쓰나미, 이다, 산사태, 까지, 인니, 30, 가구, 파묻히다, 15, 사망]
# ..                                             ...
# 51                      [현대, 기아차, 유럽, 전기차, 1만, 파다]
# 52        [부정행위, 입찰, 제한, 되다, 업체, 5년, 16조, 공사, 따내다]
# 53           [홈파티, 하고, 넷플릭스, 시청, 슬기롭다, 추석, 집콕, 방법]
# 54        [SKT, 추석, 연휴, 택배, 기사, 문자메시지, 발송, 제한, 풀다]
# 55             [국제, 유가, 코로나, 19, 확산, 털썩, WTI, 32%]
#
# [36729 rows x 5 columns]

# %%
words_list = [y for x in title_words_list for y in x] # 2차원 list 를 1차원 list 로 만들어준다. 
words_cnt = []

i = 0
for words in tqdm(set(words_list)):
    words_cnt.append((words,words_list.count(words))) # 중복을 제거한 words_list안에서 words값을 count 한다. 
#    i += 1  #디버깅용
#    if i ==100 :break
#print(words_cnt)

words_cnt.sort(key = lambda x:x[1], reverse = True) #튜플의 1인덱스(count) 기반으로 sort함
words_top1000 = words_cnt[:1000] # count한 word의 1000위 까지를 가져온다. 
words_top = []
for word in tqdm(words_top1000):
    words_top.append(word[0])

print(len(words_top))
words_top
# Out:
# 100%|██████████| 25494/25494 [02:11<00:00, 194.45it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1001505.25it/s]
# 1000
# ['종합',
#  '코로나',
#  '기업',
#  '트럼프',
#  '한국',
#  '지원',
#  '삼성',
#  '금융',
#  '중국',
#  '정부',
#  '되다',
#  '19',
#  '만에',
#  'LG',
#  '판매',
#  '경제',
#  '수출',
#  '까지',
#  '은행',
#  '사업',
#  '투자',
#  '없다',
#  '현대',
#  '홍콩',
#  '시장',
#  '최대',
#  '회장',
#  '무역',
#  '영업',
#  '글로벌',
#  '산업',
#  '롯데',
#  '전자',
#  '협상',
#  '보다',
#  '금리',
#  '출시',
#  '대다',
#  '기술',
#  '세계',
#  '이란',
#  '현대차',
#  '미국',
#  '대출',
#  '밉다',
#  '올해',
#  '시위',
#  '그룹',
#  '받다',
#  '공장',
#  '작년',
#  '추가',
#  '부터',
#  'SK',
#  '일본',
#  '추진',
#  '개발',
#  '내년',
#  '있다',
#  '확대',
#  '규제',
#  '에도',
#  '성장',
#  '경영',
#  '감소',
#  '에서',
#  '생산',
#  '업계',
#  '서비스',
#  '오다',
#  '중단',
#  'amp',
#  '국내',
#  '위기',
#  '혁신',
#  '협력',
#  '크다',
#  '사망',
#  '시트',
#  '피해',
#  '대표',
#  '업체',
#  '최고',
#  '3년',
#  '주식',
#  '지역',
#  '카드',
#  '보험',
#  '브렉',
#  '매출',
#  'EU',
#  '돼다',
#  '총리',
#  '증가',
#  '온라인',
#  '합의',
#  '펀드',
#  '강화',
#  '베트남',
#  '늘다',
#  '이다',
#  '직원',
#  '해외',
#  '하락',
#  '전쟁',
#  '이익',
#  '우려',
#  '장관',
#  '건설',
#  '대통령',
#  '부산',
#  '나오다',
#  '제재',
#  '대비',
#  '대응',
#  '아베',
#  '관리',
#  '북미',
#  '검토',
#  '개최',
#  '경기',
#  '10',
#  '인도',
#  '개월',
#  '반도체',
#  'CEO',
#  '국제',
#  '전망',
#  '거래',
#  '만들다',
#  '않다',
#  '내다',
#  '논란',
#  '남다',
#  '상승',
#  '규모',
#  '1분',
#  '안전',
#  '확산',
#  '할인',
#  '유럽',
#  '마스크',
#  '상품',
#  '논의',
#  '가다',
#  '대상',
#  '사장',
#  '넘다',
#  '기부',
#  '주택',
#  '국고',
#  '서울',
#  '디지털',
#  '공개',
#  '전기차',
#  '브랜드',
#  '가능성',
#  '20',
#  '미래',
#  '위해',
#  '인수',
#  '서다',
#  '시대',
#  'AI',
#  '회담',
#  '김정은',
#  '원금',
#  '항공',
#  '2분',
#  '기아차',
#  '공사',
#  '사태',
#  '다시',
#  '취득',
#  '두산',
#  '자금',
#  '이상',
#  '하나',
#  '찾다',
#  '영향',
#  '나서다',
#  '센터',
#  '도입',
#  '공급',
#  '방문',
#  '中企',
#  '전환',
#  '갈등',
#  '백화점',
#  '대구',
#  '조사',
#  '스마트',
#  '포토',
#  '진출',
#  '중소기업',
#  '연장',
#  '고객',
#  '시진핑',
#  '비상',
#  '속보',
#  '수입',
#  'TV',
#  '문제',
#  '제품',
#  '행사',
#  '사회',
#  '주다',
#  '맞다',
#  '사우디',
#  '앞두다',
#  '재개',
#  '단독',
#  '자산',
#  '대만',
#  '사상',
#  '정책',
#  '연기',
#  '매각',
#  '가동',
#  '신청',
#  '가격',
#  'GS',
#  '돌파',
#  '고용',
#  '노조',
#  '관세',
#  '화웨이',
#  '포스코',
#  '시작',
#  '정상회담',
#  '급증',
#  '키우다',
#  '운영',
#  '우리',
#  '자동차',
#  '공인',
#  '1천',
#  '여성',
#  '한화',
#  '내달',
#  '늘리다',
#  '호텔',
#  '연속',
#  '톡톡',
#  '회의',
#  '러시아',
#  '시설',
#  '스타트업',
#  '금감원',
#  '대한항공',
#  '아시아나',
#  '농협',
#  '현장',
#  '결정',
#  '적자',
#  '선정',
#  '창업',
#  '2020',
#  '부품',
#  '공격',
#  '금지',
#  '한진',
#  '실적',
#  '전략',
#  '들다',
#  '가전',
#  '추다',
#  '재난',
#  '언론',
#  '협약',
#  '본격',
#  '시스템',
#  '이후',
#  '일자리',
#  '국민',
#  '이재용',
#  '참여',
#  '긴급',
#  '반대',
#  '관광',
#  '대책',
#  '국가',
#  '아니다',
#  '광주',
#  '가능',
#  '르노',
#  '오르다',
#  '수주',
#  '발전',
#  '개선',
#  '역대',
#  '새롭다',
#  '영국',
#  '소상',
#  '인하',
#  '장기',
#  '배터리',
#  '에너지',
#  '일제',
#  '10년',
#  'KB',
#  '조성',
#  '손실',
#  '배달',
#  '테러',
#  '호주',
#  '결제',
#  '발표',
#  '터키',
#  '효과',
#  '존슨',
#  '인기',
#  '부동산',
#  '최저',
#  '1년',
#  '타다',
#  '교육',
#  '이번',
#  '필요',
#  'vs',
#  '코리아',
#  '인천',
#  '3분',
#  '화학',
#  '생명',
#  '바꾸다',
#  '경찰',
#  '식품',
#  '압박',
#  '공동',
#  '테크',
#  '증시',
#  '도전',
#  'CJ',
#  '회복',
#  '대화',
#  '외교',
#  '계약',
#  '최소',
#  '정상',
#  '경고',
#  '중공업',
#  '환경',
#  '기대',
#  '커지다',
#  '소비',
#  '해결',
#  '구매',
#  '안정',
#  '경쟁',
#  '제주',
#  '사고',
#  '주년',
#  '뱅크',
#  '자율',
#  '소재',
#  '요청',
#  '유지',
#  '정보',
#  '당국',
#  '제한',
#  '하루',
#  '소비자',
#  '회사',
#  '막다',
#  '울산',
#  '친환경',
#  '상반기',
#  '급감',
#  '사용',
#  '계획',
#  '구축',
#  '2년',
#  '요구',
#  '패션',
#  '완화',
#  '증권',
#  '1만',
#  '준비',
#  '관련',
#  '라임',
#  '비대',
#  '이마트',
#  '여행',
#  '면세점',
#  '달러',
#  '쇼핑',
#  '수도',
#  '신종',
#  '유통',
#  '알다',
#  '확인',
#  '셧다운',
#  '체포',
#  '배송',
#  '열다',
#  '대신',
#  '업무',
#  '매장',
#  '소득',
#  '부상',
#  '잡다',
#  '계속',
#  '절반',
#  '투입',
#  '살리다',
#  '취소',
#  '마트',
#  '5년',
#  '베다',
#  '신세계',
#  '여명',
#  '연합',
#  '전달',
#  '위원장',
#  '공략',
#  '아파트',
#  '지급',
#  '좋다',
#  '1조',
#  '중앙회',
#  '비판',
#  '전문가',
#  '가구',
#  '방역',
#  '카카오',
#  '선물',
#  '대선',
#  '소송',
#  '인증',
#  '위협',
#  '원전',
#  '극복',
#  '미사일',
#  '커피',
#  '에게',
#  '광고',
#  '열사',
#  '100',
#  '의회',
#  '활용',
#  '특별',
#  '제안',
#  '공항',
#  '뜨다',
#  '돼지',
#  '11',
#  '대형',
#  '사다',
#  '충격',
#  '손잡다',
#  '인상',
#  '관계',
#  '상생',
#  '점검',
#  '평가',
#  '매체',
#  '집중',
#  '플랫폼',
#  '전국',
#  '브라질',
#  '후보',
#  '최악',
#  '지속',
#  '재정',
#  '나선',
#  '독일',
#  '여파',
#  '30',
#  '속도',
#  '전기',
#  '설립',
#  '출범',
#  '태양광',
#  '협의',
#  '환율',
#  '줄이다',
#  '목표',
#  '가입',
#  '열병',
#  '분쟁',
#  '최초',
#  '마련',
#  '단체',
#  '가장',
#  '주장',
#  '확보',
#  '세금',
#  '기업은행',
#  '필리핀',
#  '위반',
#  '동기',
#  '신용',
#  '프랑스',
#  '만나다',
#  '가스',
#  '부회장',
#  '쌍용차',
#  '뉴딜',
#  '불법',
#  '폼페이',
#  '세대',
#  '하고',
#  '담판',
#  '건강',
#  '채권',
#  '예산',
#  '풀다',
#  '위험',
#  '북한',
#  '부담',
#  '성공',
#  '추석',
#  '육성',
#  '이유',
#  '책임',
#  '마케팅',
#  '지지',
#  '일부',
#  '주요',
#  '아마존',
#  '모두',
#  '대사',
#  '국산',
#  '의혹',
#  '난민',
#  '보증',
#  '경북',
#  '모바일',
#  '유엔',
#  'GM',
#  '청년',
#  '조치',
#  '석유',
#  '차량',
#  '대리',
#  '유가',
#  '10%',
#  '주목',
#  '제공',
#  'CES',
#  '외국인',
#  '장비',
#  '송환',
#  '잇다',
#  '편의점',
#  '25',
#  '높이다',
#  '발생',
#  '태국',
#  '특허',
#  '3월',
#  '인사',
#  '발행',
#  '화재',
#  '운항',
#  '30%',
#  '법원',
#  '인력',
#  '물류',
#  '아이',
#  '도시',
#  '시행',
#  '가치',
#  '조기',
#  '모든',
#  '추락',
#  '포럼',
#  '대규모',
#  '택시',
#  '전용',
#  '공식',
#  '배상',
#  '법인',
#  '4월',
#  'WTO',
#  '문화',
#  '놓다',
#  '촉구',
#  '명품',
#  '5월',
#  '협회',
#  '하노이',
#  '아시아',
#  '내일',
#  '화장품',
#  '폭발',
#  '지키다',
#  '스타',
#  '개인',
#  '인도네시아',
#  '달라',
#  '9월',
#  '바이오',
#  '인니',
#  '축소',
#  '민주',
#  '줄다',
#  '농가',
#  '수소',
#  '반발',
#  '7월',
#  '20%',
#  '적용',
#  '부진',
#  '외무',
#  '정지',
#  '하나은행',
#  '승인',
#  '없이',
#  '페이',
#  '쿠팡',
#  '생활',
#  '대기업',
#  '비핵화',
#  '단지',
#  '원유',
#  '몰다',
#  '사과',
#  '신규',
#  '겨냥',
#  '주주',
#  '12',
#  '수상',
#  '선거',
#  '자다',
#  '맞춤',
#  '기회',
#  'DLF',
#  '신차',
#  '노사',
#  '혜택',
#  '백악관',
#  '영상',
#  '선언',
#  '교체',
#  '우리금융',
#  '직접',
#  '매입',
#  '8월',
#  '예상',
#  '심사',
#  '안보',
#  '공단',
#  '충돌',
#  '지금',
#  '파다',
#  '시민',
#  '벤츠',
#  '드론',
#  '농산물',
#  '주민',
#  '경남',
#  '6월',
#  '혐의',
#  '보호',
#  '먹다',
#  '거부',
#  '모델',
#  '한일',
#  '통과',
#  '자회사',
#  '악화',
#  '열리다',
#  '50',
#  '로봇',
#  '프리미엄',
#  '철회',
#  '의원',
#  '신임',
#  '중동',
#  '이용',
#  '태풍',
#  '노딜',
#  '공정위',
#  '대전',
#  '핵심',
#  '기금',
#  '마크',
#  '홈쇼핑',
#  '4년',
#  '통합',
#  'SUV',
#  '3천',
#  '한국인',
#  '제조업',
#  '상장',
#  '반등',
#  '적극',
#  '설치',
#  '공모',
#  '금융위',
#  '제도',
#  '캐나다',
#  '강조',
#  '보도',
#  '추경',
#  '대로',
#  '집행',
#  '조정',
#  '캠페인',
#  '등장',
#  '폐쇄',
#  '신한은행',
#  '마켓',
#  '40',
#  '침체',
#  '인재',
#  '타이어',
#  '2천',
#  '출발',
#  '함께',
#  '성과',
#  '이스라엘',
#  '경쟁력',
#  '15',
#  '우리은행',
#  '임금',
#  '조선',
#  '개국',
#  '어렵다',
#  '데이터',
#  '주의',
#  '선임',
#  '제주항공',
#  '변신',
#  '정치',
#  '발언',
#  '모집',
#  '구조',
#  '하이닉스',
#  '애플',
#  '지정',
#  '타격',
#  '결국',
#  '국세청',
#  '멕시코',
#  '보장',
#  '낮추다',
#  '올리다',
#  '아프리카',
#  '연말',
#  '수준',
#  '버스',
#  '확정',
#  'LNG',
#  '1%',
#  '쓰다',
#  '수수료',
#  '전문',
#  '보복',
#  '키로',
#  '와인',
#  '선택',
#  '수요',
#  '채용',
#  '베이징',
#  '노선',
#  '차관',
#  '통해',
#  '품질',
#  '총재',
#  '상황',
#  '검사',
#  '푸틴',
#  '방위',
#  '검찰',
#  '확진',
#  '워치',
#  '국방',
#  '현금',
#  '정의선',
#  '차단',
#  '변경',
#  '개혁',
#  '아세안',
#  '많다',
#  '주행',
#  '실업',
#  '강원',
#  '1억',
#  '유치',
#  '지난해',
#  '국민은행',
#  '기준금리',
#  '희망',
#  '허용',
#  '70',
#  '주도',
#  '노력',
#  '임원',
#  '신고',
#  '비용',
#  '과장',
#  '기관',
#  '조원태',
#  '종료',
#  '거리',
#  '해양',
#  '기준',
#  '전시',
#  '통화',
#  '역사',
#  '멈추다',
#  '단계',
#  '오픈',
#  '공포',
#  '그린',
#  '포기',
#  '사랑',
#  '평화',
#  '몰리다',
#  '국회',
#  '근로자',
#  '높다',
#  '부문',
#  '첨단',
#  '민간',
#  '처럼',
#  '시리아',
#  '관광객',
#  '비난',
#  '의료',
#  '챙기다',
#  '연금',
#  'IT',
#  '볼턴',
#  '주문',
#  '이자',
#  '쇼크',
#  '연구',
#  '돌입',
#  '재단',
#  '네이버',
#  '경기도',
#  '닛산',
#  '훈련',
#  '조직',
#  '푸드',
#  '처음',
#  '착수',
#  '이슈',
#  '주가',
#  '가족',
#  '쓸다',
#  '합병',
#  '방안',
#  '메이',
#  '예방',
#  '인근',
#  '흑자',
#  '공유',
#  '폭탄',
#  '80',
#  '디스플레이',
#  '활성화',
#  '한미',
#  '예고',
#  '뛰다',
#  '이르다',
#  '가능하다',
#  '보잉',
#  '긴장',
#  '달성',
#  '하반기',
#  '어치',
#  '공공',
#  '디자인',
#  '이노',
#  '분야',
#  '사실',
#  '취업',
#  '개다',
#  '변화',
#  '불안',
#  '체결',
#  '의무',
#  '기능',
#  '진행',
#  '10월',
#  '투표',
#  '급여',
#  '사모펀드',
#  '금리인하',
#  '이전',
#  '뉴스',
#  '복합',
#  'BMW',
#  '번째',
#  '체제',
#  '대폭',
#  '2월',
#  '승부',
#  '완성',
#  '개시',
#  '가속',
#  '설명',
#  '빠지다',
#  'LS',
#  '60',
#  '선박',
#  '출신',
#  '16',
#  '붕괴',
#  '트럭',
#  '싱가포르',
#  '다음',
#  '충전',
#  '하향',
#  '나눔',
#  '모빌리티',
#  '발견',
#  '발사',
#  '부정',
#  '소녀',
#  '2조',
#  '수익',
#  '서도',
#  '시스',
#  '같다',
#  '운동',
#  '운용',
#  '유력',
#  '잇따르다',
#  '우한',
#  '소식',
#  '치료',
#  '총격',
#  '차세대',
#  '적발',
#  'HDC',
#  '케이',
#  '급등',
#  '제외',
#  '시험',
#  '투자자',
#  '아프간',
#  '본부',
#  '50%',
#  '전면',
#  '100%',
#  '돕다',
#  '상담',
#  '지주',
#  '이탈리아',
#  '동맹',
#  '헝가리',
#  '도약',
#  '감사',
#  '제로',
#  '테슬라',
#  '동결',
#  '바뀌다',
#  '과징금',
#  '총선',
#  '토스',
#  '상의',
#  '유동성',
#  '공무원',
#  'KT',
#  '한반도',
#  '수용',
#  '나라',
#  '전력',
#  '파키스탄',
#  '활동',
#  '한도',
#  '중소',
#  '워싱턴',
#  '대회',
#  '여부',
#  '포인트',
#  '동참',
#  '김동욱',
#  '남부',
#  '농업',
#  '보험료',
#  '중심',
#  '끝나다',
#  '실패',
#  '해상',
#  '아동',
#  '스마트폰',
#  '사람',
#  '연구원',
#  '기념',
#  '유조선',
#  '오늘',
#  '맥스',
#  '공간',
#  '뚫다',
#  '시간',
#  '우수',
#  '신형',
#  '물가',
#  '정상화',
#  '진단',
#  '택배',
#  '인정',
#  '노트르담']

# %%
date_label = data[['date', 'labeling']].drop_duplicates('date') # data의 date를 기준으로 가장 첫번째 값을 남기고 중복 데이터는 모두 제거한다.  
automl_data = pd.DataFrame(columns = words_top) # words_top 1000으로 column을 지정.
automl_data['date'] = date_label['date']
automl_data['labeling'] = date_label['labeling']
automl_data.sort_values(by=['date'], inplace =True)
automl_data.reset_index(inplace=True) # index를 리셋 
del automl_data['index'] # 옛날인덱스를 제거
automl_data
# Out:
#       종합  코로나   기업  트럼프   한국   지원   삼성   금융   중국   정부  ...   우수   신형   물가  \
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 186  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 187  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 427  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 428  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 429  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 430  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 431  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#      정상화   진단   택배   인정 노트르담        date labeling
# 0    NaN  NaN  NaN  NaN  NaN  2019.01.01        0
# 1    NaN  NaN  NaN  NaN  NaN  2019.01.02        0
# 186  NaN  NaN  NaN  NaN  NaN  2019.01.03        1
# 187  NaN  NaN  NaN  NaN  NaN  2019.01.06        1
# 2    NaN  NaN  NaN  NaN  NaN  2019.01.07        0
# ..   ...  ...  ...  ...  ...         ...      ...
# 427  NaN  NaN  NaN  NaN  NaN  2020.09.24        1
# 428  NaN  NaN  NaN  NaN  NaN  2020.09.27        1
# 429  NaN  NaN  NaN  NaN  NaN  2020.09.28        1
# 430  NaN  NaN  NaN  NaN  NaN  2020.09.29        1
# 431  NaN  NaN  NaN  NaN  NaN  2020.09.30        1
#
# [432 rows x 1002 columns]

# %%
automl_data_columns = [automl_data_column for automl_data_column in automl_data.columns] 
automl_data_columns.pop() # labeling 을 빼줌.
automl_data_columns.pop() # date 를 빼줌.
automl_data_columns
# Out:
# ['종합',
#  '코로나',
#  '기업',
#  '트럼프',
#  '한국',
#  '지원',
#  '삼성',
#  '금융',
#  '중국',
#  '정부',
#  '되다',
#  '19',
#  '만에',
#  'LG',
#  '판매',
#  '경제',
#  '수출',
#  '까지',
#  '은행',
#  '사업',
#  '투자',
#  '없다',
#  '현대',
#  '홍콩',
#  '시장',
#  '최대',
#  '회장',
#  '무역',
#  '영업',
#  '글로벌',
#  '산업',
#  '롯데',
#  '전자',
#  '협상',
#  '보다',
#  '금리',
#  '출시',
#  '대다',
#  '기술',
#  '세계',
#  '이란',
#  '현대차',
#  '미국',
#  '대출',
#  '밉다',
#  '올해',
#  '시위',
#  '그룹',
#  '받다',
#  '공장',
#  '작년',
#  '추가',
#  '부터',
#  'SK',
#  '일본',
#  '추진',
#  '개발',
#  '내년',
#  '있다',
#  '확대',
#  '규제',
#  '에도',
#  '성장',
#  '경영',
#  '감소',
#  '에서',
#  '생산',
#  '업계',
#  '서비스',
#  '오다',
#  '중단',
#  'amp',
#  '국내',
#  '위기',
#  '혁신',
#  '협력',
#  '크다',
#  '사망',
#  '시트',
#  '피해',
#  '대표',
#  '업체',
#  '최고',
#  '3년',
#  '주식',
#  '지역',
#  '카드',
#  '보험',
#  '브렉',
#  '매출',
#  'EU',
#  '돼다',
#  '총리',
#  '증가',
#  '온라인',
#  '합의',
#  '펀드',
#  '강화',
#  '베트남',
#  '늘다',
#  '이다',
#  '직원',
#  '해외',
#  '하락',
#  '전쟁',
#  '이익',
#  '우려',
#  '장관',
#  '건설',
#  '대통령',
#  '부산',
#  '나오다',
#  '제재',
#  '대비',
#  '대응',
#  '아베',
#  '관리',
#  '북미',
#  '검토',
#  '개최',
#  '경기',
#  '10',
#  '인도',
#  '개월',
#  '반도체',
#  'CEO',
#  '국제',
#  '전망',
#  '거래',
#  '만들다',
#  '않다',
#  '내다',
#  '논란',
#  '남다',
#  '상승',
#  '규모',
#  '1분',
#  '안전',
#  '확산',
#  '할인',
#  '유럽',
#  '마스크',
#  '상품',
#  '논의',
#  '가다',
#  '대상',
#  '사장',
#  '넘다',
#  '기부',
#  '주택',
#  '국고',
#  '서울',
#  '디지털',
#  '공개',
#  '전기차',
#  '브랜드',
#  '가능성',
#  '20',
#  '미래',
#  '위해',
#  '인수',
#  '서다',
#  '시대',
#  'AI',
#  '회담',
#  '김정은',
#  '원금',
#  '항공',
#  '2분',
#  '기아차',
#  '공사',
#  '사태',
#  '다시',
#  '취득',
#  '두산',
#  '자금',
#  '이상',
#  '하나',
#  '찾다',
#  '영향',
#  '나서다',
#  '센터',
#  '도입',
#  '공급',
#  '방문',
#  '中企',
#  '전환',
#  '갈등',
#  '백화점',
#  '대구',
#  '조사',
#  '스마트',
#  '포토',
#  '진출',
#  '중소기업',
#  '연장',
#  '고객',
#  '시진핑',
#  '비상',
#  '속보',
#  '수입',
#  'TV',
#  '문제',
#  '제품',
#  '행사',
#  '사회',
#  '주다',
#  '맞다',
#  '사우디',
#  '앞두다',
#  '재개',
#  '단독',
#  '자산',
#  '대만',
#  '사상',
#  '정책',
#  '연기',
#  '매각',
#  '가동',
#  '신청',
#  '가격',
#  'GS',
#  '돌파',
#  '고용',
#  '노조',
#  '관세',
#  '화웨이',
#  '포스코',
#  '시작',
#  '정상회담',
#  '급증',
#  '키우다',
#  '운영',
#  '우리',
#  '자동차',
#  '공인',
#  '1천',
#  '여성',
#  '한화',
#  '내달',
#  '늘리다',
#  '호텔',
#  '연속',
#  '톡톡',
#  '회의',
#  '러시아',
#  '시설',
#  '스타트업',
#  '금감원',
#  '대한항공',
#  '아시아나',
#  '농협',
#  '현장',
#  '결정',
#  '적자',
#  '선정',
#  '창업',
#  '2020',
#  '부품',
#  '공격',
#  '금지',
#  '한진',
#  '실적',
#  '전략',
#  '들다',
#  '가전',
#  '추다',
#  '재난',
#  '언론',
#  '협약',
#  '본격',
#  '시스템',
#  '이후',
#  '일자리',
#  '국민',
#  '이재용',
#  '참여',
#  '긴급',
#  '반대',
#  '관광',
#  '대책',
#  '국가',
#  '아니다',
#  '광주',
#  '가능',
#  '르노',
#  '오르다',
#  '수주',
#  '발전',
#  '개선',
#  '역대',
#  '새롭다',
#  '영국',
#  '소상',
#  '인하',
#  '장기',
#  '배터리',
#  '에너지',
#  '일제',
#  '10년',
#  'KB',
#  '조성',
#  '손실',
#  '배달',
#  '테러',
#  '호주',
#  '결제',
#  '발표',
#  '터키',
#  '효과',
#  '존슨',
#  '인기',
#  '부동산',
#  '최저',
#  '1년',
#  '타다',
#  '교육',
#  '이번',
#  '필요',
#  'vs',
#  '코리아',
#  '인천',
#  '3분',
#  '화학',
#  '생명',
#  '바꾸다',
#  '경찰',
#  '식품',
#  '압박',
#  '공동',
#  '테크',
#  '증시',
#  '도전',
#  'CJ',
#  '회복',
#  '대화',
#  '외교',
#  '계약',
#  '최소',
#  '정상',
#  '경고',
#  '중공업',
#  '환경',
#  '기대',
#  '커지다',
#  '소비',
#  '해결',
#  '구매',
#  '안정',
#  '경쟁',
#  '제주',
#  '사고',
#  '주년',
#  '뱅크',
#  '자율',
#  '소재',
#  '요청',
#  '유지',
#  '정보',
#  '당국',
#  '제한',
#  '하루',
#  '소비자',
#  '회사',
#  '막다',
#  '울산',
#  '친환경',
#  '상반기',
#  '급감',
#  '사용',
#  '계획',
#  '구축',
#  '2년',
#  '요구',
#  '패션',
#  '완화',
#  '증권',
#  '1만',
#  '준비',
#  '관련',
#  '라임',
#  '비대',
#  '이마트',
#  '여행',
#  '면세점',
#  '달러',
#  '쇼핑',
#  '수도',
#  '신종',
#  '유통',
#  '알다',
#  '확인',
#  '셧다운',
#  '체포',
#  '배송',
#  '열다',
#  '대신',
#  '업무',
#  '매장',
#  '소득',
#  '부상',
#  '잡다',
#  '계속',
#  '절반',
#  '투입',
#  '살리다',
#  '취소',
#  '마트',
#  '5년',
#  '베다',
#  '신세계',
#  '여명',
#  '연합',
#  '전달',
#  '위원장',
#  '공략',
#  '아파트',
#  '지급',
#  '좋다',
#  '1조',
#  '중앙회',
#  '비판',
#  '전문가',
#  '가구',
#  '방역',
#  '카카오',
#  '선물',
#  '대선',
#  '소송',
#  '인증',
#  '위협',
#  '원전',
#  '극복',
#  '미사일',
#  '커피',
#  '에게',
#  '광고',
#  '열사',
#  '100',
#  '의회',
#  '활용',
#  '특별',
#  '제안',
#  '공항',
#  '뜨다',
#  '돼지',
#  '11',
#  '대형',
#  '사다',
#  '충격',
#  '손잡다',
#  '인상',
#  '관계',
#  '상생',
#  '점검',
#  '평가',
#  '매체',
#  '집중',
#  '플랫폼',
#  '전국',
#  '브라질',
#  '후보',
#  '최악',
#  '지속',
#  '재정',
#  '나선',
#  '독일',
#  '여파',
#  '30',
#  '속도',
#  '전기',
#  '설립',
#  '출범',
#  '태양광',
#  '협의',
#  '환율',
#  '줄이다',
#  '목표',
#  '가입',
#  '열병',
#  '분쟁',
#  '최초',
#  '마련',
#  '단체',
#  '가장',
#  '주장',
#  '확보',
#  '세금',
#  '기업은행',
#  '필리핀',
#  '위반',
#  '동기',
#  '신용',
#  '프랑스',
#  '만나다',
#  '가스',
#  '부회장',
#  '쌍용차',
#  '뉴딜',
#  '불법',
#  '폼페이',
#  '세대',
#  '하고',
#  '담판',
#  '건강',
#  '채권',
#  '예산',
#  '풀다',
#  '위험',
#  '북한',
#  '부담',
#  '성공',
#  '추석',
#  '육성',
#  '이유',
#  '책임',
#  '마케팅',
#  '지지',
#  '일부',
#  '주요',
#  '아마존',
#  '모두',
#  '대사',
#  '국산',
#  '의혹',
#  '난민',
#  '보증',
#  '경북',
#  '모바일',
#  '유엔',
#  'GM',
#  '청년',
#  '조치',
#  '석유',
#  '차량',
#  '대리',
#  '유가',
#  '10%',
#  '주목',
#  '제공',
#  'CES',
#  '외국인',
#  '장비',
#  '송환',
#  '잇다',
#  '편의점',
#  '25',
#  '높이다',
#  '발생',
#  '태국',
#  '특허',
#  '3월',
#  '인사',
#  '발행',
#  '화재',
#  '운항',
#  '30%',
#  '법원',
#  '인력',
#  '물류',
#  '아이',
#  '도시',
#  '시행',
#  '가치',
#  '조기',
#  '모든',
#  '추락',
#  '포럼',
#  '대규모',
#  '택시',
#  '전용',
#  '공식',
#  '배상',
#  '법인',
#  '4월',
#  'WTO',
#  '문화',
#  '놓다',
#  '촉구',
#  '명품',
#  '5월',
#  '협회',
#  '하노이',
#  '아시아',
#  '내일',
#  '화장품',
#  '폭발',
#  '지키다',
#  '스타',
#  '개인',
#  '인도네시아',
#  '달라',
#  '9월',
#  '바이오',
#  '인니',
#  '축소',
#  '민주',
#  '줄다',
#  '농가',
#  '수소',
#  '반발',
#  '7월',
#  '20%',
#  '적용',
#  '부진',
#  '외무',
#  '정지',
#  '하나은행',
#  '승인',
#  '없이',
#  '페이',
#  '쿠팡',
#  '생활',
#  '대기업',
#  '비핵화',
#  '단지',
#  '원유',
#  '몰다',
#  '사과',
#  '신규',
#  '겨냥',
#  '주주',
#  '12',
#  '수상',
#  '선거',
#  '자다',
#  '맞춤',
#  '기회',
#  'DLF',
#  '신차',
#  '노사',
#  '혜택',
#  '백악관',
#  '영상',
#  '선언',
#  '교체',
#  '우리금융',
#  '직접',
#  '매입',
#  '8월',
#  '예상',
#  '심사',
#  '안보',
#  '공단',
#  '충돌',
#  '지금',
#  '파다',
#  '시민',
#  '벤츠',
#  '드론',
#  '농산물',
#  '주민',
#  '경남',
#  '6월',
#  '혐의',
#  '보호',
#  '먹다',
#  '거부',
#  '모델',
#  '한일',
#  '통과',
#  '자회사',
#  '악화',
#  '열리다',
#  '50',
#  '로봇',
#  '프리미엄',
#  '철회',
#  '의원',
#  '신임',
#  '중동',
#  '이용',
#  '태풍',
#  '노딜',
#  '공정위',
#  '대전',
#  '핵심',
#  '기금',
#  '마크',
#  '홈쇼핑',
#  '4년',
#  '통합',
#  'SUV',
#  '3천',
#  '한국인',
#  '제조업',
#  '상장',
#  '반등',
#  '적극',
#  '설치',
#  '공모',
#  '금융위',
#  '제도',
#  '캐나다',
#  '강조',
#  '보도',
#  '추경',
#  '대로',
#  '집행',
#  '조정',
#  '캠페인',
#  '등장',
#  '폐쇄',
#  '신한은행',
#  '마켓',
#  '40',
#  '침체',
#  '인재',
#  '타이어',
#  '2천',
#  '출발',
#  '함께',
#  '성과',
#  '이스라엘',
#  '경쟁력',
#  '15',
#  '우리은행',
#  '임금',
#  '조선',
#  '개국',
#  '어렵다',
#  '데이터',
#  '주의',
#  '선임',
#  '제주항공',
#  '변신',
#  '정치',
#  '발언',
#  '모집',
#  '구조',
#  '하이닉스',
#  '애플',
#  '지정',
#  '타격',
#  '결국',
#  '국세청',
#  '멕시코',
#  '보장',
#  '낮추다',
#  '올리다',
#  '아프리카',
#  '연말',
#  '수준',
#  '버스',
#  '확정',
#  'LNG',
#  '1%',
#  '쓰다',
#  '수수료',
#  '전문',
#  '보복',
#  '키로',
#  '와인',
#  '선택',
#  '수요',
#  '채용',
#  '베이징',
#  '노선',
#  '차관',
#  '통해',
#  '품질',
#  '총재',
#  '상황',
#  '검사',
#  '푸틴',
#  '방위',
#  '검찰',
#  '확진',
#  '워치',
#  '국방',
#  '현금',
#  '정의선',
#  '차단',
#  '변경',
#  '개혁',
#  '아세안',
#  '많다',
#  '주행',
#  '실업',
#  '강원',
#  '1억',
#  '유치',
#  '지난해',
#  '국민은행',
#  '기준금리',
#  '희망',
#  '허용',
#  '70',
#  '주도',
#  '노력',
#  '임원',
#  '신고',
#  '비용',
#  '과장',
#  '기관',
#  '조원태',
#  '종료',
#  '거리',
#  '해양',
#  '기준',
#  '전시',
#  '통화',
#  '역사',
#  '멈추다',
#  '단계',
#  '오픈',
#  '공포',
#  '그린',
#  '포기',
#  '사랑',
#  '평화',
#  '몰리다',
#  '국회',
#  '근로자',
#  '높다',
#  '부문',
#  '첨단',
#  '민간',
#  '처럼',
#  '시리아',
#  '관광객',
#  '비난',
#  '의료',
#  '챙기다',
#  '연금',
#  'IT',
#  '볼턴',
#  '주문',
#  '이자',
#  '쇼크',
#  '연구',
#  '돌입',
#  '재단',
#  '네이버',
#  '경기도',
#  '닛산',
#  '훈련',
#  '조직',
#  '푸드',
#  '처음',
#  '착수',
#  '이슈',
#  '주가',
#  '가족',
#  '쓸다',
#  '합병',
#  '방안',
#  '메이',
#  '예방',
#  '인근',
#  '흑자',
#  '공유',
#  '폭탄',
#  '80',
#  '디스플레이',
#  '활성화',
#  '한미',
#  '예고',
#  '뛰다',
#  '이르다',
#  '가능하다',
#  '보잉',
#  '긴장',
#  '달성',
#  '하반기',
#  '어치',
#  '공공',
#  '디자인',
#  '이노',
#  '분야',
#  '사실',
#  '취업',
#  '개다',
#  '변화',
#  '불안',
#  '체결',
#  '의무',
#  '기능',
#  '진행',
#  '10월',
#  '투표',
#  '급여',
#  '사모펀드',
#  '금리인하',
#  '이전',
#  '뉴스',
#  '복합',
#  'BMW',
#  '번째',
#  '체제',
#  '대폭',
#  '2월',
#  '승부',
#  '완성',
#  '개시',
#  '가속',
#  '설명',
#  '빠지다',
#  'LS',
#  '60',
#  '선박',
#  '출신',
#  '16',
#  '붕괴',
#  '트럭',
#  '싱가포르',
#  '다음',
#  '충전',
#  '하향',
#  '나눔',
#  '모빌리티',
#  '발견',
#  '발사',
#  '부정',
#  '소녀',
#  '2조',
#  '수익',
#  '서도',
#  '시스',
#  '같다',
#  '운동',
#  '운용',
#  '유력',
#  '잇따르다',
#  '우한',
#  '소식',
#  '치료',
#  '총격',
#  '차세대',
#  '적발',
#  'HDC',
#  '케이',
#  '급등',
#  '제외',
#  '시험',
#  '투자자',
#  '아프간',
#  '본부',
#  '50%',
#  '전면',
#  '100%',
#  '돕다',
#  '상담',
#  '지주',
#  '이탈리아',
#  '동맹',
#  '헝가리',
#  '도약',
#  '감사',
#  '제로',
#  '테슬라',
#  '동결',
#  '바뀌다',
#  '과징금',
#  '총선',
#  '토스',
#  '상의',
#  '유동성',
#  '공무원',
#  'KT',
#  '한반도',
#  '수용',
#  '나라',
#  '전력',
#  '파키스탄',
#  '활동',
#  '한도',
#  '중소',
#  '워싱턴',
#  '대회',
#  '여부',
#  '포인트',
#  '동참',
#  '김동욱',
#  '남부',
#  '농업',
#  '보험료',
#  '중심',
#  '끝나다',
#  '실패',
#  '해상',
#  '아동',
#  '스마트폰',
#  '사람',
#  '연구원',
#  '기념',
#  '유조선',
#  '오늘',
#  '맥스',
#  '공간',
#  '뚫다',
#  '시간',
#  '우수',
#  '신형',
#  '물가',
#  '정상화',
#  '진단',
#  '택배',
#  '인정',
#  '노트르담']

# %%
date_list = automl_data['date'].tolist()

for i in tqdm(range(len(date_list))):

    news = data[data['date'] == date_list[i]]['word'].tolist() # automl data의 date에 맞는 data의 word만 가져와 list형태로 
    X_train = [m for j in news for m in j] # [['title1_word1','title1_word2',... ], ['title2_word1','title2_word2'... ]...] 의 형태를 ['word1', 'word2'...] 로 바꾸어준다.

    for automl_data_column in automl_data_columns:
        automl_data.loc[[i],[automl_data_column]] = X_train.count(automl_data_column) # automl_data 빈칸에
# Out:
# 100%|██████████| 432/432 [02:38<00:00,  2.73it/s]

# %%
automl_data.to_csv(result_path, encoding='utf-8-sig')

# %%
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers, losses, metrics
from tensorflow.keras import preprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os
import re

from konlpy.tag import Okt

import matplotlib.pyplot as plt

# %%
file_name = 'Crawling_D램04'

base_dir = 'C:/Users/user/Desktop/'  # 경로

excel_file = file_name + '.xlsx'      # 파일명

# %%
excel_dir = os.path.join(base_dir, excel_file)

excel_dir
# Out:
# 'C:/Users/user/Desktop/Crawling_D램04.xlsx'

# %%
df=pd.read_excel(excel_dir, header=0)
df
# Out:
#      Unnamed: 0         date  \
# 0             0  2020.07.19.
# 1             1  2020.07.19.
# 2             2  2020.07.19.
# 3             3  2020.07.19.
# 4             4  2020.07.19.
# ..          ...          ...
# 413         413  2020.07.24.
# 414         414  2020.07.24.
# 415         415  2020.07.25.
# 416         416  2020.07.25.
# 417         417  2020.07.25.
#
#                                                  title       source  \
# 0    [K-Biz 리뷰] 아모레퍼시픽 '마몽드' 美 아마존 입점·'차세대 D램' DDR5...          더구루
# 1                  정의선-이재용 오른쪽에 박정국…현대모비스, 'K미래차' 중심으로          뉴스핌
# 2                  SK하이닉스, 완연한 회복세…엇갈리는 하반기 전망 V자? W자?         이투데이
# 3                        삼성전자, '비메모리 1위' 목표로 신입사원까지 투입         매일일보
# 4                                           새로운 것 DDR5         한국경제
# ..                                                 ...          ...
# 413                  인텔 7나노 칩 출시 연기에···삼성 메모리 '뜻밖의 악재'         서울경제
# 414                삼성전자·SK하이닉스 실적 효자 'D램'…하반기도 힘 발휘할까?       아시아투데이
# 415             흔들리는 '인텔제국'.. 한숨짓는 '삼성전자' [양철민의 인더스트리]   서울경제언론사 선정
# 416     삼성전자를 'NN'이라고 부르며 저주하는 중국 업체 [황정수의 반도체 이슈 짚...   한국경제언론사 선정
# 417                   반도체업계, 코로나 폭풍에도 '굳건'…D램 수요 실적 견인  아시아경제언론사 선정
#
#                                               contents  \
# 0    삼성전자·SK하이닉스 = '차세대 D램' DDR5 규격 발표…메모리 시장 판 커진다...
# 1    박정국 현대모비스 사장이 정의선 현대자동차그룹 수석부회장과 이재용 삼성전자 부회장의...
# 2    DDR5 D램 (SK하이닉스) 삼성전자가 2분기 어닝 서프라이즈를 기록하면서 SK하...
# 3    사진=삼성전자 제공 삼성전자는 D램·낸드 등 메모리 반도체에선 세계 시장의 40% ...
# 4    D램의 새 규격인 DDR5 표준안이 지난 15일 발표됐다. DDR5는 현 세대인 D...
# ..                                                 ...
# 413  무엇보다 인텔이 글로벌 서버·PC용 중앙처리장치(CPU) 시장에서 압도적 점유율을 ...
# 414  삼성전자와 SK하이닉스가 2분기 서버용 D램 수요 급등으로 어닝서프라이즈를 기록해,...
# 415  당연히 D램이나 낸드플래시도 추가 구매해 탑재한다. D램·낸드플래시 업계 1위인 삼...
# 416  삼성전자 입장에서, 가전시장에서 경쟁하는 LG전자처럼 SK하이닉스는 글로벌 D램 시...
# 417  삼성전자와 SK하이닉스가 올 2분기 신종 코로나바이러스감염증(코로나19) 사태에도 ...
#
#                                                   link
# 0    https://www.theguru.co.kr/news/article.html?no...
# 1      http://www.newspim.com/news/view/20200717000299
# 2           https://www.etoday.co.kr/news/view/1919069
# 3    http://www.m-i.kr/news/articleView.html?idxno=...
# 4    https://www.hankyung.com/finance/article/20200...
# ..                                                 ...
# 413        https://www.sedaily.com/NewsView/1Z5FG8W0NM
# 414  https://www.asiatoday.co.kr/view.php?key=20200...
# 415        https://www.sedaily.com/NewsView/1Z5FV41T5U
# 416  https://www.hankyung.com/economy/article/20200...
# 417  https://view.asiae.co.kr/article/2020072511323...
#
# [418 rows x 6 columns]

# %%
x=df['title']
x
# Out:
# 0      [K-Biz 리뷰] 아모레퍼시픽 '마몽드' 美 아마존 입점·'차세대 D램' DDR5...
# 1                    정의선-이재용 오른쪽에 박정국…현대모비스, 'K미래차' 중심으로
# 2                    SK하이닉스, 완연한 회복세…엇갈리는 하반기 전망 V자? W자?
# 3                          삼성전자, '비메모리 1위' 목표로 신입사원까지 투입
# 4                                             새로운 것 DDR5
#                              ...
# 413                    인텔 7나노 칩 출시 연기에···삼성 메모리 '뜻밖의 악재'
# 414                  삼성전자·SK하이닉스 실적 효자 'D램'…하반기도 힘 발휘할까?
# 415               흔들리는 '인텔제국'.. 한숨짓는 '삼성전자' [양철민의 인더스트리]
# 416       삼성전자를 'NN'이라고 부르며 저주하는 중국 업체 [황정수의 반도체 이슈 짚...
# 417                     반도체업계, 코로나 폭풍에도 '굳건'…D램 수요 실적 견인
# Name: title, Length: 418, dtype: object

# %%
# 태그 단어
PAD = "<PADDING>"   # 패딩
OOV = "<OOV>"       # 없는 단어(Out of Vocabulary)

# 태그 인덱스
PAD_INDEX = 0
OOV_INDEX = 1

# 데이터 타입
#ENCODER_INPUT  = 0
#DECODER_INPUT  = 1
#DECODER_TARGET = 2

# 한 문장에서 단어 시퀀스의 최대 개수 
max_sequences = 100
max_words=100
# 임베딩 벡터 차원
embedding_dim = 100

# LSTM 히든레이어 차원
lstm_hidden_dim = 128

# 정규 표현식 필터
RE_FILTER = re.compile("=[.,!?\"':;~()]")

# %%
# 형태소분석 함수
def pos_tag(sentences):
    
    # KoNLPy 형태소분석기 설정
    tagger = Okt()
    
    # 문장 품사 변수 초기화
    sentences_pos = []
    
    # 모든 문장 반복
    for sentence in sentences:
        # 특수기호 제거
        sentence = re.sub(RE_FILTER, "", str(sentence))
        
        # 배열인 형태소분석의 출력을 띄어쓰기로 구분하여 붙임
        sentence = " ".join(tagger.morphs(sentence))
        sentences_pos.append(sentence)
        
    return sentences_pos

# %% [markdown]
# # 기사 제목 마이닝

# %%
x_new = pos_tag(x)

sentences = []
sentences.extend(x_new)


words = []

# 단어들의 배열 생성
for sentence in sentences:
    for word in sentence.split():
        words.append(word)

# 길이가 0인 단어는 삭제
words = [word for word in words if len(word) > 0]

# 중복된 단어 삭제
words = list(set(words))

# 제일 앞에 태그 단어 삽입
words[:0] = [PAD, OOV]

#print(words) # words : test,trainset의 모든 단어들이 들어간 list

# 단어와 인덱스의 단어사전 생성
word_to_index = {word: index for index, word in enumerate(words)}  # 단어 : 인덱스값 (인코딩시 사용)  # 단어 : 인덱스값
index_to_word = {index: word for index, word in enumerate(words)}  # 인덱스값 : 단어 (디코딩시 사용)  # 인덱스값 : 단어

x_new
# Out:
# ["[ K - Biz 리뷰 ] 아모레퍼시픽 ' 마몽드 ' 美 아마존 입점 ·' 차세대 D 램 ' DDR 5 규격 ...",
#  "정의선 - 이재용 오른쪽 에 박정국 … 현대 모비스 , ' K 미래 차 ' 중심 으로",
#  'SK 하이닉스 , 완연 한 회복 세 … 엇갈리는 하반기 전망 V 자 ? W 자 ?',
#  "삼성 전자 , ' 비메 모리 1 위 ' 목표 로 신입사원 까지 투입",
#  '새로운 것 DDR 5',
#  'SK 하이닉스 , 반도체 수요 회복 땐 9만원 돌파 등',
#  '심텍 , 패키지 판 호황 … 2022년 까지 외형 성장 기대',
#  '고선지 ( 上 ) | 모험 을 두려워하지 않는 리더십',
#  "SK 하이닉스 2분 기 매출 30% , 영업 이익 190% 증가 예상 ... 내년 전망 ' 쾌청 '",
#  'SK 하이닉스 시장 의 기 대치 하향 조정 을 기다리며',
#  '심텍 , 패키지 기 판 과 그래픽 D 램 으로 실적 개선 - 하나',
#  '[ 이 지숙 의 재계 OLD & NEW ] M & A 후 진짜 주인 만나 성장한 기업 들',
#  "[ 여의도 클라 쓰 ] DDR 5 전환 모멘텀 ' 엑시콘 ' ㆍ 서버 용 메모리 모듈 매출 증가 ...",
#  "SK 하이닉스 , 2분 기 영업 익 2조원 탈환 기 대감 ' 쑥 '",
#  "SK 하이닉스 , 2분 기 실적 호조 전망 에도 ' 비실 비실 '",
#  '차세대 반도체 시장 열 린다 , DDR 5 상용 화 성큼',
#  '[ 집중 ! 시세 포착 !] 패키지 기 판 대 장주 , 차세대 D 램 라인업 본격 화 수혜 ! < 심텍 ...',
#  'SK 하이닉스 , 차세대 D 램 , 128 단 낸드 플래시 로 승부 수',
#  "SK 하이닉스 , 반도체 EUV 공정 ' 가속 페달 ' 밟는다",
#  '반도체 " 상반기 는 선방 했는데 "… 하반기 는 ?',
#  "SK 하이닉스 , 2분 기 영업 익 2조 돌파 하나 ?... 내년 전망 도 ' 쾌청 '",
#  "[ 日 수출 규제 1년 - 상 ] ' 소 부장 독립 ' 필요성 일 깨워 준 아베",
#  "생산자 물가 5 개월 만에 ' 반등 '… 휘발 윳값 32.4% ↑",
#  '생산자 물가 , 유가 반등 으로 전월 대비 상승 ... 석유 · 화학 제품 ↑',
#  '" 테슬라 게 섰거라 "··· 이재용 · 정의선 힘 모은다 [ 양 철민 의 인더스 트리 ]',
#  '국제 유가 상승 여파 … 6월 생산자 물가 0.5% 상승',
#  '삼성 전자 선방 했는데 … SK 하이닉스 2분 기 실적 향방 은',
#  '국제 유가 상승 에 6월 생산자 물가 0.5% 상승',
#  "생산자 물가 5 개월 만에 ' 반등 '… 국제 유가 올라",
#  '생산자 물가 , 국제 유가 상승 으로 5 개월 만에 상승 전환',
#  '유가 상승 에 생산자 물가 5 개월 만에 반등',
#  '[ 이지 보고서 ] 6월 생산자 물가 , 5 개월 만에 ↑ … 국제 유가 상승 영향',
#  '6월 생산자 물가 전월 비 0.5% ↑ … 5 개월 만에 반등',
#  '6월 생산자 물가 0.5% 상승 ... 5 개월 내림세 뒤 반등',
#  "3분 기 D 램 전망 ' 살얼음 판 '… ' 코로나 재 유행 - 무역 분쟁 여파 ' 우려",
#  "세계 반도체 기업 ' 언택트 효과 ' 로 날았다 … 2분 기 줄줄이 호실 적",
#  "세계 반도체 기업 들 ' 코로나 사태 ' 에 2분 기 줄줄이 호실 적",
#  '미래 차 협력 , 배터리 넘어 전장 부품 확대 전망',
#  "세계 반도체 기업 ' 언택트 효과 ' 로 날았다 … 2분 기 줄줄이 호실 적",
#  'SK 하이닉스 , 2분 기 영업 익 2조원 돌파 할까',
#  '6월 생산자 물가 0.5% 올라 ... 5 개월 만에 반등',
#  '" 테슬라 추월 한다 "···\' 미래 모빌리티 \' 동행 하는 이재용 · 정의선',
#  '“ K 칩 시대 열겠다 ” 삼성 전자 · SK 하이닉스 , 반도체 생태계 확장 에 적극 지원',
#  '코로나 에 ‘ 기침 한번 안 한 ’ 반도체 … 기업 들 , 2분 기 잇 달 아 호실 적',
#  '" 메모리 수요 증가 덕 "… SK 하이닉스 , 2분 기 깜짝 실적 기대',
#  '반도체 \' 언택트 \' 날개 달 고 2분 기 好 실적 …" 3분 기 긍정 적 "',
#  '한국 도 미국 도 언택트 株 가 실적 이끈다',
#  'SK 하이닉스 , 2 Q 어닝 서프라이즈 기록 할까 ?… 차세대 D 램 개발 전망 ‘ 밝음 ’',
#  "세계 반도체 기업 ' 언택트 효과 ' 로 날았다 … 2분 기 줄줄이 호실 적",
#  "국제 유가 오르며 생산자 물가 5 개월 만에 ' 반등 '… 전월 대비 0.5% 상승",
#  '“ 현대차 가 반도체 에 왜 관심 ” … 정의선 - 이재용 2 차 회동 에 김기남 동행',
#  '생산자 물가 다섯 달 만에 오름세 전환',
#  '글로벌 반도체 ‘ 언택트 효과 ’ 에 2분 기 훨훨',
#  "[ 특별 기획 ] 경기 남부 ' 통합 국제공항 '… 그 必要性 을 살피 다",
#  '[ 단독 ] 애플 · SK 하이닉스 ‘ 빅딜 ’… 친환경 반도체 이례 적 동맹',
#  '[ 단독 ] ‘ 추격자 ’ SK 하이닉스 , 애플 업고 ‘ 반도체 왕좌 ’ 노리 나',
#  '[ 단독 ] SK 하이닉스 · 애플 ‘ 친환경 반도체 생산 ’ 그린 동맹',
#  '[ 단독 ] ‘ 재생에너지 ’ 수용 결단 … 아이폰 12 업고 ‘ 반도체 왕좌 ’ 노려',
#  '[[ 종목 PICK !] SK 하이닉스 , 개미 매수 행렬 … 지금 이 기회 ?',
#  "' 반도체 의 힘 '… SK 하이닉스 2 Q 영업 이익 2조 회복할까",
#  '" 내년 반도체 장비 투자 액 약 700억 달러 전망 … 역대 최 대치 "',
#  "반도체 장비 시장 성장 ... 투자 규모 내년 700만달러 로 ' 역대 최대 '",
#  '" 전 세계 반도체 장비 투자 액 632억달러 … 전 년 比 6% 증가 "',
#  '올해 반도체 장비 투자 액 6% 상승 … 중국 이 최대 투자 국가',
#  'SEMI " 전세계 반도체 장비 투자 액 올해 632억 에서 내년 700억달러 전망 "',
#  'SK 하이닉스 , 애플 신재생에너지 생산 국내 협력 사 등록',
#  'SEMI " 내년 반도체 장비 투자 700억달러 ... 최 대치 경신 "',
#  '韓 반도체 장비 투자 세계 3 위 … 중국 · 대만 에 밀려',
#  '반도체 시장 살아난다 … 내년 장비 투자 역대 최대 전망',
#  '생산자 물가 5 개월 만에 반등 … 휘발 윳값 오르고 돼지고기 등 하락',
#  "올 반도체 장비 투자 6% 증가 … 내년 엔 ' 역대 최대 '",
#  "SK 하이닉스 , 애플 과 탄소 순 배출 량 ' 0 ' 을 위 하여",
#  "SK 하이닉스 도 ' 깜짝 실적 ' 내 나 … 2분 기 영업 익 2조원 대 넘 본다",
#  "내년 반도체 장비 투자 액 700억달러 ' 역대 최대 '",
#  '올해 글로벌 반도체 장비 투자 액 전 년 比 7% 증가 ..." 내년 최대 "',
#  '반도체 장비 시장 ‘ 전성 시대 ’… 2021년 역대 최 대치 전망',
#  '2020년 韓 반도체 장비 투자 123억 불 세계 3 위 전망',
#  '올해 전세계 반도체 장비 투자 규모 , 전 년비 6% 증가 전망',
#  "국내 배터리 3 사 … 2분 기 실적 도 ' 희비 ' 전망",
#  "애플 , 2030년 까지 탄소 배출 량 ' 제로 ' 비전 발표",
#  'ACM , 18 챔버 싱글 웨이퍼 세 정 장비 출시',
#  'ACM 리서치 , 첨단 메모 리용 18 챔버 싱글 웨이퍼 세 정 장비 발표',
#  "SK 하이닉스 도 ' 깜짝 실적 ' 내 나 … 2분 기 영업 익 2조원 대 넘 본다 ( 종합 )",
#  'ACM 리서치 , 18 챔버 싱글 웨이퍼 세 정장 비 ( Ultra C VI ) 공개 … 3분 기 공급 시작',
#  "내년 반도체 장비 투자 역대 최대 전망 … 기 대감 ' 업 '",
#  '올해 반도체 장비 투자 액 632억달러 … 내년 700억달러 로 역대 최대 전망',
#  '하이닉스 팔고 삼성 전자 1조 쓸어 담은 외국인',
#  '[ 단독 ] 반도체 선방 ‘ 경계 론 ’, 진교 영 삼성 사장 “ 사력 을 다 하고 있다 ”',
#  '[ 시론 ] 나 는 이렇게 삼성 반도체 진출 과 외환위기 극복 을 도 왔다',
#  'ACM 리서치 , 첨단 메모리 디바이스 용 웨이퍼 세 정 장비 출시',
#  '평택 삼성 반도체 공장 " 하루 25만 t 물 어떻게 끌어오나 "… 평택시 공업 용수 확 ...',
#  'SK 하이닉스 2분 기 2조원 대 영업 이익 넘 본다',
#  'SK 하이닉스 , 오늘 실적 발표 … ‘ 깜짝 실적 ’ 기대 솔솔',
#  '[ 인터뷰 ] 양 향 자 " 정권 재창 출 위해 선 경제 전문가 필요 … 나 의 소명 "',
#  'SK 하이닉스 , 하반기 숨 고르기 들어서나',
#  "SK 하이닉스 , 2분 기 영업 이익 2조원 육박 ' 어닝 서프라이즈 '( 종합 )",
#  '코로나 이겨 낸 반도체 ... SK 하이닉스 도 어닝 서프라이즈',
#  'SK 하이닉스 , 2분 기 실적 매출 액 8조 6065억 · 영업 이익 1조 9467억 ... 전 분기 대비 ...',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 205.3% 껑충 ( 상보 )',
#  'SK 하이닉스 , 2분 기 영업 익 1.9조 .. 전분 기비 143% ↑',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 .. 영업 이익 률 23%',
#  'SK 하이닉스 2분 기 영업 익 1조 9500억원 … 작년 비 205.3% ↑ ( 상보 )',
#  'SK 하이닉스 , 언택트 수요 덕 에 2분 기 영업 익 2조원 육박',
#  'SK 하이닉스 2분 기 매출 8조 6,065억원 , 영업 이익 1조 9,467억원',
#  'SK 하이닉스 , 2분 기 영업 익 205.3% 껑충 … 코로나 19 에도 ‘ 깜짝 실적 ’ ( 종합 )',
#  '[ 속보 ] SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 전 년비 205.3% ↑',
#  'SK 하이닉스 반도체 회복 신호탄 쐈다 … 2분 기 영업 이익 2조 육박',
#  'SK 하이닉스 , 코로나 19 불구 ‘ 깜짝 실적 ’… 영업 익 , 전 년비 205.3% ↑ ( 상보 )',
#  "SK 하이닉스 2분 기 영업 이익 1조 9467억원 …' 작년 대비 205.3% 증가 '",
#  "SK 하이닉스 , 2 Q 영업 이익 ' 2조 ' 육박 … 코로나 에도 웃었다 ( 종합 )",
#  'SK 하이닉스 , 2분 기 깜짝 실적 … 서버 수요 강세 에 영업 익 2조원 육박',
#  'SK 하이닉스 2분 기 영업 익 1조 9천 467억 · 205.3% ↑ … 예상 상회 ( 종합 )',
#  "SK 하이닉스 2분 기 ' 어닝 서프라이즈 '… 영업 이익 1조 9천억원 ( 종합 )",
#  '[ 상보 ] SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 … 어닝 서프라이즈',
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 … 작년 대비 205.3% 늘어',
#  'SK 하이닉스 , 2 Q 어닝 서프라이즈 … 영업 익 2조 육박',
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억 .. 전 년 比 205% ↑',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 전 년비 205% ↑',
#  'SK 하이닉스 , 2분 기 영업 익 1.94조 … 전 년 比 205.3% ↑',
#  'SK 하이닉스 , 2분 기 영업 이익 1.9조원 ... 전 년 比 205% ↑',
#  '[ 상보 ] SK 하이닉스 2 Q 영업 익 2조원 육박 … " 시장 컨센서스 상회 "',
#  'SK 하이닉스 , 2 Q 영업 익 1조 9467억 , 전 년비 205% ↑ … ‘ 어닝 서프라이즈 ’',
#  'SK 하이닉스 , 2분 기 영업 이익 2조 육박 ‘ 어닝 서프라이즈 ’',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '... 영업 익 전 년 比 205% ↑",
#  'SK 하이닉스 2분 기 영업 익 1조 9467억원 … 전 년비 205.3% ↑',
#  'SK 하이닉스 , 2분 기 영업 익 2조원 육박 ··· 전 년 比 205% ↑',
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 … 전 년 比 205% ↑',
#  "' 어닝 서프라이즈 ' SK 하이닉스 2분 기 영업 이익 1조 9천억원",
#  'SK 하이닉스 , 2분 기 전 망치 웃돈 약 2조원 영업 익 … 하반기 보수 적 기조 유지',
#  'SK 하이닉스 , 2분 기 어닝 서프라이즈 … 코로나 19 에도 ‘ 활짝 ’',
#  "SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 …' 언택트 ' 서버 수요 강세 지속",
#  '[ 종합 ] SK 하이닉스 , 2분 기 영업 익 1조 9467억원 ... ‘ 반도체 의 힘 ’',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 전 년 比 205% ↑',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 전 분기 比 143% 증가',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 … 전 년 比 205.3% ↑',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '… 영업 익 1조 9천억원",
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 … 전 년 比 205.3% ↑',
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억 … 전 년비 205% ↑',
#  "' 코로나 특수 ' SK 하이닉스 , 2분 기 깜짝 실적 … 영업 익 1.9조 [ 종합 ]",
#  '[ 종합 ] \' 깜짝 실적 \' SK 하이닉스 영업 익 2 兆 육박 … " 하반기 불확실 성 여전 "',
#  'SK 하이닉스 " 2 Q D 램 출 하량 전 분기 대비 2% 증가 "',
#  '[ 속보 ] SK 하이닉스 2분 기 ‘ 어닝 서프라이즈 ’… 2조원 육박',
#  'SK 하이닉스 , 코로나 위기 에도 어닝 서프라이즈 기록 ( 2 보 )',
#  'SK 하이닉스 " 2 Q D 램 ASP 15% ↑ "',
#  "[ 종합 ] SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '… 영업 익 1조 9467억",
#  'SK 하이닉스 , 2분 기 영업 익 1.9조 … 전 년 대비 205% ↑',
#  'SK 하이닉스 , 2분 기 깜짝 실적 에도 강보 합세',
#  "SK 하이닉스 , 2분 기 영업 이익 2조 육박 ...' 깜짝 실적 '",
#  '[ SK 하이닉스 컨콜 ] 2분 기 매출 비중 , D 램 73% 낸드 24%',
#  'SK 하이닉스 , 코로나 뚫고 영업 이익 3 배 로 늘렸다',
#  '[ 컨콜 ] SK 하이닉스 " D 램 직전 분기 대비 출 하량 2% · 평균 판매 가격 15% 상승 "',
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 … 전 년 比 205.3% ↑',
#  "SK 하이닉스 , 코로나 發 재택근무 확산 에 2 Q 실적 ' 껑충 '( 종합 )",
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억원 ... 전 년 比 205% ↑',
#  '[ 컨콜 ] SK 하이닉스 , “ D 램 평균 판매 가격 상승 에 서버 와 그래픽 판매 확대 ”',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억원 … 서버 메모리 수요 강세',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억원 … 전 년 比 205% ↑',
#  "SK 하이닉스 , 코로나 속 ' 깜짝 실적 '… 2 Q 영업 익 1.9조 달성",
#  '[ 컨콜 ] SK 하이닉스 " 하반기 메모리 반도체 업체 들 공급 확대 어려워 "',
#  'SK 하이닉스 , 2분 기 영업 익 1.9조 … 전 년 대비 205% ↑',
#  'SK 하이닉스 " 3 Q 낸드 한 자릿수 후반 출 하량 증가 예상 "',
#  'SK 하이닉스 , ` 언택트 ` 단비 로 2분 기 어닝 서프라이즈 … 영업 익 2조원 육박',
#  'SK 하이닉스 , 5분 기 만에 분기 영업 이익 1조원 달성',
#  '[ 컨콜 ] SK 하이닉스 “ 연간 출 하량 코로나 9 이전 제시 했던 수치 에 부합 전망 ”',
#  "[ SK 하이닉스 컨콜 ] 3분 기 출 하량 , 전 기비 D 램 ' 유사 ' 낸드 ' 한 자릿수 후반 ' 증 ...",
#  '[ 컨콜 ] SK 하이닉스 " D 램 직전 분기 대비 출 하량 2% · 평균 판매 가격 15% 상승 "',
#  '[ IR ] SK 하이닉스 " 3분 기 D 램 출 하량 전 분기 와 비슷할 듯 "',
#  '[ 종합 ] SK 하이닉스 , ‘ V 자 ’ 반등 성공 … 수익 성 중심 으로 하반기 돌파',
#  'SK 하이닉스 " 연간 D 램 출 하량 10% 중후 반 증가 예상 "',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 전 분기 대비 143% ↑',
#  '[ 컨콜 ] SK 하이닉스 " 3분 기 D 램 출 하량 2분 기와 비슷 ... 낸드 한 자릿수 후반 증 ...',
#  '[ 컨콜 ] SK 하이닉스 " 상반기 D 램 · 낸드 재고 정상 수준 도달 "',
#  'SK 하이닉스 도 2분 기 ‘ 깜짝 실적 ’… 코로나 속 메모리 저력 입증 ( 종합 )',
#  "SK 하이닉스 2분 기 ' 깜짝 실적 '… 영업 익 2조 육박 ( 종합 )",
#  "' 깜짝 실적 ' SK 하이닉스 , 2분 기 영업 이익 1.9조 … 전 년 比 205% ↑",
#  '[ 컨콜 ] SK 하이닉스 " 3분 기 그래픽 D 램 중 HBM · GDDR 6 비중 60% 돌파 "',
#  '“ 2분 기 D 램 ASP 15% ↑ .. 낸드 도 8% ↑” - SK 하이닉스 컨콜',
#  'SK 하이닉스 , 올 2분 기 영업 이익 1조 9467억 ( 종합 )',
#  '" 코로나 비대 면 특수 톡톡 "… SK 하이닉스 , 영업 익 2조원 육박',
#  'SK 하이닉스 , 반도체 로 2분 기 영업 이익 1.9조 … 전 년 동기 대비 205.3% 증가',
#  'SK 하이닉스 " 올해 D 램 출하 전 년 比 10% 중후 반 , 낸드 40% 이상 증가 전망 "',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '… 영업 이익 1조 9467억원",
#  'SK 하이닉스 , 2 Q 영업 익 1조 9467억원 … 전 년 比 205% ↑',
#  '“ 하반기 말 D 램 · 낸드 재고 수준 건전해질 것 ” - SK 하이닉스 컨콜',
#  'SK 하이닉스 , 2분 기 영업 익 1.9조원 \' 깜짝 실적 \'…" 서버 수요 강세 "',
#  '[ 컨콜 ] SK 하이닉스 " 상반기 고객 사 재고 높았다 ... 연말 정상화 예상 "',
#  '“ 연간 출 하량 , D 램 10% 중후 반 · 낸드 40% 이상 증가 ” - SK 하이닉스 컨콜',
#  '[ 컨콜 ] SK 하이닉스 " 고객 사 D 램 · 낸드 재고 하반기 에 건전한 수준 예상 "',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '… 영업 이익 1조 9467억",
#  "' 코로나 특수 ' SK 하이닉스 , 2 Q 어닝 서프라이즈 ··· 영업 익 1.9조",
#  '[ SK 하이닉스 컨콜 ] 5 G 폰 , D 램 · 낸드 모두 긍정 적 … 중 가폰 수요 견인',
#  '[ 컨콜 ] SK 하이닉스 " 연간 출 하량 D 램 전 년 比 10% 중후 반 , 낸드 40% 중후 반 증 ...',
#  '[ IR ] SK 하이닉스 " 올 하반기 D 램 가격 저 점 으로 인식 "',
#  '[ 컨콜 ] SK 하이닉스 " 하반기 D 램 가격 하락 불가피 ... 짧은 조정 그칠듯 "',
#  '“ 하반기 D 램 가격 하락 불가피 ” - SK 하이닉스 컨콜',
#  '[ 컨콜 ] SK 하이닉스 " 연간 출 하량 , D 램 10% 중후 반 · 낸드 40% 이상 증가 전망 "',
#  "SK 하이닉스 , ' 코로나 특수 ' 에 2분 기 어닝 서프라이즈 … 영업 익 1.9조",
#  '[ 컨콜 ] SK 하이닉스 “ D 램 가격 조정 불가피 … 중 장기 성장 은 견조 ”',
#  '[ 컨콜 ] SK 하이닉스 " D 램 가격 , 조정 기간 짧을 것 ... 올 하반기 가 저 점 "',
#  'SK 하이닉스 2분 기 ‘ 깜짝 실적 ’ 영업 익 1조 9000억원 … 전 년 比 205% 증가',
#  'SK 하이닉스 , 반도체 수요 증가 로 2분 기 영업 이익 2조 육박',
#  '[ 컨콜 ] SK 하이닉스 " 하반기 D 램 ASP 조정 불가피 … 저 점 찍 을 듯 "',
#  '[ 컨콜 ] SK 하이닉스 " 3 Q 그래픽 D 램 , HBM · GDDR 6 비중 60% 돌파 전망 "',
#  '[ 컨콜 ] SK 하이닉스 “ D 램 가격 , 올해 하반기 저 점 으로 인식 ”',
#  '[ SK 하이닉스 컨콜 ] 하반기 D 램 가격 하락 불가피 … 내년 반등',
#  'SK 하이닉스 또 웃었다 .. 코로나 에도 2분 기 어닝 서프라이즈',
#  '[ 컨콜 ] SK 하이닉스 " 하반기 D 램 가격 하락 , 짧은 조정 기간 거칠 듯 "',
#  'SK 하이닉스 " D 램 가격 , 하반기 짧은 조정 거칠 것 "',
#  'SK 하이닉스 " 하반기 신규 콘솔 이 GDDR , 낸드 수요 견인 할 것 "',
#  '[ 컨콜 ] SK 하이닉스 “ D 램 하반기 도 재고 수준 변화 없어 ”',
#  'SK 하이닉스 2분 기 영업 이익 2조 육박 깜짝 실적 , 서버 메모리 호조',
#  '[ 컨콜 ] SK 하이닉스 " 5 G 스마트폰 확산 , 메모리 사업 에 긍정 적 인 요인 "',
#  '[ 컨콜 ] SK 하이닉스 " D 램 가격 , 하반기 가 저 점 "',
#  'SK 하이닉스 , 2 Q 영업 익 1조 9천억원 … 전 년 比 205% ↑',
#  '[ 컨콜 ] SK 하이닉스 " 3분 기 D 램 재고 상반기 와 유사 ... 낸드 는 소 폭 감소 예상 ...',
#  '[ 컨콜 ] SK 하이닉스 , “ 현 메모리 가격 , 5 G 스마트폰 원가 부담 없을 것 ”',
#  'SK 하이닉스 2분 기 깜짝 실적 … 영업 익 1.9조 원',
#  'SK 하이닉스 " 내년 D 램 비트 그 로스 20% 이상 성장 전망 "',
#  '[ 컨콜 ] SK 하이닉스 " 내년 D 램 · 낸드 출 하량 각각 20% · 30% 이상 증가 "',
#  '[ 컨콜 ] SK 하이닉스 “ D 램 하반기 도 재고 수준 변화 없어 ”',
#  '[ 컨콜 ] SK 하이닉스 " D 램 가격 , 올 하반기 저 점 예상 "',
#  '[ 컨콜 ] SK 하이닉스 “ 내년 D 램 빗 그 로스 는 올해 대비 20% 상회 예상 ”',
#  '[ IR ] SK 하이닉스 " 내년 D 램 빗 그 로스 올해 보다 20% 상회 전망 "',
#  '[ SK 하이닉스 컨콜 ] 2021년 D 램 · 낸드 수요 ‘ 장밋빛 ’… D 램 20% · 낸드 30% ↑',
#  '[ 컨콜 ] SK 하이닉스 “ 내년 D 램 수요 , 올해 기 저 효과 반영 될 것 ”',
#  '[ 컨콜 ] SK 하이닉스 “ 신규 데이터 센터 건설 이 D 램 수요 촉진 할 것 ”',
#  '[ 컨콜 ] SK 하이닉스 " 내년 D 램 빗 그 로스 20% 이상 , 낸드 30% 초반 성장 예상 "',
#  '[ 컨콜 ] SK 하이닉스 " 내년 빗 그 로스 , 올해 比 D 램 20% · 낸드 30% 성장 "',
#  'SK 하이닉스 , 2분 기 서버 메모리 수요 강세 에 영업 익 200% 이상 증가',
#  "SK 하이닉스 2분 기 영업 이익 2조 원 육박 ' 깜짝 실적 '",
#  '[ 컨콜 ] SK 하이닉스 “ 내년 D 램 빗 그 로스 올해 대비 20% 상회 ”',
#  'SK 하이닉스 " 내년 D 램 비트 그 로스 20% , 낸드 30% 이상 전망 "',
#  "SK 하이닉스 2분 기 ' 어닝 서프라이즈 '… 영업 이익 2조 육박",
#  '[ 컨콜 ] SK 하이닉스 " 내년 D 램 비트 그 로스 , 올해 대비 20% 이상 상회 "',
#  "SK 하이닉스 , 2 Q 영업 익 1.9조 ... 코로나 특수 ' 톡톡 '",
#  '[ 컨콜 ] SK 하이닉스 " 내년 빗 그 로스 D 램 20% , 낸드 30% 상승 전망 "',
#  '[ 컨콜 ] SK 하이닉스 " 내년 비트 그 로스 D 램 20% · 낸드 30% 예상 "',
#  'SK 하이닉스 2분 기 ‘ 어닝 서프라이즈 ’… 영업 이익 1조 9천억원',
#  "SK 하이닉스 ' 어닝 서프라이즈 '… 2 Q 영업 익 1조 9천억",
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원 달성 … 1분 기 대비 143% 증가',
#  "SK 하이닉스 2분 기 ' 깜짝 실적 '… 영업 이익 1조 9천억원 ( 종합 2 보 )",
#  '[ 컨콜 ] SK 하이닉스 , “ 화웨이 제재 등 리스크 발생 적절히 대응 할 것 ”',
#  '[ SK 하이닉스 컨콜 ] 게임 콘솔 신제품 , 하반기 D 램 수요 견인',
#  '[ 컨콜 ] SK 하이닉스 " 게임 콘솔 이 하반기 GDDR · 낸드 출하 50% · 5% 차지 "',
#  '[ 컨콜 ] SK 하이닉스 " DDR 5 내년 본격 확대 ... 2023년 50% 이상 차지 "',
#  "[ 실적 ] SK 하이닉스 , 2 Q 영업 익 1조 9467억 ' 어닝 서프라이즈 '… 전 년 比 205.3% ↑",
#  'SK 하이닉스 , 2분 기 영업 이익 1.9조원 전 년 比 205% ↑ " 서버 메모리 수요 증가 덕 ...',
#  '[ 컨콜 ] SK 하이닉스 " 차세대 게임 콘솔 출시 , 메모리 수요 에 긍정 적 "',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '…' 코로나 19 특수 ' 영업 익 1.9조",
#  '“ DDR 5 시장 , 내년 하반기 본격 확대 할 것 ” - SK 하이닉스 컨콜',
#  '“ 내년 D 램 비트 그 로스 , 올해 대비 20% 이상 상회 ” - SK 하이닉스 컨콜',
#  "SK 하이닉스 2분 기 ' 깜짝 실적 '… 영업 이익 2조원 육박",
#  '‘ 비대 면 효과 ’… 삼성 · SK 반도체 실적 , 시장 예상 뛰어넘었다',
#  'SK 하이닉스 2분 기 영업 익 1조 9400억 \' 기염 \'..." 서버 D 램 수요 뒷받침 "',
#  '[ 컨콜 ] SK 하이닉스 , “ 하반기 게임 콘솔 증가 , 전체 낸드 시장 수요 늘린다 ”',
#  '[ 컨콜 ] SK 하이닉스 " 하반기 D 램 평균 판매 가격 조정 불가피 "',
#  "SK 하이닉스 , 2분 기 매출 액 8.6조 · 영업 이익 1.9조 ... 코로나 19 에도 ' 선방 '",
#  '[ 컨콜 ] SK 하이닉스 " 소니 PS 5 등 신규 게임콘솔 향 낸드 비중 5% "',
#  'SK 하이닉스 " 화웨이 관련 큰 문제 없어 , 적절히 대응 할것 "',
#  'SK 하이닉스 2분 기 ‘ 깜짝 실적 ’… 영업 이익 2조 원 육박 전 년 比 205.3% ↑',
#  'SK 하이닉스 , 코로나 19 비대 면 특수 에 2분 기 깜짝 실적 … 영업 익 1조 9467억원',
#  'SK 하이닉스 , 2 Q 매출 8조 6065억 , 영업 익 1조 9467억원 ... 전 년 동기 比 각 33% ↑ ,...',
#  "[ 컨콜 종합 ] SK 하이닉스 “ 3분 기말 128 낸드 판매 할 것 ... 내년 D 램 ' 낸드 수요 ...",
#  'SK 하이닉스 , 2분 기 영업 익 205% 상승 \' 깜짝 실적 \'…" 화웨이 제재 , 이미 대응 ...',
#  "삼성 전자 · SK 하이닉스 , 코로나 속 한국 경제 ' 대들보 ' 역할",
#  '[ 컨콜 ] SK 하이닉스 " 하반기 고객 재고 , 2분 기 말 보다 건전 "',
#  'SK 하이닉스 " 서버 가 효자 "… 코로나 위기 속 깜짝 실적 달성 ( 종합 )',
#  '" 언택트 가 반도체 살렸다 "... SK 하이닉스 , 2분 기 영업 이익 2조 육박',
#  '韓 경제 ‘ 믿을 건 반도체 ’… 삼성 전자 · SK 하이닉스 동반 ‘ 어닝 서프라이즈 ’',
#  "' 비대 면 바람 ' 탄 SK 하이닉스 , 2분 기 ' 깜짝 실적 '( 종합 )",
#  "SK 하이닉스 , 영업 익 1조 9467억 - 전 년 대비 205% 증가 ' 깜짝 실적 '",
#  'SK 하이닉스 영업 이익 2조 ... 코로나 비대 면 특수',
#  'SK 하이닉스 , 2분 기 영업 이익 2조원 육박 ... 코로나 19 비대 면 특수',
#  "SK 하이닉스 , 2 Q 엔 ' 어닝 서프라이즈 '… 하반기 는 조정 국면",
#  "SK 하이닉스 , 언택트 바람 에 ' 깜짝 실적 ' 기록",
#  'SK 하이닉스 " 올해 D 램 출하 전 년 比 10% , 낸드 40% 이상 증가 전망 "( 종합 )',
#  'SK 하이닉스 2분 기 매출 8조 6065억원 영업 이익 1조 9467억원',
#  'SK 하이닉스 도 2분 기 날았다 … 영업 이익 1.94조원',
#  '[ 컨콜 종합 ] SK 하이닉스 , 하반기 도 호실 적 자신감 …" 메모리 성장 세 견조 "',
#  '반도체 업계 小 호황 기 접어드 나 … SK 하이닉스 " 내년 수요 증가 기대 "',
#  "SK 하이닉스 , 2분 기 ' 호실 적 '... 장 중 주가 ' 강세 '",
#  '[ 컨콜 종합 ] SK 하이닉스 “ 하반기 D 램 가격 하락 , 짧게 끝난다 ”',
#  '‘ 반도체 의 힘 ’ 삼성 전자 이어 SK 하이닉스 도 2분 기 ‘ 어닝 서프라이즈 ’( 종합 ...',
#  'SK 하이닉스 , 2분 기 ‘ 깜짝 실적 ’… 하반기 ‘ 저 점 ’ 내년 ‘ 반등 ’( 종합 )',
#  "SK 하이닉스 , 코로나 19 불구 2분 기 영업 이익 2조 육박 .....' 깜짝 실적 '",
#  "SK 하이닉스 , 코로나 특수 로 2분 기 ' 깜짝 실적 '… 하반기 도 ' 맑음 '",
#  "SK 하이닉스 , 언택트 수혜 ' D 램 · 낸드 ' 날았다 ( 종합 )",
#  '[ 컨콜 ] SK 하이닉스 " D 램 가격 조정 불가피 ··· 하반기 저 점 인식 "',
#  'SK 하이닉스 , 2 Q 매출 8조 6,065억 … 전 년 比 33.4% ↑',
#  "SK 하이닉스 , 2분 기 영업 익 2 兆 육박 … 하반기 는 ' 안갯속 '( 종합 )",
#  '" 코로나 특수 에 메모리 수요 늘어 "… SK 하이닉스 , 2분 기 영업 익 전 년 比 205% ↑',
#  '코로나 특수 누린 \' K 반도체 \'…" 하반기 도 양호 할 것 " 기 대감',
#  '[ 컨콜 ] SK 하이닉스 " 게임콘솔 시장 확대 · 서버 시장 안정화 기대 "',
#  'SK 하이닉스 , 2분 기 매출 8조 6065억 · 영업 익 1조 9467억 … 코로나 19 위기 타파',
#  '[ SR 통신 IT ] SK 하이닉스 , 2분 기 \' 깜짝 실적 \'…" 하반기 짧은 조정 "',
#  'SK 하이닉스 , 2분 기 영업 益 1조 9천억 달성 ... 143% 증가',
#  'SK 하이닉스 , 2 Q 영업 이익 2조 육박 … ‘ 서버 메모리 수요 강세 + 원가 절감 ’',
#  '서프라이즈 SK 하이닉스',
#  '상반기 , 반도체 독식 … 삼성 전자 · SK 하이닉스 ‘ 깜짝 실적 ’',
#  'SK 하이닉스 “ 하반기 도 불확실 성 … 메모리 수요 는 증가 기대 ”',
#  'SK 하이닉스 , 2분 기 영업 익 1.9조원 \' 어닝 서프라이즈 \'…" 하반기 가 D 램 저 점 "',
#  "낸드 적자 끝 보인다 … SK 하이닉스 , ' 1조 클럽 복귀 ' 이유 는",
#  'SK 하이닉스 " 하반기 도 신제품 효과 로 개선 기대 "',
#  'SK 하이닉스 , 2분 기 깜짝 실적 발표 … 영업 이익 1조 9천억원',
#  "SK 하이닉스 2분 기 ' 깜짝 실적 '... 영업 이익 률 23% ., 순이익 만 15% 남겨",
#  '[ 컨콜 ] SK 하이닉스 , 2분 기 ‘ 깜짝 실적 ’… 하반기 도 성장 ( 종합 )',
#  'SK 하이닉스 , 상반기 이어 하반기 호실 적 ‘ 고 ’... “ 메모리 성장 세 견조 “ ( 종 ...',
#  'SK 하이닉스 , 2분 기 깜짝 영업 실적 ...... 영업 이익 1.9조원 달성',
#  '코로나 19 특수 누린 \' K 반도체 \'…" 하반기 도 양호 할 것 " 기 대감',
#  'SK 하이닉스 , 2분 기 ‘ 어닝 서프라이즈 ’ 기록 … 영업 이익 전 년 대비 205% 급증',
#  '[ 컨콜 종합 ] SK 하이닉스 , “ 하반기 반도체 가격 하락 , 만회 할 조건 충분 ”',
#  'SK 하이닉스 2분 기 실적 날았다',
#  "반도체 회복 ' 신호탄 '… SK 하이닉스 영업 익 1.9조 쐈다",
#  "삼성 전자 이어 SK 하이닉스 도 웃었다 …' K - 반도체 ' 의 힘 !",
#  '[ 컨콜 종합 ] SK 하이닉스 " D 램 가격 , 하반기 짧은 조정 … 내년 반등 "',
#  'SK 하이닉스 , 2분 기 영업 이익 2조 육박 ... 영업 이익 률 23%',
#  '[ 종합 ] “ 영업 익 200% 늘었다 ” 부활 한 SK 하이닉스 … 1.9조 어닝 서프라이즈',
#  "' 언택트 ' 덕 본 SK 하이닉스 , 2분 기 영업 익 2조원 육박",
#  'SK 하이닉스 2020년 2분 기 매출 8조 6,065억 , 영업 이익 1조 9,467억 기록',
#  "SK 하이닉스 , 코로나 뚫고 2분 기 ' 어닝 서프라이즈 '… 영업 익 1조 9천억원",
#  '[ 컨콜 종합 ] SK 하이닉스 " 하반기 도 실적 개선 기대 … 가격 하락 제한 적 "',
#  "SK 하이닉스 2분 기 ' 깜짝 실적 '… 영업 益 전 년 대비 205% 증가",
#  '‘ 어닝 서프라이즈 ’ SK 하이닉스 , 게임 · 5 G 로 코로나 19 넘는다',
#  "' 깜짝 실적 ' SK 하이닉스 , 2분 기 영업 익 2조 육박 ' 어닝 서프라이즈 '",
#  'SK 하이닉스 , 2020년 2분 기 경영 실적 발표',
#  "SK 하이닉스 , 코로나 19 에도 2분 기 순이익 143% ' 반짝 상승 '",
#  "코로나 이긴 ' 반도체 코리아 '… SK 하이닉스 도 ' 깜짝 실적 '",
#  '영업 익 2조 육박 … SK 하이닉스 ‘ 어닝 서프라이즈 ’',
#  '상반기 꽃길 걸은 SK 하이닉스 , 하반기 기세 잇는다',
#  '삼성 · SK 하이닉스 2분 기 호실 적 …" 반도체 · 언택트 의 힘 "',
#  '코로나 특수 누린 \' K 반도체 \'…" 하반기 도 양호 할 것 " 기 대감',
#  "SK 하이닉스 , 2분 기 영업 이익 2조원 육박 ' 깜짝 실적 '",
#  "SK 하이닉스 2분 기 영업 익 2조 육박 ' 대박 '… 코로나 ' 호재 ' 영향",
#  '영업 익 2조원 찍은 SK 하이닉스 .. 표정 관리 이유 는 ?',
#  "' 코로나 특수 ' SK 하이닉스 , 2분 기 깜짝 실적 … 하반기 전망 은",
#  "코로나 에도 잘나가는 반도체 업계 , 경력 채용 ' 넓은 문 '",
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 \' 기염 \'..." 하반기 · 내년 시 황도 호조 "',
#  "2분 기도 빛난 ' K - 반도체 '… 하반기 도 괜찮을까",
#  '[ e 프리즘 ] 삼성 · SK 하이닉스 2분 기 실적 … 기대 와 우려 교차 하는 이유',
#  'SK 하이닉스 “ 128 단 낸드 이르면 3분 기 말 본격 판매 ”',
#  '코로나 뚫고 언택트 로 비상한 SK 하이닉스 …" 하반기 불확실 성 돌파 기대 "',
#  'SK 하이닉스 , 2분 기 호실 적 이 어가',
#  '코로나 특수 누린 \' K 반도체 \'…" 하반기 도 양호 할 것 " 기 대감 ( 종합 )',
#  'SK 하이닉스 2분 기 영업 이익 2조원 육박 … 비대 면 분야 수요 증가',
#  'SK 하이닉스 , 2020년 2분 기 경영 실적 발표 … 순이익 률 15%',
#  'SK 하이닉스 도 어닝 서프라이즈 … ‘ 언택트 효과 ’ 에 2 Q 깜짝 실적 ’ 영업 익 2조 ...',
#  '코로나 뚫은 메모리 의 힘 … ‘ 반도체 쌍 두 마차 ’ 상반기 호실 적',
#  'SK 하이닉스 " D 램 가격 조정 기간 짧다 "… 하반기 호실 적 자신',
#  'SK 하이닉스 , 2분 기 영업 익 1조 9467억 기록',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '… 영업 익 1.9조원 , 영업 이익 률 23%",
#  '‘ 코로나 특수 ’ SK 하이닉스 2 Q 영업 익 2조 육박',
#  '반도체 시장 하반기 D 램 가격 하락 이 변수',
#  '연 이 은 깜짝 실적 … 하반기 ‘ 반 · 디 ’ 특수 이어질까',
#  "SK 하이닉스 , 2분 기 ' 어닝 서프라이즈 '... 영업 익 2조원 육박",
#  "' 언택트 의 힘 ' 반도체 2분 기 ' 선방 '… 3분 기는 ?",
#  "코로나 에도 버텼다 ... 현대차 ' 선방 ' 하이닉스 ' 깜짝 실적 '",
#  "[ 오늘 Who ] 이석희 , SK 하이닉스 ' 아픈 손가락 ' 낸드 사업 반등 반갑다",
#  '이석희 號 SK 하이닉스 , 하반기 메모리 반도체 시장 성장 가능성 봤다',
#  "SK 하이닉스 ' 코로나 특수 ' 하반기 에도 이어질까",
#  '2분 기 호실 적 에 슬그머니 웃는 SK 하이닉스 , " 예상 대로 "',
#  '코로나 19 확산 에 SK 하이닉스 의 영업 이익 이 205% 나 증가 했다',
#  "SK 하이닉스 ' 깜짝 실적 '… 이익 200% 늘어 2조 육박",
#  "SK 하이닉스 , 2분 기 영업 익 2조 육박 ' 어닝 서프라이즈 '... K 반도체 하반기 희망 ...",
#  '[ 로 & 스탁 ] SK 하이닉스 , 2분 기 영업 이익 1조 9467억 ... 전 년 동 기비 205% 증가',
#  'SK 하이닉스 , 코로나 19 경기 악화 에도 2분 기 어닝 서프라이즈',
#  'SK 하이닉스 " 보수 적 투자 기조 이어 간다 , 기술 과 수익 성 향상 에 주력 "',
#  'SK 하이닉스 는 ` 깜짝 실적 `… 비대 면 특수 로 반도체 날았다',
#  '" 수요 꾸 준 " " D 램값 내릴것 " 반도체 엇갈리는 전망',
#  '코로나 에도 빛났다 … SK 하이닉스 영업 익 143% 증가 ‘ 깜짝 실적 ’',
#  '희망 쏜 반도체 바닥 친 차 , 업황 엇갈려 SK 웃고 현대차 울 고',
#  '이천 SK 하이닉스 2분 기 영업 이익 2조 육박',
#  'SK 하이닉스 ‘ 비대 면 특수 ’ 2분 기 영업 이익 2조 기염',
#  "' 비대 면 수혜 ' SK 하이닉스 , 서버 용 D 램 이 매출 절반",
#  "' 반도체 의 힘 ' SK 하이닉스 ' 깜짝 실적 '… 2분 기 영업 익 1조 9467억",
#  '역성 장 서 빛난 대기업 실적 … 경제 버팀목 역할',
#  "홀로 웃은 반도체 … 하반기 에도 ' 맑음 '",
#  'SK 하이닉스 ` 언택트 잭팟 `… 하반기 낸드 신화 다시 쓴다',
#  'SK 하이닉스 2분 기 영업 익 1조 9467억',
#  'SK 하이닉스 실적 개선 … 청주 도 희 ( 喜 )',
#  '[ 사설 ] 평택시 , 삼성 품 을 능력 시험 무대 다',
#  "2분 기 실적 ··· 하이닉스 ' 깜짝 성적 ' 현대차 는 ' 선방 '",
#  'SK 하이닉스 , 2분 기 영업 이익 1조 9467억원',
#  'SK 하이닉스 코로나 에도 웃었다',
#  'SK 하이닉스 , 2020년 2분 기 매출 액 8조 6065억원 기록',
#  'SK 하이닉스 주력 품 잘 팔리네 2분 기 영업 이익 1조 9467억원',
#  "SK 하이닉스 도 ' K 반도체 ' 저력 올 2분 기 영업 이익 2조 원 육박",
#  '‘ K 반도체 저력 ’ SK 하이닉스 영업 익 2조 , 3 배 늘었다',
#  'SK 하이닉스 , 영업 익 2조 ‘ 서프라이즈 ’… 현대 車 그룹 , 글로벌 부진 속 흑자 ‘ ...',
#  '고맙다 , 서버 증설 … SK 하이닉스 2분 기 영업 이익 작년 의 3 배',
#  'SK 하이닉스 깜짝 실적 … 하반기 ‘ 반 · 디 특수 ’ 이어질까',
#  '[ 원 포인트 투자 레슨 ] 내년 디램 세대 교체 … 반도체 업황 에 호재',
#  '포기 할 줄 알았는데 …" 대만 침공 할 판 " 중국 의 D 램 집착',
#  "코로나 견딘 ' K 칩 '… 삼성 · SK 하이닉스 6분 기만의 최대 실적",
#  "SK 하이닉스 도 2 Q ' 깜짝 실적 '… 하반기 반도체 전망 은 ?",
#  "SK 하이닉스 , ' 깜짝 실적 ' 냈지만 하반기 전망 은 엇갈려",
#  '" SK 하이닉스 , 3분 기 실적 부진할듯 ... 목표 주가 10만원 으로 하향 "',
#  '[ Invest ] 현대차 · SK 하이닉스 , 같은 어닝 서프라이즈 에도 엇갈린 증시 반응',
#  'SK 하이닉스 , 2 Q 실적 전 망치 상회 .. 하반기 일시 적 조정 - DB 금투',
#  "[ 더벨 ] SK 하이닉스 , 낸드 플래시 ' 백조 ' 로 탈바꿈 하나",
#  'SK 하이닉스 주식 매수 의견 유지 , " D 램 수요 하반기 늘 가능성 높아 "',
#  '[ 오늘 기업 오늘 사람 ] LG 유플러스 · 화이자 · SK 하이닉스 · 이스타항공',
#  '" SK 하이닉스 4분 기 실적 저 점 예상 … 지금 이 매수 적기 " [ 미래에셋 대우 ]',
#  '7월 24일 이 세 철 의 출근길 뉴스 / 정책 브리핑',
#  '[ 2020.2 Q ] 잠정 실적 중계 .. 먼저 볼 기업 어디 ? - 7/23',
#  'D 램 가격 , 3분 기 하락 불가피 … 하반기 저 점 통과',
#  '무디스 " SK 하이닉스 2분 기 실적 , 반도체 업황 개선 시그널 "',
#  '국산 화 잰 걸음 에 힘 받는 반도체 소재 株',
#  "' 깜짝 ' 선방 SK 하이닉스 ... 하반기 전망 불투명",
#  '‘ 코로나 뚫은 ’ K 칩 . 하반기 에도 동반 질주',
#  '[ 삼 성 전자 의 위상 ① ] 팬데믹 에서 국내 수출 구 해내다',
#  '[ 취재 뒷담화 ] 애플 · TSMC , 삼성 전자 좌절 케 한 양대 장벽',
#  '“ SK 하이닉스 , 터널 의 중반 을 통과 했다는 신호 가 있어야 주가 반등 빨라질 것 ...',
#  '美 · 中 갈등 고조 에 코스피 · 코스닥 모두 하락 마감',
#  "인텔 7 나노 칩 출시 연기 에 ··· 삼성 메모리 ' 뜻밖 의 악재 '",
#  "삼성 전자 · SK 하이닉스 실적 효자 ' D 램 '… 하반기 도 힘 발휘 할까 ?",
#  "흔들리는 ' 인텔 제국 '.. 한숨짓는 ' 삼성 전자 ' [ 양 철민 의 인더스 트리 ]",
#  "삼 성 전자 를 ' NN ' 이라고 부르며 저주 하는 중국 업체 [ 황정수 의 반도체 이슈 짚 ...",
#  "반도체 업계 , 코로나 폭풍 에도 ' 굳건 '… D 램 수요 실적 견인"]

# %%
import operator

lst=[]
for i in range(len(x_new)):
    w=x_new[i]
    w=w.split(' ')
    for j in range(len(w)):
        lst.append(w[j])

d={}
ex_t='[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…...》'

for i in lst:
    if i in ex_t:
        continue
    if i not in d:
        d[i]=1
    else:
        d[i]+=1
        
d=sorted(d.items(), key = lambda item: item[1])
d2={}

for i in range(len(d)):
    d2[d[i][0]]=d[i][1]
    

for k,v in d2.items():
    print('{} : {}'.format(k,v))
# Out:
# Biz : 1
# 리뷰 : 1
# 아모레퍼시픽 : 1
# 마몽드 : 1
# 아마존 : 1
# 입점 : 1
# ·' : 1
# 규격 : 1
# 오른쪽 : 1
# 박정국 : 1
# 모비스 : 1
# 완연 : 1
# W : 1
# 비메 : 1
# 모리 : 1
# 1 : 1
# 신입사원 : 1
# 투입 : 1
# 새로운 : 1
# 땐 : 1
# 9만원 : 1
# 2022년 : 1
# 외형 : 1
# 고선지 : 1
# 上 : 1
# 모험 : 1
# 두려워하지 : 1
# 않는 : 1
# 리더십 : 1
# 190% : 1
# 기다리며 : 1
# 지숙 : 1
# 재계 : 1
# OLD : 1
# NEW : 1
# M : 1
# A : 1
# 후 : 1
# 진짜 : 1
# 주인 : 1
# 만나 : 1
# 성장한 : 1
# 여의도 : 1
# 클라 : 1
# 쓰 : 1
# 모멘텀 : 1
# 엑시콘 : 1
# 모듈 : 1
# 탈환 : 1
# 쑥 : 1
# 열 : 1
# 린다 : 1
# 상용 : 1
# 성큼 : 1
# 집중 : 1
# 시세 : 1
# 포착 : 1
# 장주 : 1
# 라인업 : 1
# 승부 : 1
# 수 : 1
# EUV : 1
# 공정 : 1
# 가속 : 1
# 페달 : 1
# 밟는다 : 1
# ?... : 1
# 日 : 1
# 규제 : 1
# 1년 : 1
# 상 : 1
# 부장 : 1
# 독립 : 1
# 필요성 : 1
# 일 : 1
# 깨워 : 1
# 아베 : 1
# 32.4% : 1
# 석유 : 1
# 화학 : 1
# 제품 : 1
# 게 : 1
# 섰거라 : 1
# "··· : 1
# 모은다 : 1
# 향방 : 1
# 이지 : 1
# 보고서 : 1
# 내림세 : 1
# 뒤 : 1
# 살얼음 : 1
# 재 : 1
# 유행 : 1
# 무역 : 1
# 분쟁 : 1
# 사태 : 1
# 넘어 : 1
# 전장 : 1
# 부품 : 1
# 추월 : 1
# 한다 : 1
# "···' : 1
# 모빌리티 : 1
# 열겠다 : 1
# 생태계 : 1
# 확장 : 1
# 적극 : 1
# 지원 : 1
# 기침 : 1
# 한번 : 1
# 안 : 1
# 잇 : 1
# 아 : 1
# 날개 : 1
# 好 : 1
# 미국 : 1
# 이끈다 : 1
# ?… : 1
# 개발 : 1
# 밝음 : 1
# 오르며 : 1
# 왜 : 1
# 관심 : 1
# 회동 : 1
# 김기남 : 1
# 다섯 : 1
# 오름세 : 1
# 훨훨 : 1
# 특별 : 1
# 기획 : 1
# 남부 : 1
# 통합 : 1
# 국제공항 : 1
# 必要性 : 1
# 살피 : 1
# 빅딜 : 1
# 이례 : 1
# 추격자 : 1
# 노리 : 1
# 그린 : 1
# 재생에너지 : 1
# 수용 : 1
# 결단 : 1
# 아이폰 : 1
# 12 : 1
# 노려 : 1
# [[ : 1
# 종목 : 1
# PICK : 1
# 개미 : 1
# 행렬 : 1
# 기회 : 1
# 회복할까 : 1
# 700억 : 1
# 달러 : 1
# 700만달러 : 1
# 국가 : 1
# 632억 : 1
# 신재생에너지 : 1
# 등록 : 1
# 경신 : 1
# 밀려 : 1
# 살아난다 : 1
# 오르고 : 1
# 돼지고기 : 1
# 순 : 1
# 0 : 1
# 하여 : 1
# 7% : 1
# ..." : 1
# 전성 : 1
# 123억 : 1
# 불 : 1
# 희비 : 1
# 2030년 : 1
# 제로 : 1
# 비전 : 1
# 메모 : 1
# 리용 : 1
# 정장 : 1
# Ultra : 1
# C : 1
# VI : 1
# 공개 : 1
# 시작 : 1
# 업 : 1
# 팔고 : 1
# 쓸어 : 1
# 담은 : 1
# 외국인 : 1
# 경계 : 1
# 론 : 1
# ’, : 1
# 진교 : 1
# 영 : 1
# 사장 : 1
# 사력 : 1
# 하고 : 1
# 있다 : 1
# 시론 : 1
# 이렇게 : 1
# 진출 : 1
# 외환위기 : 1
# 극복 : 1
# 왔다 : 1
# 디바이스 : 1
# 평택 : 1
# 공장 : 1
# 하루 : 1
# 25만 : 1
# t : 1
# 물 : 1
# 어떻게 : 1
# 끌어오나 : 1
# 공업 : 1
# 용수 : 1
# 확 : 1
# 솔솔 : 1
# 인터뷰 : 1
# 정권 : 1
# 재창 : 1
# 위해 : 1
# 선 : 1
# 전문가 : 1
# 필요 : 1
# 소명 : 1
# 숨 : 1
# 고르기 : 1
# 들어서나 : 1
# 이겨 : 1
# 낸 : 1
# 전분 : 1
# 9500억원 : 1
# 6,065억원 : 1
# 9,467억원 : 1
# 9천 : 1
# 467억 : 1
# 1.94조 : 1
# 컨센서스 : 1
# 웃돈 : 1
# 활짝 : 1
# 지속 : 1
# 여전 : 1
# 강보 : 1
# 합세 : 1
# ...' : 1
# 73% : 1
# 24% : 1
# 늘렸다 : 1
# 發 : 1
# 재택근무 : 1
# 어려워 : 1
# 단비 : 1
# 5분 : 1
# 1조원 : 1
# 9 : 1
# 이전 : 1
# 제시 : 1
# 했던 : 1
# 수치 : 1
# 부합 : 1
# 비슷할 : 1
# 성공 : 1
# 기와 : 1
# 비슷 : 1
# 정상 : 1
# 도달 : 1
# 입증 : 1
# 8% : 1
# ↑” : 1
# 건전해질 : 1
# 높았다 : 1
# 연말 : 1
# 정상화 : 1
# 건전한 : 1
# 폰 : 1
# 가폰 : 1
# 그칠듯 : 1
# 장기 : 1
# 짧을 : 1
# 9000억원 : 1
# 찍 : 1
# 또 : 1
# 인 : 1
# 요인 : 1
# 폭 : 1
# 감소 : 1
# 현 : 1
# 부담 : 1
# 없을 : 1
# 각각 : 1
# 장밋빛 : 1
# 반영 : 1
# 될 : 1
# 데이터 : 1
# 센터 : 1
# 건설 : 1
# 촉진 : 1
# 초반 : 1
# 1분 : 1
# 리스크 : 1
# 발생 : 1
# 2023년 : 1
# '…' : 1
# 뛰어넘었다 : 1
# 9400억 : 1
# 뒷받침 : 1
# 전체 : 1
# 늘린다 : 1
# 8.6조 : 1
# 소니 : 1
# PS : 1
# 관련 : 1
# 큰 : 1
# 문제 : 1
# 할것 : 1
# 각 : 1
# 33% : 1
# ,... : 1
# 기말 : 1
# 이미 : 1
# 대들보 : 1
# 건전 : 1
# 살렸다 : 1
# "... : 1
# 믿을 : 1
# 건 : 1
# 탄 : 1
# 국면 : 1
# "( : 1
# 1.94조원 : 1
# 자신감 : 1
# 小 : 1
# 접어드 : 1
# 짧게 : 1
# 끝난다 : 1
# .....' : 1
# 33.4% : 1
# 안갯속 : 1
# 안정화 : 1
# 타파 : 1
# SR : 1
# 통신 : 1
# IT : 1
# 절감 : 1
# 독식 : 1
# 적자 : 1
# 끝 : 1
# 보인다 : 1
# 클럽 : 1
# 복귀 : 1
# ., : 1
# 만 : 1
# 남겨 : 1
# ’... : 1
# 종 : 1
# ...... : 1
# 급증 : 1
# 만회 : 1
# 조건 : 1
# 충분 : 1
# 부활 : 1
# 본 : 1
# 9,467억 : 1
# 제한 : 1
# 넘는다 : 1
# 반짝 : 1
# 이긴 : 1
# 코리아 : 1
# 꽃길 : 1
# 걸은 : 1
# 기세 : 1
# 잇는다 : 1
# 대박 : 1
# 찍은 : 1
# 표정 : 1
# 관리 : 1
# 잘나가는 : 1
# 경력 : 1
# 채용 : 1
# 넓은 : 1
# 문 : 1
# 시 : 1
# 황도 : 1
# 기도 : 1
# 괜찮을까 : 1
# e : 1
# 프리즘 : 1
# 교차 : 1
# 이르면 : 1
# 비상한 : 1
# 어가 : 1
# 분야 : 1
# 쌍 : 1
# 두 : 1
# 마차 : 1
# 짧다 : 1
# 자신 : 1
# 변수 : 1
# 연 : 1
# 기는 : 1
# 버텼다 : 1
# Who : 1
# 아픈 : 1
# 손가락 : 1
# 반갑다 : 1
# 號 : 1
# 봤다 : 1
# 슬그머니 : 1
# 웃는 : 1
# 대로 : 1
# 했다 : 1
# 스탁 : 1
# 동 : 1
# 악화 : 1
# 간다 : 1
# 기술 : 1
# 향상 : 1
# 꾸 : 1
# 램값 : 1
# 내릴것 : 1
# 빛났다 : 1
# 쏜 : 1
# 바닥 : 1
# 친 : 1
# 웃고 : 1
# 울 : 1
# 이천 : 1
# 절반 : 1
# 역성 : 1
# 서 : 1
# 대기업 : 1
# 버팀목 : 1
# 홀로 : 1
# 웃은 : 1
# 잭팟 : 1
# 신화 : 1
# 다시 : 1
# 쓴다 : 1
# 청주 : 1
# 희 : 1
# 喜 : 1
# 사설 : 1
# 능력 : 1
# 시험 : 1
# 무대 : 1
# 성적 : 1
# 잘 : 1
# 팔리네 : 1
# 車 : 1
# 그룹 : 1
# 부진 : 1
# 흑자 : 1
# 고맙다 : 1
# 증설 : 1
# 포인트 : 1
# 레슨 : 1
# 디램 : 1
# 세대 : 1
# 교체 : 1
# 포기 : 1
# 줄 : 1
# 알았는데 : 1
# 침공 : 1
# 집착 : 1
# 견딘 : 1
# 6분 : 1
# 기만의 : 1
# 냈지만 : 1
# 부진할듯 : 1
# 10만원 : 1
# Invest : 1
# 같은 : 1
# 엇갈린 : 1
# 증시 : 1
# 반응 : 1
# 일시 : 1
# DB : 1
# 금투 : 1
# 더벨 : 1
# 백조 : 1
# 탈바꿈 : 1
# 주식 : 1
# 의견 : 1
# 늘 : 1
# 높아 : 1
# 사람 : 1
# LG : 1
# 유플러스 : 1
# 화이자 : 1
# 이스타항공 : 1
# 4분 : 1
# 적기 : 1
# 미래에셋 : 1
# 대우 : 1
# 7월 : 1
# 24일 : 1
# 철 : 1
# 출근길 : 1
# 뉴스 : 1
# 정책 : 1
# 브리핑 : 1
# 2020.2 : 1
# 잠정 : 1
# 중계 : 1
# 먼저 : 1
# 볼 : 1
# 어디 : 1
# 7/23 : 1
# 무디스 : 1
# 시그널 : 1
# 국산 : 1
# 잰 : 1
# 걸음 : 1
# 받는 : 1
# 소재 : 1
# 불투명 : 1
# 질주 : 1
# 위상 : 1
# ① : 1
# 팬데믹 : 1
# 구 : 1
# 해내다 : 1
# 취재 : 1
# 뒷담화 : 1
# TSMC : 1
# 좌절 : 1
# 케 : 1
# 양대 : 1
# 장벽 : 1
# 터널 : 1
# 중반 : 1
# 했다는 : 1
# 신호 : 1
# 있어야 : 1
# 빨라질 : 1
# 中 : 1
# 갈등 : 1
# 고조 : 1
# 코스피 : 1
# 코스닥 : 1
# 마감 : 1
# 7 : 1
# 나노 : 1
# 연기 : 1
# 뜻밖 : 1
# 악재 : 1
# 발휘 : 1
# 흔들리는 : 1
# 제국 : 1
# '.. : 1
# 한숨짓는 : 1
# 를 : 1
# NN : 1
# 이라고 : 1
# 부르며 : 1
# 저주 : 1
# 황정수 : 1
# 이슈 : 1
# 짚 : 1
# 폭풍 : 1
# 굳건 : 1
# 美 : 2
# 현대 : 2
# 중심 : 2
# 엇갈리는 : 2
# V : 2
# 목표 : 2
# 호황 : 2
# 쾌청 : 2
# 하향 : 2
# 비실 : 2
# !] : 2
# 단 : 2
# 플래시 : 2
# 했는데 : 2
# 수출 : 2
# 소 : 2
# 준 : 2
# 휘발 : 2
# 윳값 : 2
# 테슬라 : 2
# 철민 : 2
# 인더스 : 2
# 트리 : 2
# 여파 : 2
# 올라 : 2
# 영향 : 2
# 우려 : 2
# 협력 : 2
# 배터리 : 2
# 동행 : 2
# 시대 : 2
# 한국 : 2
# 株 : 2
# 경기 : 2
# 친환경 : 2
# 동맹 : 2
# 업고 : 2
# 왕좌 : 2
# 생산 : 2
# 지금 : 2
# 약 : 2
# 규모 : 2
# 632억달러 : 2
# SEMI : 2
# 전세계 : 2
# 에서 : 2
# 대만 : 2
# 엔 : 2
# 탄소 : 2
# 배출 : 2
# 량 : 2
# 내 : 2
# 2021년 : 2
# 첨단 : 2
# 공급 : 2
# 평택시 : 2
# 향 : 2
# 속보 : 2
# 신호탄 : 2
# 쐈다 : 2
# 불구 : 2
# 망치 : 2
# 보수 : 2
# 기조 : 2
# 유지 : 2
# 兆 : 2
# 보 : 2
# 직전 : 2
# 업체 : 2
# 유사 : 2
# 수익 : 2
# HBM : 2
# 6 : 2
# 60% : 2
# 톡톡 : 2
# 동기 : 2
# 모두 : 2
# 거칠 : 2
# 변화 : 2
# 스마트폰 : 2
# 사업 : 2
# 원가 : 2
# 보다 : 2
# 9천억 : 2
# 제재 : 2
# 적절히 : 2
# 신제품 : 2
# 50% : 2
# 5% : 2
# 차지 : 2
# '..." : 2
# 게임콘솔 : 2
# 역할 : 2
# 효자 : 2
# 동반 : 2
# 바람 : 2
# 6065억원 : 2
# 장 : 2
# ’( : 2
# 맑음 : 2
# 6,065억 : 2
# 益 : 2
# 늘었다 : 2
# 경영 : 2
# 호재 : 2
# 빛난 : 2
# 뚫은 : 2
# 디 : 2
# 이석희 : 2
# 가능성 : 2
# 희망 : 2
# 주력 : 2
# `… : 2
# 엇갈려 : 2
# 품 : 2
# 통과 : 2
# 삼 : 2
# 인텔 : 2
# 미래 : 3
# 까지 : 3
# 심텍 : 3
# 패키지 : 3
# 하나 : 3
# 전환 : 3
# 용 : 3
# 호조 : 3
# 화 : 3
# 수혜 : 3
# 128 : 3
# 전월 : 3
# 양 : 3
# 비 : 3
# 할까 : 3
# 하는 : 3
# 달 : 3
# 고 : 3
# 글로벌 : 3
# 다 : 3
# 매수 : 3
# 최 : 3
# 국내 : 3
# 韓 : 3
# 넘 : 3
# 본다 : 3
# 18 : 3
# 챔버 : 3
# 싱글 : 3
# 정 : 3
# 리서치 : 3
# 6065억 : 3
# 껑충 : 3
# 기비 : 3
# …' : 3
# 늘어 : 3
# 불확실 : 3
# 2% : 3
# 위기 : 3
# ASP : 3
# 뚫고 : 3
# 배 : 3
# 확산 : 3
# 자릿수 : 3
# 후반 : 3
# 증 : 3
# IR : 3
# 듯 : 3
# 저력 : 3
# 출하 : 3
# 말 : 3
# 고객 : 3
# 인식 : 3
# 견조 : 3
# 기간 : 3
# 신규 : 3
# 없어 : 3
# 200% : 3
# 화웨이 : 3
# 대응 : 3
# 기염 : 3
# 업계 : 3
# 주가 : 3
# 이유 : 3
# 순이익 : 3
# 이어질까 : 3
# 업황 : 3
# 정의선 : 4
# 이재용 : 4
# 차 : 4
# 회복 : 4
# 자 : 4
# 위 : 4
# 등 : 4
# 대치 : 4
# 과 : 4
# 그래픽 : 4
# 들 : 4
# 대 : 4
# 본격 : 4
# 줄줄이 : 4
# 칩 : 4
# 덕 : 4
# 긍정 : 4
# 6% : 4
# 중국 : 4
# 700억달러 : 4
# 사 : 4
# ACM : 4
# 웨이퍼 : 4
# 출시 : 4
# 오늘 : 4
# 경제 : 4
# '( : 4
# 23% : 4
# 작년 : 4
# 웃었다 : 4
# 비중 : 4
# 평균 : 4
# 와 : 4
# 중 : 4
# GDDR : 4
# G : 4
# 견인 : 4
# 이어 : 4
# 누린 : 4
# 양호 : 4
# 판 : 5
# 개선 : 5
# …" : 5
# 현대차 : 5
# 단독 : 5
# 2020년 : 5
# 상보 : 5
# 률 : 5
# '... : 5
# ··· : 5
# 속 : 5
# 연간 : 5
# 수준 : 5
# 40% : 5
# 짧은 : 5
# 콘솔 : 5
# 원 : 5
# 비트 : 5
# 게임 : 5
# 차세대 : 6
# DDR : 6
# 대감 : 6
# 국제 : 6
# 6월 : 6
# 0.5% : 6
# 은 : 6
# 확대 : 6
# 올 : 6
# 발표 : 6
# 1.9조원 : 6
# 15% : 6
# 달성 : 6
# 10% : 6
# 중후 : 6
# 빗 : 6
# 한 : 7
# 돌파 : 7
# "… : 7
# 세계 : 7
# 날았다 : 7
# 기록 : 7
# 애플 : 7
# 나 : 7
# 년비 : 7
# 143% : 7
# 강세 : 7
# 성 : 7
# 판매 : 7
# 으로 : 8
# 세 : 8
# 30% : 8
# 기업 : 8
# 상반기 : 8
# 선방 : 8
# 유가 : 8
# 효과 : 8
# 가 : 8
# 역대 : 8
# 3 : 8
# 8조 : 8
# 분기 : 8
# 상회 : 8
# 9천억원 : 8
# 반 : 8
# 재고 : 8
# '…" : 8
# 불가피 : 8
# 을 : 9
# 최대 : 9
# 성장 : 10
# 기대 : 10
# 개월 : 10
# 액 : 10
# 비대 : 10
# 면 : 10
# 만에 : 11
# 힘 : 11
# 하락 : 11
# 점 : 11
# 로스 : 11
# 는 : 12
# 그 : 12
# 이상 : 12
# 저 : 12
# 할 : 12
# 매출 : 13
# 시장 : 13
# 이 : 13
# 3분 : 13
# 호실 : 13
# ’… : 13
# 하량 : 13
# 20% : 13
# K : 14
# 전자 : 14
# 예상 : 14
# 조정 : 14
# 생산자 : 14
# 물가 : 14
# 출 : 14
# 19 : 14
# 서버 : 15
# 반등 : 15
# 올해 : 15
# 1.9조 : 15
# 것 : 16
# 205.3% : 16
# 로 : 18
# 상승 : 18
# 언택트 : 18
# 투자 : 18
# 에도 : 19
# 장비 : 19
# 메모리 : 20
# 대비 : 20
# 9467억원 : 20
# 5 : 21
# 삼성 : 21
# 의 : 21
# 2조원 : 21
# 적 : 22
# 특수 : 22
# 9467억 : 23
# 가격 : 24
# 205% : 25
# ” : 26
# Q : 27
# 수요 : 28
# 2 : 29
# 比 : 29
# 전망 : 30
# 2조 : 30
# 에 : 31
# “ : 31
# 도 : 32
# 종합 : 32
# 증가 : 33
# 내년 : 34
# ’ : 34
# 년 : 34
# 낸드 : 36
# 육박 : 39
# ↑ : 40
# 어닝 : 42
# 서프라이즈 : 44
# 전 : 50
# · : 51
# 코로나 : 54
# 깜짝 : 55
# 1조 : 61
# 컨콜 : 65
# 이익 : 67
# 하반기 : 71
# 램 : 76
# D : 77
# 반도체 : 78
# 실적 : 80
# 익 : 83
# 영업 : 152
# 2분 : 159
# 기 : 182
# SK : 319
# 하이닉스 : 320

# %%
# res=pd.DataFrame(list(d2.items()),
#                    columns=['단어', '빈도수'])
# res.to_excel('word_' + file_name + '.xlsx')

# %%
res=pd.DataFrame(list(d2.items()),
                   columns=['단어', '빈도수'])
res1 = res.sort_values(by=['빈도수'],ascending=False)
res2 = res1.reset_index().drop(['index'], axis=1)
res2.to_excel('word_' + file_name + '.xlsx')

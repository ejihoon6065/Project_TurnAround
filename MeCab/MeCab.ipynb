# %%
import MeCab

# %%
m= MeCab.Tagger()
out = m.parse("메켑이 잘 설치되었는지 확인 중입니다.")
print(out)
# Out:
# 메	VV+EC,*,F,메,Inflect,VV,EC,메/VV/*+어/EC/*
# 켑이	UNKNOWN,*,*,*,*,*,*,*
# 잘	MAG,*,T,잘,*,*,*,*
# 설치	NNG,행위,F,설치,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 확인	NNG,행위,T,확인,*,*,*,*
# 중	NNB,*,T,중,*,*,*,*
# 입니다	VCP+EF,*,F,입니다,Inflect,VCP,EF,이/VCP/*+ᄇ니다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %% [markdown]
# <br>
# <br>
#
# # TF상위 1000단어 Uni-gram / Bi-gram 추출

# %%
import codecs
from nltk.util import ngrams
import re
import pandas as pd
import copy

df = pd.read_excel('뉴스데이터.xlsx')  # 1997.10.21 ~ 2020.06.15 한국경제 뉴스데이터
title = df['title'].values.tolist()
docs = title

# %%
print(len(docs))
# Out:
# 9369

# %%
# 리뷰문장 출력
import re
clean_docs = []
pattern = '[-=+,#/\?:·;^$.%@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]'   # 특수문자 제거
pattern2='[]'
cnt=0
news_remov_index=[]
for i in range(len(docs)) :
    sen=docs[i]
    
    span=[]
    for p in range(len(sen)):
        if sen[p]=='[':
            span.append(p)
        elif sen[p]==']':
            span.append(p)
        else:
            continue
    if len(span)==2:
        sen=sen[0:span[0]]+sen[span[1]+1::]     # 칼럼제목([]로 둘러싸인 문자열)을 제거
    
    sen = re.sub(pattern,"",sen) # pattern에서 정의한 특수문자 정규표현식 을 제거 
    sen = re.sub('[0-9]+','',sen)
    #sen = re.sub('[一-龥]','',sen)
    #sen = re.sub('[ㄱ-ㅣ가-힣]+','',sen)
    #sen = re.sub('[a-zA-Z]','',sen)
    sen = sen.strip() # 양옆의 공백을 제거 
    
    if sen=='':
        cnt+=1
        news_remov_index.append(i)
    clean_docs.append(sen)
    
# ex) [오늘의 뉴스] 오늘의 날씨는 맑음! ---(정제)---> 오늘 의 날씨 는 맑음

# %%
clean_docs[:10]
# Out:
# ['세계무역센터 어떤 곳인가',
#  '미국주요도시 동시다발 테러공격',
#  '뉴욕 세계무역센터 빌딩 비행기 충돌',
#  '럼즈펠드 美 국방 관료주의와의 전면전 선언',
#  '짧고 쉽게 답변자신감 보여줘야  성공취업인터뷰 요령',
#  '소피아 로렌과 미녀들',
#  '英공교육 성공신화 호브파크 스쿨',
#  '엔화 엔대로 급등엔캐리 트레이드 청산 가속',
#  '예루살렘 성벽 밝힌 빛 축제',
#  '동물 난자에 사람 유전자 주입英의회 교잡배아 허용']

# %%
docs = clean_docs

# %% [markdown]
# # 바이그램 추출

# %% [markdown]
# Mecab을 적용해 형태소로 나누고, 바이그램생성

# %%
from konlpy.tag import Okt
from tqdm import tqdm
from konlpy.tag import Mecab
tagger=Mecab('C:/mecab/mecab-ko-dic')

#tagger = Okt()
sentence_bigram = []

# http://kkma.snu.ac.kr/documents/?doc=postag 참고
josa=['JKS','JKC','JKG','JKO','JKB','JKV','JKQ','JX','JC']                    # 조사
jeop_misa_and_doosa=['XSN','XSV','XSA','XPN']                                 # 접미사
boosa=['MAG','MAJ']                                                           # 부사
eomaleomy=['EF','EC','ETN','ETM','EP']                                        # 어말어미   (EP는 선어말어미)

for doc in tqdm(docs):
    p = tagger.pos(doc)
    tokens=[]
    
    for j in p:
        i=j[1]
        if (i in josa) | (i in jeop_misa_and_doosa) | (i in boosa) | (i in eomaleomy):
            continue
        tokens.append(j[0])
        
    bigram = ngrams(tokens, 2, pad_left=False, pad_right=False)
                    #left_pad_symbol="SS", right_pad_symbol="SE")
    
#     for t in bigram:
#         if t[0] in trans_cntry
    sentence_bigram += [t for t in bigram]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 9369/9369 [00:02<00:00, 3880.12it/s]

# %%
# 예시 1)
tagger.pos('대한종금 인가 취소키로 .. 금융감독위원회')
# Out:
# [('대한', 'VV+ETM'),
#  ('종금', 'NNG'),
#  ('인가', 'VCP+EC'),
#  ('취소', 'NNG'),
#  ('키로', 'XSV+ETN+JKB'),
#  ('.', 'SF'),
#  ('.', 'SY'),
#  ('금융', 'NNG'),
#  ('감독', 'NNG'),
#  ('위원회', 'NNG')]

# %%
sentence_bigram[:10]
# Out:
# [('세계무역센터', '어떤'),
#  ('어떤', '곳'),
#  ('곳', '인가'),
#  ('미국', '주요'),
#  ('주요', '도시'),
#  ('도시', '동시'),
#  ('동시', '다발'),
#  ('다발', '테러'),
#  ('테러', '공격'),
#  ('뉴욕', '세계무역센터')]

# %%
# 바이그램에서 나라한자들을 한글로 Replace
trans_cntry={'美':'미국','佛':'프랑스','日':'일본','中': '중국','露': '러시아','獨':'독일','北':'북한','英':'영국','弗':'달러' }

sentence_bigram2=[]
for i in sentence_bigram:
    i=list(i)
    sentence_bigram2.append(i)
   
for i in range(len(sentence_bigram2)):
    for k in range(len(sentence_bigram2[i])):
        if sentence_bigram2[i][k] in trans_cntry.keys():
            sentence_bigram2[i][k]=trans_cntry[sentence_bigram2[i][k]]
            
sentence_bigram=copy.deepcopy(sentence_bigram2)
sentence_bigram[:10]
# Out:
# [['세계무역센터', '어떤'],
#  ['어떤', '곳'],
#  ['곳', '인가'],
#  ['미국', '주요'],
#  ['주요', '도시'],
#  ['도시', '동시'],
#  ['동시', '다발'],
#  ['다발', '테러'],
#  ['테러', '공격'],
#  ['뉴욕', '세계무역센터']]

# %%
# 바이그램 출력
len(sentence_bigram)
# Out:
# 58032

# %%
# 뉴스데이터의 Uni-gram 만드는 과정 -> sentence_unigram
sentence_unigram=[]
for doc in tqdm(docs):
    p=tagger.pos(doc)
    tokens=[]
    
    for j in p:
        i=j[1]
        if (i in josa) | (i in jeop_misa_and_doosa) | (i in boosa) | (i in eomaleomy):
            continue
        tokens.append(j[0])
    
    for t in tokens:
        sentence_unigram.append(t)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 9369/9369 [00:00<00:00, 21397.47it/s]

# %%
print(len(sentence_unigram))
sentence_unigram[:20]
# Out:
# 67399
# ['세계무역센터',
#  '어떤',
#  '곳',
#  '인가',
#  '미국',
#  '주요',
#  '도시',
#  '동시',
#  '다발',
#  '테러',
#  '공격',
#  '뉴욕',
#  '세계무역센터',
#  '빌딩',
#  '비행기',
#  '충돌',
#  '럼즈펠드',
#  '美',
#  '국방',
#  '관료주의']

# %%
# sentence_unigram에 있는 한자로된 나라이름을 한글로 바꿔주는 과정
trans_cntry={'美':'미국','佛':'프랑스','日':'일본','中': '중국','露': '러시아','獨':'독일','北':'북한','英':'영국','弗':'달러' }

for i in range(len(sentence_unigram)):
    if sentence_unigram[i] in trans_cntry.keys():
        sentence_unigram[i]=trans_cntry[sentence_unigram[i]]
            
sentence_unigram[:20]
# Out:
# ['세계무역센터',
#  '어떤',
#  '곳',
#  '인가',
#  '미국',
#  '주요',
#  '도시',
#  '동시',
#  '다발',
#  '테러',
#  '공격',
#  '뉴욕',
#  '세계무역센터',
#  '빌딩',
#  '비행기',
#  '충돌',
#  '럼즈펠드',
#  '미국',
#  '국방',
#  '관료주의']

# %%
from nltk import ConditionalFreqDist

# 조건 빈도수 구함
cfd = ConditionalFreqDist(sentence_bigram)

# 특정 단어 다음에 가장 자주 나오는 단어 (조건부 빈도수) - 예시
print('SK ->', cfd["SK"].most_common(5))  # 'SK 에너지'의 등장 빈도수가 4, 'SK 텔'의 등장빈도수가 3이라는 뜻
print('나 ->', cfd["나"].most_common(20))
print('의 ->', cfd["의"].most_common(5))
print('삼성 ->', cfd["삼성"].most_common(5))
print('감사>', cfd["감사"].most_common(20))
# Out:
# SK -> [('에너지', 4), ('텔', 3), ('상사', 3), ('CC', 3), ('생명', 3)]
# 나 -> [('대통령', 1), ('노동', 1), ('IMF', 1), ('하', 1), ('증가', 1), ('히트상품', 1), ('엔', 1), ('년간', 1), ('예', 1), ('공동운항', 1), ('숙녀', 1), ('르', 1), ('결국', 1), ('하나', 1), ('년', 1), ('포스', 1), ('상상', 1), ('채권', 1), ('환율', 1), ('상승', 1)]
# 의 -> []
# 삼성 -> [('SDS', 10), ('경제', 9), ('항공', 7), ('중공업', 7), ('자동차', 6)]
# 감사> [('마음', 2), ('등', 2), ('인', 2), ('의견', 2), ('황용하', 1), ('감사원', 1), ('반', 1), ('선임', 1), ('이왕종', 1), ('주', 1), ('솜방망이', 1), ('보고서', 1)]

# %%
# 한글자 빼기
sen=[]
for i in sentence_unigram:
    if len(i)>1:
        sen.append(i)
sentence_unigram=copy.deepcopy(sen)

# %%
# Uni-gram의 단어와 단어별 빈도수를 데이터프레임으로 만듦 -> df
freq=[]
sentence_unigram=set(sentence_unigram)
for i in sentence_unigram:
    freq.append(sum(cfd[i].values()))

# %%
print(len(sentence_unigram))
print(len(freq))
# Out:
# 12238
# 12238

# %%
sentence_unigram=list(sentence_unigram)

# %%
sentence_unigram[:20]
# Out:
# ['동남아',
#  '딜레마',
#  '증서',
#  '편의',
#  '원당',
#  '범죄',
#  '향하',
#  '고양시',
#  '브루킹스',
#  '소서',
#  '전화료',
#  '가입자',
#  '달러 원',
#  '미니밴',
#  '분열증',
#  '이성태',
#  '후지쯔',
#  '아이',
#  '와타나베',
#  '친선']

# %%
df_unigram = pd.DataFrame({'Word':sentence_unigram,'Frequency':freq})
df_unigram = df_unigram.sort_values(by='Frequency', ascending=False)
df_unigram.index=df_unigram['Word']
df_unigram[:10]
# Out:
#      Word  Frequency
# Word
# 미국     미국        455
# 기업     기업        388
# 한국     한국        355
# 금융     금융        318
# 일본     일본        300
# 경제     경제        274
# 달러     달러        256
# 은행     은행        238
# 중국     중국        237
# 시장     시장        205

# %%
Frequency_df_unigram=df_unigram.head(1000)    # Uni-gram의 TF top1000이 들어간 데이터프레임 -> 저장할 데이터프레임
df_unigram.head(30)
# Out:
#      Word  Frequency
# Word
# 미국     미국        455
# 기업     기업        388
# 한국     한국        355
# 금융     금융        318
# 일본     일본        300
# 경제     경제        274
# 달러     달러        256
# 은행     은행        238
# 중국     중국        237
# 시장     시장        205
# 개발     개발        199
# LG     LG        194
# 정보     정보        185
# 수출     수출        182
# 기술     기술        175
# 투자     투자        175
# 현대     현대        171
# 사업     사업        165
# 정부     정부        160
# 업체     업체        157
# 지원     지원        156
# 인터넷   인터넷        152
# 산업     산업        152
# 금리     금리        152
# 삼성     삼성        151
# 전자     전자        137
# 경영     경영        136
# 세계     세계        136
# 시스템   시스템        135
# 내년     내년        133

# %%
# 예시)
print(df_unigram[df_unigram['Word']=='LG'].Frequency)  # LG라는 단어의 총 등장 횟수 : 194회

# 예시)
print(cfd['사람'].most_common()[0])    # '사람'이라는 단어 다음에 가장 많이 나오는 단어는 '정보' 이며 그 횟수는 2회
# Out:
# Word
# LG    194
# Name: Frequency, dtype: int64
# ('정보', 2)

# %%
import numpy as np
from matplotlib import pyplot as plt

t=cfd['한국'].values()   # 한국다음에 나오는 단어들의 등장횟수들을 그래프로 나타냄
plt.hist(t)              # 한국 다음에 나오는 단어들의 등장횟수중 1번이 제일 많음을 알 수 있다
# Out:
# (array([200.,  11.,   0.,   2.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 1. ,  3.7,  6.4,  9.1, 11.8, 14.5, 17.2, 19.9, 22.6, 25.3, 28. ]),
#  <a list of 10 Patch objects>)

# %%
# 각 단어별, 등장하는 단어들과 그 횟수들을 정리한 사전을 생성

d={}                          
for i in df_unigram.index:
    sub=[]
    d[i]=[]
    for p in cfd[i].most_common():
        if p[1]==1:
            break
        sub.append(p)
    d[i]+=sub

# %%
# 각 uni그램들의 횟수들을 이용해 bi그램을 생성
 
compound_word2 = [] 
frequency_word=[]

lst=[]

max_column_len=0
for j in range(len(df_unigram.index)):
    compound_word = [df_unigram.index[j]]
    test=[x[1] for x in d[df_unigram.index[j]]]    # 사전(d)내 키의 값들을 모두 더해서 빈도수를 만들고 그것을 frequency_word에 담음
    if sum(test)==0:
        continue
    frequency_word.append(sum(test))
    max_column_len=max(max_column_len,len(d[df_unigram.index[j]]))
    
    for i in d[df_unigram.index[j]]:
        word = i[0]
        if len(word)>1:
            compound = df_unigram.index[j] + ' ' + word +' ' +'(' + str(i[1]) +')'             
            lst.append((df_unigram.index[j]+word,i[1]))
            #compound = re.sub('[^\w\s]',"",compound) 
            #compound = re.sub('[a-zA-Z]',"",compound)
            #print(compound)
            compound_word.append(compound)
    compound_word2.append(compound_word)

# %%
compound_word2[:20]
# Out:
# [['미국',
#   '미국 일본 (11)',
#   '미국 유럽 (11)',
#   '미국 수출 (11)',
#   '미국 경제 (10)',
#   '미국 기업 (9)',
#   '미국 시장 (7)',
#   '미국 의회 (7)',
#   '미국 중국 (6)',
#   '미국 금융 (5)',
#   '미국 자동차 (4)',
#   '미국 금리 (4)',
#   '미국 국채 (4)',
#   '미국 달러 (4)',
#   '미국 정부 (4)',
#   '미국 영국 (4)',
#   '미국 최대 (4)',
#   '미국 EU (4)',
#   '미국 한국 (4)',
#   '미국 민주당 (3)',
#   '미국 FRB (3)',
#   '미국 증권 (3)',
#   '미국 증시 (3)',
#   '미국 방문 (3)',
#   '미국 신용 (3)',
#   '미국 상원 (3)',
#   '미국 경기 (3)',
#   '미국 회사 (3)',
#   '미국 하원 (3)',
#   '미국 IMF (3)',
#   '미국 연방 (3)',
#   '미국 반도체 (3)',
#   '미국 주요 (2)',
#   '미국 재무부 (2)',
#   '미국 캐나다 (2)',
#   '미국 기자 (2)',
#   '미국 대통령 (2)',
#   '미국 내년 (2)',
#   '미국 농무부 (2)',
#   '미국 채권 (2)',
#   '미국 대선 (2)',
#   '미국 실업 (2)',
#   '미국 주택 (2)',
#   '미국 USA (2)',
#   '미국 법인 (2)',
#   '미국 구제 (2)',
#   '미국 증권사 (2)',
#   '미국 PCS (2)',
#   '미국 품질 (2)',
#   '미국 자국 (2)',
#   '미국 벤처 (2)',
#   '미국 제소 (2)',
#   '미국 ITC (2)',
#   '미국 월마트 (2)'],
#  ['기업',
#   '기업 은행 (12)',
#   '기업 경영 (7)',
#   '기업 구조 (7)',
#   '기업 자금난 (6)',
#   '기업 선정 (5)',
#   '기업 모집 (5)',
#   '기업 지원 (4)',
#   '기업 개혁 (4)',
#   '기업 해외 (4)',
#   '기업 내년 (4)',
#   '기업 정보 (4)',
#   '기업 육성 (3)',
#   '기업 정책 (3)',
#   '기업 집단 (3)',
#   '기업 도시 (3)',
#   '기업 대상 (3)',
#   '기업 신용 (3)',
#   '기업 실적 (2)',
#   '기업 부도 (2)',
#   '기업 유럽 (2)',
#   '기업 대대 (2)',
#   '기업 세금 (2)',
#   '기업 어음 (2)',
#   '기업 총수 (2)',
#   '기업 문화 (2)',
#   '기업 한국 (2)',
#   '기업 지지 (2)',
#   '기업 도요타 (2)',
#   '기업 부문 (2)',
#   '기업 참여 (2)',
#   '기업 벤처 (2)',
#   '기업 부설 (2)',
#   '기업 대형 (2)',
#   '기업 부채 (2)',
#   '기업 개사 (2)',
#   '기업 환리스크 (2)',
#   '기업 개발 (2)',
#   '기업 세무 (2)',
#   '기업 MA (2)',
#   '기업 금융 (2)',
#   '기업 사업 (2)',
#   '기업 도산 (2)',
#   '기업 대출 (2)'],
#  ['한국',
#   '한국 경제 (28)',
#   '한국 기업 (12)',
#   '한국 투자 (11)',
#   '한국 금융 (10)',
#   '한국 무역 (6)',
#   '한국 IBM (6)',
#   '한국 신용 (6)',
#   '한국 일본 (5)',
#   '한국 MS (5)',
#   '한국 타이어 (4)',
#   '한국 정보 (4)',
#   '한국 조선 (4)',
#   '한국 생산 (4)',
#   '한국 컴팩 (4)',
#   '한국 중공업 (4)',
#   '한국 방문 (3)',
#   '한국 자기 (3)',
#   '한국 PC (3)',
#   '한국 HP (3)',
#   '한국 표준 (3)',
#   '한국 러시아 (3)',
#   '한국 국제 (3)',
#   '한국 진출 (3)',
#   '한국 구조 (3)',
#   '한국 컴퓨터 (3)',
#   '한국 상품 (2)',
#   '한국 단기외채 (2)',
#   '한국 업체 (2)',
#   '한국 수출 (2)',
#   '한국 산업디자인 (2)',
#   '한국 여성 (2)',
#   '한국 전자 (2)',
#   '한국 기술 (2)',
#   '한국 반도체 (2)',
#   '한국 벤처 (2)',
#   '한국 원자력 (2)',
#   '한국 야쿠르트 (2)',
#   '한국 철강 (2)',
#   '한국 인식 (2)',
#   '한국 강관 (2)',
#   '한국 산업가스 (2)',
#   '한국 중국 (2)',
#   '한국 미국 (2)'],
#  ['금융',
#   '금융 기관 (34)',
#   '금융 위기 (26)',
#   '금융 시장 (14)',
#   '금융 안정 (9)',
#   '금융 감독 (7)',
#   '금융 산업 (6)',
#   '금융 감독원 (6)',
#   '금융 종합 (6)',
#   '금융 불안 (5)',
#   '금융 상품 (5)',
#   '금융 지원 (5)',
#   '금융 구조 (4)',
#   '금융 사고 (3)',
#   '금융 시스템 (3)',
#   '금융 대책 (3)',
#   '금융 소득 (3)',
#   '금융 회사 (3)',
#   '금융 지주 (3)',
#   '금융 그룹 (3)',
#   '금융 거래 (3)',
#   '금융 연구원 (3)',
#   '금융 연수원 (3)',
#   '금융 지표 (3)',
#   '금융 정상 (2)',
#   '금융 정보 (2)',
#   '금융 회장 (2)',
#   '금융 분쟁 (2)',
#   '금융 당국 (2)',
#   '금융 부문 (2)',
#   '금융 자금 (2)',
#   '금융 대출 (2)',
#   '금융 계열사 (2)',
#   '금융 경제 (2)',
#   '금융 기업 (2)',
#   '금융 대우 (2)',
#   '금융 자동화 (2)'],
#  ['일본',
#   '일본 기업 (12)',
#   '일본 경제 (11)',
#   '일본 미국 (6)',
#   '일본 은행 (6)',
#   '일본 정부 (6)',
#   '일본 금융 (5)',
#   '일본 자동차 (4)',
#   '일본 총리 (4)',
#   '일본 수출 (4)',
#   '일본 분기 (3)',
#   '일본 미쓰비시 (3)',
#   '일본 파견 (3)',
#   '일본 주가 (2)',
#   '일본 상륙 (2)',
#   '일본 마쓰시타 (2)',
#   '일본 미쓰이 (2)',
#   '일본 디플레이션 (2)',
#   '일본 닛케이 (2)',
#   '일본 대형 (2)',
#   '일본 국채 (2)',
#   '일본 금리 (2)',
#   '일본 외환 (2)',
#   '일본 NTT (2)',
#   '일본 우량 (2)',
#   '일본 샤프 (2)',
#   '일본 공장 (2)',
#   '일본 소니 (2)',
#   '일본 신용 (2)',
#   '일본 도시바 (2)',
#   '일본 시장 (2)',
#   '일본 수입 (2)',
#   '일본 진출 (2)',
#   '일본 이토 (2)'],
#  ['경제',
#   '경제 정책 (13)',
#   '경제 위기 (12)',
#   '경제 신문 (8)',
#   '경제 살리 (7)',
#   '경제 연구소 (7)',
#   '경제 대책 (6)',
#   '경제 단체장 (5)',
#   '경제 신문사 (5)',
#   '경제 협력 (4)',
#   '경제 회복 (4)',
#   '경제 기획 (4)',
#   '경제 대책위 (4)',
#   '경제 장관 (4)',
#   '경제 성장 (3)',
#   '경제 전망 (3)',
#   '경제 단체 (3)',
#   '경제 활동 (3)',
#   '경제 연착륙 (3)',
#   '경제 연 분석 (3)',
#   '경제 개혁 (3)',
#   '경제 수석 (3)',
#   '경제 현안 (3)',
#   '경제 분기 (2)',
#   '경제 질식 (2)',
#   '경제 대국 (2)',
#   '경제 전략 (2)',
#   '경제 침체 (2)',
#   '경제 회생 (2)',
#   '경제 부처 (2)',
#   '경제 자유 (2)',
#   '경제 미치 (2)',
#   '경제 활성 (2)',
#   '경제 흔들 (2)',
#   '경제 대상 (2)',
#   '경제 간다 (2)',
#   '경제 문회 (2)',
#   '경제 복병 (2)',
#   '경제 관료 (2)',
#   '경제 효과 (2)',
#   '경제 외교 (2)',
#   '경제 부총리 (2)',
#   '경제 안정 (2)',
#   '경제 연구원 (2)'],
#  ['달러',
#   '달러 규모 (13)',
#   '달러 투자 (10)',
#   '달러 수주 (10)',
#   '달러 수출 (8)',
#   '달러 유치 (7)',
#   '달러 지원 (5)',
#   '달러 돌파 (5)',
#   '달러 어치 (5)',
#   '달러 투입 (4)',
#   '달러 공급 (4)',
#   '달러 이상 (4)',
#   '달러 출연 (3)',
#   '달러 전망 (3)',
#   '달러 조달 (3)',
#   '달러 도입 (3)',
#   '달러 흑자 (3)',
#   '달러 조기 (3)',
#   '달러 그쳐 (2)',
#   '달러 긴급 (2)',
#   '달러 미국 (2)',
#   '달러 추가 (2)',
#   '달러 구제 (2)',
#   '달러 가치 (2)',
#   '달러 무제한 (2)',
#   '달러 부양책 (2)',
#   '달러 최고 (2)',
#   '달러 손실 (2)',
#   '달러 사상 (2)',
#   '달러 차입 (2)',
#   '달러 물려 (2)',
#   '달러 기록 (2)',
#   '달러 안팎 (2)',
#   '달러 확보 (2)',
#   '달러 합의 (2)'],
#  ['은행',
#   '은행 구조 (6)',
#   '은행 예금 (5)',
#   '은행 부실 (4)',
#   '은행 외화 (4)',
#   '은행 감독원 (4)',
#   '은행 한국 (3)',
#   '은행 경영 (3)',
#   '은행 기업 (3)',
#   '은행 총재 (2)',
#   '은행 주식 (2)',
#   '은행 경영진 (2)',
#   '은행 외국인 (2)',
#   '은행 증권 (2)',
#   '은행 금리 (2)',
#   '은행 해외 (2)',
#   '은행 中企 (2)',
#   '은행 대출 (2)',
#   '은행 예대 (2)',
#   '은행 가계 (2)',
#   '은행 중도 (2)',
#   '은행 채권 (2)',
#   '은행 외환 (2)',
#   '은행 연합회 (2)',
#   '은행 거래 (2)'],
#  ['중국',
#   '중국 미국 (5)',
#   '중국 정부 (5)',
#   '중국 위안 (4)',
#   '중국 금리 (4)',
#   '중국 WTO (4)',
#   '중국 수출 (4)',
#   '중국 CDMA (4)',
#   '중국 한국 (3)',
#   '중국 진출 (3)',
#   '중국 경제 (3)',
#   '중국 부동산 (3)',
#   '중국 시장 (3)',
#   '중국 바이러스 (2)',
#   '중국 금융 (2)',
#   '중국 원전 (2)',
#   '중국 외국 (2)',
#   '중국 총리 (2)',
#   '중국 무역 (2)',
#   '중국 우한 봉쇄 (2)',
#   '중국 첨단 (2)',
#   '중국 산업 (2)',
#   '중국 벤처 (2)',
#   '중국 현지 (2)',
#   '중국 합작 (2)',
#   '중국 재정 (2)',
#   '중국 공략 (2)'],
#  ['시장',
#   '시장 진출 (12)',
#   '시장 개척 (7)',
#   '시장 안정 (7)',
#   '시장 점유 (6)',
#   '시장 개방 (5)',
#   '시장 본격 공략 (5)',
#   '시장 안정책 (4)',
#   '시장 적극 (4)',
#   '시장 큰손 (3)',
#   '시장 불안 (3)',
#   '시장 가격 (3)',
#   '시장 판매 (3)',
#   '시장 급속 (3)',
#   '시장 경제 (3)',
#   '시장 돌풍 (3)',
#   '시장 개입 (2)',
#   '시장 급팽창 (2)',
#   '시장 활기 (2)',
#   '시장 선점 (2)',
#   '시장 노크 (2)',
#   '시장 분기 (2)',
#   '시장 수출 (2)',
#   '시장 탐색 (2)',
#   '시장 규모 (2)',
#   '시장 참여 (2)',
#   '시장 세대 (2)'],
#  ['개발',
#   '개발 한국 (5)',
#   '개발 LG (5)',
#   '개발 사업 (4)',
#   '개발 현대 (4)',
#   '개발 본격 (3)',
#   '개발 성공 (3)',
#   '개발 대우 (3)',
#   '개발 시판 (3)',
#   '개발 자금 (3)',
#   '개발 기술 (2)',
#   '개발 미국 (2)',
#   '개발 내년 (2)',
#   '개발 연구 (2)',
#   '개발 KIST (2)',
#   '개발 공급 (2)',
#   '개발 국제 (2)',
#   '개발 경쟁 (2)',
#   '개발 내달 (2)',
#   '개발 대우중공업 (2)',
#   '개발 판매 (2)',
#   '개발 삼성 (2)',
#   '개발 세계 (2)'],
#  ['LG',
#   'LG 전자 (38)',
#   'LG 정보 (10)',
#   'LG 반도체 (8)',
#   'LG 경제 (7)',
#   'LG 텔레콤 (6)',
#   'LG 카드 (6)',
#   'LG 산전 (5)',
#   'LG 화재 (3)',
#   'LG 그룹 (3)',
#   'LG 애드 (3)',
#   'LG 캐피탈 (3)',
#   'LG 필립스 (2)',
#   'LG 건설 (2)',
#   'LG 백화점 (2)',
#   'LG 기계 (2)',
#   'LG 인터넷 (2)',
#   'LG 정밀 (2)',
#   'LG 창업투자 (2)',
#   'LG 유통 (2)',
#   'LG 하반기 (2)',
#   'LG 디스플레이 (2)',
#   'LG 텍사코 (2)'],
#  ['정보',
#   '정보 통신 (51)',
#   '정보 시스템 (20)',
#   '정보 서비스 (11)',
#   '정보 기술 (10)',
#   '정보 통신부 (6)',
#   '정보 제공 (5)',
#   '정보 추진 (4)',
#   '정보 산업 (4)',
#   '정보 사회 (2)',
#   '정보 문화 (2)',
#   '정보 컨설팅 (2)',
#   '정보 화선 (2)',
#   '정보 촉진 (2)',
#   '정보 구축 (2)'],
#  ['수출',
#   '수출 계약 (7)',
#   '수출 시장 (6)',
#   '수출 LG (4)',
#   '수출 증가 (4)',
#   '수출 키로 (4)',
#   '수출 기업 (3)',
#   '수출 상품 (3)',
#   '수출 전략 (3)',
#   '수출 삼성전자 (3)',
#   '수출 보험 (3)',
#   '수출 확대 (3)',
#   '수출 급증 (3)',
#   '수출 총력 (3)',
#   '수출 업체 (2)',
#   '수출 감소 (2)',
#   '수출 업계 (2)',
#   '수출 비중 (2)',
#   '수출 상담 (2)',
#   '수출 규모 (2)',
#   '수출 신용 (2)',
#   '수출 호조 (2)',
#   '수출 중심 (2)',
#   '수출 대행 (2)',
#   '수출 늘린다 (2)',
#   '수출 목표 (2)',
#   '수출 지원 (2)',
#   '수출 구매 (2)',
#   '수출 현대 (2)',
#   '수출 자유 (2)'],
#  ['기술',
#   '기술 개발 (18)',
#   '기술 혁신 (8)',
#   '기술 연구원 (7)',
#   '기술 투자 (6)',
#   '기술 품질원 (5)',
#   '기술 표준 (4)',
#   '기술 수출 (3)',
#   '기술 국제 (3)',
#   '기술 세미나 개최 (3)',
#   '기술 거래소 (3)',
#   '기술 경쟁력 (3)',
#   '기술 세계 (2)',
#   '기술 독자 (2)',
#   '기술 협력 (2)',
#   '기술 평가 (2)',
#   '기술 인정 (2)',
#   '기술 지도 (2)',
#   '기술 창업 (2)',
#   '기술 정보 (2)',
#   '기술 신보 (2)',
#   '기술 경영 (2)',
#   '기술 지원 (2)',
#   '기술 보유 (2)',
#   '기술 제휴 (2)',
#   '기술 연구소 (2)',
#   '기술 지정 (2)'],
#  ['투자',
#   '투자 확대 (8)',
#   '투자 자금 (3)',
#   '투자 설명회 (3)',
#   '투자 증권 (3)',
#   '투자 유치 (3)',
#   '투자 신탁 (3)',
#   '투자 내년 (2)',
#   '투자 펀드 (2)',
#   '투자 시동 (2)',
#   '투자 수단 (2)',
#   '투자 적기 (2)',
#   '투자 담사 (2)',
#   '투자 조합 (2)',
#   '투자 축소 (2)',
#   '투자 허용 (2)',
#   '투자 계획 (2)',
#   '투자 조사단 (2)',
#   '투자 규모 (2)',
#   '투자 세액 (2)',
#   '투자 위험 (2)',
#   '투자 박람회 (2)',
#   '투자 협력 (2)'],
#  ['현대',
#   '현대 전자 (18)',
#   '현대 중공업 (13)',
#   '현대 자동차 (9)',
#   '현대 LG (6)',
#   '현대 금강산 (3)',
#   '현대 건설 (3)',
#   '현대 기아 (3)',
#   '현대 정공 (3)',
#   '현대 自救 (3)',
#   '현대 협력사 (2)',
#   '현대 엘리베이터 (2)',
#   '현대 강관 (2)',
#   '현대 미포조선 (2)',
#   '현대 리바트 (2)',
#   '현대 상사 (2)',
#   '현대 정보 (2)',
#   '현대 채권단 (2)',
#   '현대 문제 (2)',
#   '현대 오토 (2)',
#   '현대 일본 (2)',
#   '현대 카드 (2)',
#   '현대 정유 (2)'],
#  ['사업',
#   '사업 진출 (13)',
#   '사업 계획 (8)',
#   '사업 부문 (6)',
#   '사업 구조 (6)',
#   '사업 포기 (4)',
#   '사업 본격 진출 (3)',
#   '사업 설명회 (3)',
#   '사업 수주 (3)',
#   '사업 참여 (3)',
#   '사업 지원 (2)',
#   '사업 축소 (2)',
#   '사업 교환 (2)',
#   '사업 본격 (2)',
#   '사업 철수 (2)',
#   '사업 합작 (2)',
#   '사업 다각화 (2)',
#   '사업 선정 (2)',
#   '사업 신규 (2)'],
#  ['정부',
#   '정부 지원 (5)',
#   '정부 IMF (4)',
#   '정부 금융 (4)',
#   '정부 경제 (4)',
#   '정부 부처 (3)',
#   '정부 주식 (2)',
#   '정부 자민 (2)',
#   '정부 건물 (2)',
#   '정부 출범 (2)',
#   '정부 업계 (2)',
#   '정부 종금 (2)',
#   '정부 추진 (2)',
#   '정부 건의 (2)',
#   '정부 산하 (2)',
#   '정부 보증 (2)',
#   '정부 기업 (2)',
#   '정부 영세 (2)'],
#  ['업체',
#   '업체 소개 (4)',
#   '업체 설립 (3)',
#   '업체 모집 (3)',
#   '업체 참여 (3)',
#   '업체 부상 (2)',
#   '업체 지원 (2)',
#   '업체 대상 (2)',
#   '업체 인수 (2)',
#   '업체 합작 (2)']]

# %%
df_bigram = pd.DataFrame(compound_word2)
df_bigram=df_bigram.rename(columns = {0: "Word"})

# %%
df_bigram.insert(1, 'Total_Frequency', frequency_word)
print(len(frequency_word))
# Out:
# 1687

# %%
df_bigram.head(10)
# Out:
#   Word  Total_Frequency           1           2           3           4  \
# 0   미국              214  미국 일본 (11)  미국 유럽 (11)  미국 수출 (11)  미국 경제 (10)
# 1   기업              152  기업 은행 (12)   기업 경영 (7)   기업 구조 (7)  기업 자금난 (6)
# 2   한국              186  한국 경제 (28)  한국 기업 (12)  한국 투자 (11)  한국 금융 (10)
# 3   금융              202  금융 기관 (34)  금융 위기 (26)  금융 시장 (14)   금융 안정 (9)
# 4   일본              123  일본 기업 (12)  일본 경제 (11)   일본 미국 (6)   일본 은행 (6)
# 5   경제              177  경제 정책 (13)  경제 위기 (12)   경제 신문 (8)   경제 살리 (7)
# 6   달러              146  달러 규모 (13)  달러 투자 (10)  달러 수주 (10)   달러 수출 (8)
# 7   은행               76   은행 구조 (6)   은행 예금 (5)   은행 부실 (4)   은행 외화 (4)
# 8   중국               77   중국 미국 (5)   중국 정부 (5)   중국 위안 (4)   중국 금리 (4)
# 9   시장              101  시장 진출 (12)   시장 개척 (7)   시장 안정 (7)   시장 점유 (6)
#
#             5             6            7           8  ...         44  \
# 0   미국 기업 (9)     미국 시장 (7)    미국 의회 (7)   미국 중국 (6)  ...  미국 법인 (2)
# 1   기업 선정 (5)     기업 모집 (5)    기업 지원 (4)   기업 개혁 (4)  ...       None
# 2   한국 무역 (6)    한국 IBM (6)    한국 신용 (6)   한국 일본 (5)  ...       None
# 3   금융 감독 (7)     금융 산업 (6)   금융 감독원 (6)   금융 종합 (6)  ...       None
# 4   일본 정부 (6)     일본 금융 (5)   일본 자동차 (4)   일본 총리 (4)  ...       None
# 5  경제 연구소 (7)     경제 대책 (6)   경제 단체장 (5)  경제 신문사 (5)  ...       None
# 6   달러 유치 (7)     달러 지원 (5)    달러 돌파 (5)   달러 어치 (5)  ...       None
# 7  은행 감독원 (4)     은행 한국 (3)    은행 경영 (3)   은행 기업 (3)  ...       None
# 8  중국 WTO (4)     중국 수출 (4)  중국 CDMA (4)   중국 한국 (3)  ...       None
# 9   시장 개방 (5)  시장 본격 공략 (5)   시장 안정책 (4)   시장 적극 (4)  ...       None
#
#           45          46          47         48         49         50  \
# 0  미국 구제 (2)  미국 증권사 (2)  미국 PCS (2)  미국 품질 (2)  미국 자국 (2)  미국 벤처 (2)
# 1       None        None        None       None       None       None
# 2       None        None        None       None       None       None
# 3       None        None        None       None       None       None
# 4       None        None        None       None       None       None
# 5       None        None        None       None       None       None
# 6       None        None        None       None       None       None
# 7       None        None        None       None       None       None
# 8       None        None        None       None       None       None
# 9       None        None        None       None       None       None
#
#           51          52          53
# 0  미국 제소 (2)  미국 ITC (2)  미국 월마트 (2)
# 1       None        None        None
# 2       None        None        None
# 3       None        None        None
# 4       None        None        None
# 5       None        None        None
# 6       None        None        None
# 7       None        None        None
# 8       None        None        None
# 9       None        None        None
#
# [10 rows x 55 columns]

# %%
# Top 1000까지의 bigram단어들을 추출

lst=sorted(lst,key=lambda x : x[1],reverse=True)
top_1000=lst[:1000]
top_1000

Frequency_df=pd.DataFrame()
compound_word=[]
freqs=[]
for i in top_1000:
    compound_word.append(i[0])
    freqs.append(i[1])
Frequency_df_bigram=pd.DataFrame({'Word':compound_word,'Frequency':freqs})
Frequency_df_bigram.head(10)
# Out:
#     Word  Frequency
# 0   구조조정         95
# 1   정보통신         51
# 2   LG전자         38
# 3  시스템개발         36
# 4   금융기관         34
# 5   천만달러         31
# 6   벤처기업         29
# 7   한국경제         28
# 8   금리인하         28
# 9   금융위기         26

# %%
# Frequency_df_bigram : BI-gram TF Top1000 단어 (처음 한번만 해주기)
# Frequency_df_unigram : Uni-gram TF Top1000 단어 (처음 한번만 해주기)
Frequency_df_bigram.to_excel('./Bi_Gram_By_Mecab_Top1000.xlsx',encoding='utf-8-sig',index=False) 
Frequency_df_unigram.to_excel('./Uni_Gram_By_Mecab_Top1000.xlsx',encoding='utf-8-sig',index=False)

# %%
df_bigram = df_bigram.sort_values(by='Total_Frequency', ascending=False)
df_bigram.head(10)
# Out:
#    Word  Total_Frequency           1            2            3           4  \
# 0    미국              214  미국 일본 (11)   미국 유럽 (11)   미국 수출 (11)  미국 경제 (10)
# 3    금융              202  금융 기관 (34)   금융 위기 (26)   금융 시장 (14)   금융 안정 (9)
# 2    한국              186  한국 경제 (28)   한국 기업 (12)   한국 투자 (11)  한국 금융 (10)
# 5    경제              177  경제 정책 (13)   경제 위기 (12)    경제 신문 (8)   경제 살리 (7)
# 1    기업              152  기업 은행 (12)    기업 경영 (7)    기업 구조 (7)  기업 자금난 (6)
# 6    달러              146  달러 규모 (13)   달러 투자 (10)   달러 수주 (10)   달러 수출 (8)
# 11   LG              127  LG 전자 (38)   LG 정보 (10)   LG 반도체 (8)   LG 경제 (7)
# 12   정보              123  정보 통신 (51)  정보 시스템 (20)  정보 서비스 (11)  정보 기술 (10)
# 4    일본              123  일본 기업 (12)   일본 경제 (11)    일본 미국 (6)   일본 은행 (6)
# 34   구조              113  구조 조정 (95)    구조 개선 (9)   구조 조정안 (4)   구조 개혁 (3)
#
#              5           6           7           8  ...         44         45  \
# 0    미국 기업 (9)   미국 시장 (7)   미국 의회 (7)   미국 중국 (6)  ...  미국 법인 (2)  미국 구제 (2)
# 3    금융 감독 (7)   금융 산업 (6)  금융 감독원 (6)   금융 종합 (6)  ...       None       None
# 2    한국 무역 (6)  한국 IBM (6)   한국 신용 (6)   한국 일본 (5)  ...       None       None
# 5   경제 연구소 (7)   경제 대책 (6)  경제 단체장 (5)  경제 신문사 (5)  ...       None       None
# 1    기업 선정 (5)   기업 모집 (5)   기업 지원 (4)   기업 개혁 (4)  ...       None       None
# 6    달러 유치 (7)   달러 지원 (5)   달러 돌파 (5)   달러 어치 (5)  ...       None       None
# 11  LG 텔레콤 (6)   LG 카드 (6)   LG 산전 (5)   LG 화재 (3)  ...       None       None
# 12  정보 통신부 (6)   정보 제공 (5)   정보 추진 (4)   정보 산업 (4)  ...       None       None
# 4    일본 정부 (6)   일본 금융 (5)  일본 자동차 (4)   일본 총리 (4)  ...       None       None
# 34  구조 조정위 (2)        None        None        None  ...       None       None
#
#             46          47         48         49         50         51  \
# 0   미국 증권사 (2)  미국 PCS (2)  미국 품질 (2)  미국 자국 (2)  미국 벤처 (2)  미국 제소 (2)
# 3         None        None       None       None       None       None
# 2         None        None       None       None       None       None
# 5         None        None       None       None       None       None
# 1         None        None       None       None       None       None
# 6         None        None       None       None       None       None
# 11        None        None       None       None       None       None
# 12        None        None       None       None       None       None
# 4         None        None       None       None       None       None
# 34        None        None       None       None       None       None
#
#             52          53
# 0   미국 ITC (2)  미국 월마트 (2)
# 3         None        None
# 2         None        None
# 5         None        None
# 1         None        None
# 6         None        None
# 11        None        None
# 12        None        None
# 4         None        None
# 34        None        None
#
# [10 rows x 55 columns]

# %%
df_bigram.to_excel('./Bigram_Words.xlsx',encoding='utf-8-sig',index=False)

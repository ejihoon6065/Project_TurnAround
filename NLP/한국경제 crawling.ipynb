# %%
from wordcloud import WordCloud, STOPWORDS
import urllib.request
from urllib.request import urlopen
import requests 
from urllib.request import HTTPError
from bs4 import BeautifulSoup
from konlpy.tag import Okt 
import re
from collections import Counter
import pytagcloud
import pygame

# %%
year = 2020
month = 9
list1 = []
for i in range(30):
    list2 = []
    day = i+1
    if i+1 <=9 :
        day = '0' + str(i+1)
    else :
        day = i + 1
    
    for j in range(5) :
        
        page = j+1
        

        url = f'https://hankyung.com/economy/?date={year}.{month}.{day}&page={page}'
        #url = 'https://www.hankyung.com/economy?date=2020.04.01'
        response = requests.get(url)
        html = response.text
        #print(html)
        soup = BeautifulSoup(response.content.decode('UTF-8','replace'))
        #print(soup)
        tit1 = soup.find_all('div', 'article') # 1~ 10
        tit2 = soup.find_all('h3', 'tit') # 나머지 
        #print(tit1)
        #print(tit2)
        

        for i in range(len(tit2)):
            a=str(tit2[i])
            a2 = a.split('>')[2]

            a3 = a2.split('<')[0]
            list2.append(a3)
    list1.append(list2)

list1
# Out:
# [['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
# ...
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"],
#  ['키신저, 미중 갈등에 "1차 대전 유사 상황 갈 수도" 경고',
#   '웰크론한텍, 2020 한국건축문화대상 국토부장관상 수상',
#   'LG폰 22분기 연속 적자…적자폭은 3분기 연속 개선',
#   '동화기업, 2020년 하반기 신입·경력사원 공개채용',
#   '우리이앤엘 "계열사 Wooree에 74억원 출자"',
#   '홈앤쇼핑, 20 F/W 맞이 패션 카테고리 강화',
#   '중국 고급차 시장 성장에 BMW 3분기 中판매 30% 증가',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   'LG전자 비수기에 1조원 가까이 벌었다…3분기 최대 실적(종합)',
#   '홍남기 "대주주 양도세 \'지분율 1%\' 요건 조정 검토"',
#   'DGB대구은행 캄보디아 법인 상업은행 라이선스 획득',
#   '[한경 CFO Insight] 초격차 / 권오현 전 삼성전자 회장이 꼭 없애고 싶었던 것',
#   '[한경 CFO Insight]코로나19가 기업 재무보고에 미치는 영향...이채능 삼정KPMG 감사부문 상무',
#   '경남·부산·전남, 고부가가치 항만배후단지 조성에 힘모은다',
#   '[1보] LG전자 3분기 영업이익 9천590억원…작년 동기 대비 22.7%↑',
#   '[한경 CFO Insight] 시총 30위 상장사 CFO 연봉왕은 윤재수 엔씨소프트 부사장',
#   "[한경 CFO Insight] 내년 가장 큰 위협은 '수요부진'",
#   '중국 어선 불법조업 여전…최근 5년간 1천704척 적발',
#   '아모레 가맹점 20개월새 ⅓ 사라져…"본사 온라인 정책 탓"',
#   '"4대 은행 채용비리 \'후속조치\' 미흡"',
#   '현대모비스, AR 헤드업디스플레이 개발위해 英업체에 300억 투자',
#   '월켐저축은행, 연 3.2~6.0% 이자주는 적금 12~16일 판매',
#   '윤준병 의원 "최근 10년간 30대 건설사 산재 사망 485명"',
#   '"\'2021 티볼리 에어\' 타고 2박3일 차박 떠나세요"',
#   '중소조선연구원, 빅데이터 보안 인증 교육생 모집',
#   '전기차 충전 쉬워진다…한전, 로밍 중개 서비스 개발',
#   '잇단 화재 발생 현대차 코나 EV, 16일부터 리콜',
#   '"면역력 강화" 백두대간수목원 명품 흑도라지 진액 제품 개발',
#   '"여의도 면적 1천배, 공유수면 불법 점용"…해수부 50년간 방치',
#   '한·중, 560억달러 통화스와프 연장',
#   "BMW, '뉴 320i 블랙 수트' 100대 한정 출시…5420만원",
#   "외국인 근로자 웃게 한 'K송금'…동남아 사로잡았다 [넥스트K]",
#   '부채 9조 농어촌공사, 나주에 아파트 137채 보유…"시가 307억"',
#   '삼성전자, 3분기 기대 이상 실적에 장중 주가 6만원대 진입(종합)',
#   '청정바다 완도 수산물, 베트남 시장 두드린다',
#   'KB금융지주, 2천700억원 규모 ESG 채권 발행',
#   '농어촌공사, 에티오피아 농촌개발사업 설계·감리 수주',
#   "핀란드 국민 캐릭터 '무민' 제주서 만나요…무민랜드 개관",
#   '따이공의 귀환…면세업계 "죽음의 계곡 넘었나" 기대감',
#   '공정위원장 "네이버, 다른 분야서도 알고리즘 조정 가능할 것"',
#   '부산서 아파트 입주자대표회의 상대 감사요청 잇따라',
#   '통계청 "올해 쌀생산량 363만t 예측"…장마·태풍에 3% 줄어',
#   '野 "재벌개혁 앞장설테니 노동개혁에 협조하라"',
#   '기업 10곳 중 3곳은 초과 유보금 과세 대상…국회서 반대 기류(종합)',
#   '집중호우에 부서진 제방 등 시설물 80%, 안전등급 받았다',
#   '여야 \'대주주 3억\' 일제히 질타…홍남기 "수정 쉽지 않다"',
#   '해안데크·둘레숲길·전망대…가을에 더 볼만한 목포 고하도',
#   '화성시 버스공영제 첫발부터 삐끗…127명 모집공고에 채용 5명뿐',
#   '테슬라 전 CTO 스트라우벨 배터리 재활용 사업 확대 추진',
#   "한번 배 타면 최장 13일…'극한직업?' 어업관리단",
#   '"중소기업·소상공인 특례보증서 저신용자 2.7% 불과"',
#   '산은, 단일 건물 국내 최대 물류센터에 지분 10% 출자',
#   '홍남기 "주택·주식시장 상승만 하는 것 아냐…판단후 투자해야"',
#   '금융시장 의구심 키우는 중국 부동산 개발사 유동성',
#   '"재수 말고 의대 갈걸" 삼성 서류 발표 날 서울공대 카톡방에선…',
#   '비오는 밤에도 잘 보이는 차선, 고속도로 전 구간 확대',
#   '"중소기업 5년간 기술 유출·탈취로 4천346억원 피해"',
#   '하고(HAGO), 코로나에도 올 매출 372% 급등한 비결은?',
#   '중국인 한국·홍콩 여행 막히자 하이난 면세점 대박…"매출 5조"',
#   '제조업·조선업 불황 탓?…부산·경남 법원 경매 증가율 최고',
#   '부산산업혁신원 "제조업 고도화 위해 엔지니어링 산업 주목"',
#   '"나가주세요"…홍남기 부총리도 전셋집서 쫓겨날 판',
#   '홍남기 "전셋값 쉽게 안 내려갈 것 같다…추가 대책 강구"',
#   "'다재다능한 소형 SUV' 뉴 미니 컨트리맨 국내 출시",
#   '[고침] 경제(삼성전자 또 예상 뛰어넘었다…펜트업 수요에…)',
#   '농협카드 용산 콜센터서 또 코로나19 확진자 나와',
#   "마스크 생활에 입술 보습제 인기…GS리테일 '이재용 립밤' 판매",
#   '코로나19로 소비자 피해 늘었는데…"인력부족으로 처리율 하락"',
#   "8월 경상수지 65.7억달러로 4개월 연속 흑자…수출입 감소 '불황형'",
#   'BMW코리아, 미니 부분변경 컨트리맨 출시',
#   '기보·연세대 고등교육혁신원 소셜벤처 활성화 협약',
#   "미 당국 '내부 통제 부실' 씨티그룹에 4천억원대 제재금",
#   '조정훈 "산자부? 중기부? 수출바우처 사업 혼선 심각"',
#   'EU 의원들, 아마존 CEO에 "염탐할 생각인가"',
#   '첫 여성 WTO 사무총장 눈앞…유명희 vs 오콘조',
#   '"지식재산금융 평가기간 기술금융의 4배…비용 최대 20배 비싸"',
#   "'연말 특수' 맞아 와인 강화하는 이마트24",
#   "갑자기 추워진 날씨에…편의점 손님들 '이것' 부터 찾았다",
#   "대우건설, 보츠와나-잠비아 접경 '카중굴라 교량' 준공",
#   "하나은행 '일달러 외화적금' 출시 한달만에 1만좌 돌파",
#   '미정산 알림에 사다리타기까지…카카오페이, 정산하기 개편',
#   '박영선 "디지털경제 선도…중소기업·소상공인 스마트화 추진"',
#   '삼성전자 또 예상 뛰어넘었다…펜트업 수요에 화웨이 특수까지',
#   "'세계 최초 양산' 현대차 수소트럭, 스위스서 달린다",
#   '원자력연, 손바닥 크기 장치로 선명한 엑스선 촬영 기술 이전',
#   '"보상금 주며 나라가 승계한 국유특허 활용률 22.7% 불과"',
#   '제4회 판교자율주행모빌리티쇼, 15일 개막',
#   '캐딜락코리아, CT4 원메이크 레이스 참가자 모집',
#   '"특허 괴물 업체, 기업과 제휴 과장 특허 남발…특허 시장 교란"',
#   "쉐보레 '트레일블레이저 RS 미드나잇' 홍보모델에 가수 박재범",
#   '경제교육대상 수상자 공모…코로나 대비 비대면사례 중점 시상',
#   'GS25 "편의점서 대용량 생맥주 주문하세요"',
#   '반도체 코리아 3분기 선전…모바일·화웨이 덕봤다',
#   '도로교통공단, 2020년 하반기 청년인턴 공개 채용',
#   '벤츠, 전기 AMG·마이바흐 출시 확정',
#   '한국지엠, 박재범과 트레일블레이저 RS 미드나잇 알린다',
#   '지난해 추경사업 19개는 반도 못 썼다…"주먹구구식 추경 편성"',
#   '美·中 충돌 속 日의 계산…韓 배제 노리나 [여기는 논설실]',
#   "8월 경상수지 66억달러 흑자…수입이 감소한 '불황형 흑자'",
#   "'자동차 유리로 목걸이를'…현대차 업사이클링 프로젝트 공개"]]
